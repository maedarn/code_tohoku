# %%
import numpy as np
import matplotlib.pyplot as plt
 
z = np.arange(0, 100, 0.1)   # xを-5から5まで0.1刻みで用意する
T_lb =138.0 - 138.0/(1.0+z)               # y = sin x
Tk=2.73 * (1.0+z)

#plt.plot( T_lb,z)   # 横軸をxとして y=y(x) のグラフをプロットする
plt.plot(z,Tk) 
plt.show()
