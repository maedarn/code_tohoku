# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.animation as animation
from matplotlib.animation import ArtistAnimation
from sympy import *
from sympy.codegen.cfunctions import log10
import pylab
from matplotlib.colors import Normalize # Normalizeをimport
from matplotlib.colors import LogNorm

import matplotlib.colors as colors
norm = [0,1,10,20,50,100,200,500,1000,2000,5000,10000]
norml=colors.BoundaryNorm(norm,256)
m.imshow(ma.masked_less_equal(gdriv2[0],0),norm=norml,cmap=cm.YlGnBu)






#colorbar(ticks=[0.1,1,10]).set_ticklabels(["0.1","1","10"])


dir = '/Users/maeda/Desktop/'

# %%
a=0.01
n = np.logspace(-2,4,100)
Tg = np.logspace(2,7,100)
#10e6 K -> 160 km/s
#
nm, Tgm = np.meshgrid(n, Tg)

t = 5.5*(nm/1000.0)**(-1)*(a/0.01)*((2.0*10.0**6.0/Tgm)**2.5+1.0)



fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

#im=plt.imshow(Z,extent=(-1,1,-1,1))
#plt.pcolormesh(X,Y,Z,cmap='bwr', vmin=-1.0, vmax=1.0) #等高線図の生成。cmapで色付けの規則を指定する
#plt.pcolormesh(X2,Y2,Phi_g,cmap='bwr', vmin=-1.0, vmax=1.0) 
plt.pcolormesh(nm,Tgm,t, norm=LogNorm(vmin=1000,vmax=1e6))#, vmin=-1.0, vmax=1.0) 
#plt.pcolormesh(nm,Tgm,t, , norm=colors.LogNorm(vmin=Z.min(), vmax=Z.max()),cmap=cm.summer)
plt.colorbar(orientation="vertical")#カラーバーの表示
plt.plot(4.0,1e5,'*',markersize=20,c='red')
#plt.quiver(X, Y, gr , gphi, color='green')

#plt.colorbar(im)
ax.set_yscale('log')  # y軸をlogスケールで描く
ax.set_xscale('log')  # x軸をlogスケールで描く
ax.set_xlabel(r"n",fontsize=20)
ax.set_ylabel(r"T",fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
#ax.set_aspect ('equal')


#plt.yscale('log')
#plt.xscale('log')
#plt.plot(t) 
#plt.show()
