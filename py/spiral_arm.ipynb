# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#used packages

def derivative(f,a,h):
    return(f(a+h)-f(a-h))/(2*h)

import numpy as np
import matplotlib.pyplot as plt
import pylab

h = 1e-10


p=-1.0
A=1.0
k=-1.0
m=2.0

#x = np.arange(1, 5 , 0.1)
#y = np.arange(5, 1 ,-0.1)
r1  = np.linspace(2, 5.0, 1)
p1 = np.linspace(0.0, 2.0*np.pi, 35)
R, P = np.meshgrid(r1, p1)
X, Y = R*np.cos(P), R*np.sin(P)

r2  = np.linspace(1, 5.0, 100)
p2 = np.linspace(0.0, 2.0*np.pi, 100)
R2, P2 = np.meshgrid(r2, p2)
X2, Y2 = R2*np.cos(P2), R2*np.sin(P2)

#Z = R*np.cos(P)


#X, Y =pylab.meshgrid(x, y) 
r = R#np.sqrt(X*X+Y*Y)
phi = P#np.arccos(X/r)
S = A* r **p  
f=k*r
S_drv = p*S/r 
f_drv  = 1.0*f/r

gphi=m*(-S/r*np.sin(m*(phi-f)))
gphi0=gphi*0
#gr    = (p*S/r *np.cos(m*(phi-f))+m*S*k*np.sin(m*(phi-f) ))
gr    = (S_drv *np.cos(m*(phi-f))+m*f_drv*S*np.sin(m*(phi-f) ))
gr0=gr*0
Z    = gphi*gr

r2 = R2#np.sqrt(X*X+Y*Y)
phi2 = P2#np.arccos(X/r)
S2 = A* r2 **p  
f2=k*r2
S_drv2 = p*S2/r2 
f_drv2  = 1.0*f2/r2
Phi_g=S2*np.cos(m*(phi2-f2))
grgphi_sc=S_drv2 *m*(-S2/r2)*(np.sin(2.0*m*(phi2-f2)) + np.sin(0.0))#(np.cos(m*(phi-f))*np.sin(m*(phi-f)))
grgphi_ss=m*f_drv2*S2 *m*(-S2/r2)*(np.cos(2.0*m*(phi2-f2)) + np.cos(0.0))
                        

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

#im=plt.imshow(Z,extent=(-1,1,-1,1))
#plt.pcolormesh(X,Y,Z,cmap='bwr', vmin=-1.0, vmax=1.0) #等高線図の生成。cmapで色付けの規則を指定する
#plt.pcolormesh(X2,Y2,Phi_g,cmap='bwr', vmin=-1.0, vmax=1.0) 
plt.pcolormesh(X2,Y2,grgphi_ss,cmap='bwr', vmin=-1.0, vmax=1.0) 
plt.colorbar(orientation="vertical")#カラーバーの表示
plt.quiver(X, Y, gr0 , gphi) # 矢印プロット
plt.quiver(X, Y, gr , gphi0) # 矢印プロット
#plt.quiver(X, Y, gr , gphi, color='green')

#plt.colorbar(im)
ax.set_xlabel(r"x",fontsize=20)
ax.set_ylabel(r"y",fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.set_aspect ('equal')

plt.show()
# Out:
# /var/folders/kw/hmy8d3gn14j8321d_1qs3ry40000gn/T/ipykernel_24699/509445408.py:67: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(X2,Y2,grgphi_ss,cmap='bwr', vmin=-1.0, vmax=1.0)

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#used packages

def derivative(f,a,h):
    return(f(a+h)-f(a-h))/(2*h)

import numpy as np
import matplotlib.pyplot as plt
import pylab

h = 1e-10


p=-1.0
A=1.0
k=-1.0
m=1.0

#x = np.arange(1, 5 , 0.1)
#y = np.arange(5, 1 ,-0.1)
r1  = np.linspace(2, 5.0, 1)
p1 = np.linspace(0.0, 2.0*np.pi, 35)
R, P = np.meshgrid(r1, p1)
X, Y = R*np.cos(P), R*np.sin(P)

r2  = np.linspace(1, 5.0, 100)
p2 = np.linspace(0.0, 2.0*np.pi, 100)
R2, P2 = np.meshgrid(r2, p2)
X2, Y2 = R2*np.cos(P2), R2*np.sin(P2)

#Z = R*np.cos(P)


#X, Y =pylab.meshgrid(x, y) 
r = R#np.sqrt(X*X+Y*Y)
phi = P#np.arccos(X/r)
S = A  
f=k*r
S_drv =  0.0
f_drv  = 1.0*f/r

gphi=m*(-S/r*np.sin(m*(phi-f)))
gphi0=gphi*0
#gr    = (p*S/r *np.cos(m*(phi-f))+m*S*k*np.sin(m*(phi-f) ))
gr    = (S_drv *np.cos(m*(phi-f))+m*f_drv*S*np.sin(m*(phi-f) ))
gr0=gr*0
Z    = gphi*gr

r2 = R2#np.sqrt(X*X+Y*Y)
phi2 = P2#np.arccos(X/r)
S2 = A
f2=k*r2
S_drv2 = 0.0
f_drv2  = 1.0*f2/r2
Phi_g=S2*np.cos(m*(phi2-f2))
grgphi_sc=S_drv2 *m*(-S2/r2)*(np.sin(2.0*m*(phi2-f2)) + np.sin(0.0))#(np.cos(m*(phi-f))*np.sin(m*(phi-f)))
grgphi_ss=m*f_drv2*S2 *m*(-S2/r2)*(np.cos(2.0*m*(phi2-f2)) + np.cos(0.0))
#grgphi_ss_1=m*f_drv2*S2 *m*(-S2/r2)*(np.cos(2.0*m*(phi2-f2)) )
#grgphi_ss_2=m*f_drv2*S2 *m*(-S2/r2)*(np.cos(0.0))

                        

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

#im=plt.imshow(Z,extent=(-1,1,-1,1))
#plt.pcolormesh(X,Y,Z,cmap='bwr', vmin=-1.0, vmax=1.0) #等高線図の生成。cmapで色付けの規則を指定する
plt.pcolormesh(X2,Y2,Phi_g,cmap='bwr', vmin=-1.0, vmax=1.0) 
#plt.pcolormesh(X2,Y2,grgphi_ss,cmap='bwr', vmin=-1.0, vmax=1.0) 
plt.colorbar(orientation="vertical")#カラーバーの表示
#plt.quiver(X, Y, gr0 , gphi) # 矢印プロット
plt.quiver(X, Y, gr*np.cos(phi) , gr*np.sin(phi)) # 矢印プロット
plt.quiver(X, Y, -gphi*np.sin(phi) , gphi*np.cos(phi)) # 矢印プロット
#plt.quiver(X, Y, gr , gphi, color='green')

#plt.colorbar(im)
ax.set_xlabel(r"x",fontsize=20)
ax.set_ylabel(r"y",fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.set_aspect ('equal')



plt.show()
# Out:
# /var/folders/kw/hmy8d3gn14j8321d_1qs3ry40000gn/T/ipykernel_29110/4031705136.py:69: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(X2,Y2,Phi_g,cmap='bwr', vmin=-1.0, vmax=1.0)

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#used packages

def derivative(f,a,h):
    return(f(a+h)-f(a-h))/(2*h)

import numpy as np
import matplotlib.pyplot as plt
import pylab

h = 1e-10


p=-1.0
A=1.0
k=-1.0
m=1.0

#x = np.arange(1, 5 , 0.1)
#y = np.arange(5, 1 ,-0.1)
r1  = np.linspace(2, 5.0, 1)
p1 = np.linspace(0.0, 2.0*np.pi, 35)
R, P = np.meshgrid(r1, p1)
X, Y = R*np.cos(P), R*np.sin(P)

r2  = np.linspace(1, 5.0, 100)
p2 = np.linspace(0.0, 2.0*np.pi, 100)
R2, P2 = np.meshgrid(r2, p2)
X2, Y2 = R2*np.cos(P2), R2*np.sin(P2)

#Z = R*np.cos(P)


#X, Y =pylab.meshgrid(x, y) 
r = R#np.sqrt(X*X+Y*Y)
phi = P#np.arccos(X/r)
S = A  
f=k*r
S_drv =  0.0
f_drv  = 1.0*f/r

gphi=m*(-S/r*np.sin(m*(phi-f)))
gphi0=gphi*0
#gr    = (p*S/r *np.cos(m*(phi-f))+m*S*k*np.sin(m*(phi-f) ))
gr    = (S_drv *np.cos(m*(phi-f))+m*f_drv*S*np.sin(m*(phi-f) ))
gr0=gr*0
Z    = gphi*gr

r2 = R2#np.sqrt(X*X+Y*Y)
phi2 = P2#np.arccos(X/r)
S2 = A
f2=k*r2
S_drv2 = 0.0
f_drv2  = 1.0*f2/r2
Phi_g=S2*np.cos(m*(phi2-f2))
gphi2=m*(-S2/r2*np.sin(m*(phi2-f2)))
gr2    = (S_drv2 *np.cos(m*(phi2-f2))+m*f_drv2*S2*np.sin(m*(phi2-f2) ))
grgphi_sc=S_drv2 *m*(-S2/r2)*(np.sin(2.0*m*(phi2-f2)) + np.sin(0.0))#(np.cos(m*(phi-f))*np.sin(m*(phi-f)))
grgphi_ss=m*f_drv2*S2 *m*(-S2/r2)*(np.cos(2.0*m*(phi2-f2)) + np.cos(0.0))
#grgphi_ss_1=m*f_drv2*S2 *m*(-S2/r2)*(np.cos(2.0*m*(phi2-f2)) )
#grgphi_ss_2=m*f_drv2*S2 *m*(-S2/r2)*(np.cos(0.0))

                        

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
#ax2 = fig.add_subplot(212)


#im=plt.imshow(Z,extent=(-1,1,-1,1))
#plt.pcolormesh(X,Y,Z,cmap='bwr', vmin=-1.0, vmax=1.0) #等高線図の生成。cmapで色付けの規則を指定する
plt.pcolormesh(X2,Y2,gr2*gphi2,cmap='bwr', vmin=-1.0, vmax=1.0) 
#plt.pcolormesh(X2,Y2,grgphi_ss,cmap='bwr', vmin=-1.0, vmax=1.0) 
plt.colorbar(orientation="vertical")#カラーバーの表示
#plt.quiver(X, Y, gr0 , gphi) # 矢印プロット
plt.quiver(X, Y, gr*np.cos(phi) , gr*np.sin(phi)) # 矢印プロット
plt.quiver(X, Y, -gphi*np.sin(phi) , gphi*np.cos(phi)) # 矢印プロット
#plt.quiver(X, Y, gr , gphi, color='green')

#plt.colorbar(im)
ax.set_xlabel(r"x",fontsize=20)
ax.set_ylabel(r"y",fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.set_aspect ('equal')



plt.show()
# Out:
# /var/folders/kw/hmy8d3gn14j8321d_1qs3ry40000gn/T/ipykernel_29110/4082700933.py:73: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(X2,Y2,gr2*gphi2,cmap='bwr', vmin=-1.0, vmax=1.0)

# %%
def derivative(f,a,h):
    return(f(a+h)-f(a-h))/(2*h)

import numpy as np
import matplotlib.pyplot as plt
import pylab

Sigma1=1.0 #function of r

h = 1e-10
p=-1.0
A=1.0
m=2.0
r = np.arange(1.0, 10.0, 0.1)
m=1.0
phi2=1.0*np.pi
k=-1.0
f2=k*r
S2 = A
phi_g= S2*np.cos(m*(phi2-f2))
#phi_phi=derivative(S2*np.cos(m*(phi2-k*r)),phi2,h)
#rho=-m*k*m*k*phi_g-m*m*phi_g

#Sigma2 = Sigma1*np.cos(m*(phi2))


fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
plt.plot(r, phi_g)
ax.set_xlabel(r"x",fontsize=20)
ax.set_ylabel(r"y",fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)
#ax.set_aspect ('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# 1個の点電荷がつくる電場
def Ex(x, y):
    return x/np.sqrt(x**2 + y**2)**3
def Ey(x, y):
    return y/np.sqrt(x**2 + y**2)**3

# 正負の2個の点電荷がつくる電場
def E2x(x, y):
    return Ex(x, y-1) - Ex(x, y+1)
def E2y(x, y):
    return Ey(x, y-1) - Ey(x, y+1)

# 正負の2個の点電荷がつくる電場の大きさ
def E(x, y):
    return np.sqrt(E2x(x, y)**2 + E2y(x, y)**2)

# 規格化された電場ベクトル
def hE2x(x, y):
    return E2x(x, y)/E(x, y)
def hE2y(x, y):
    return E2y(x, y)/E(x, y)
