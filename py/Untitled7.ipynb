# %%
from sympy import *
from sympy.abc import *
from sympy import I, pi, E
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.animation as animation
from matplotlib.animation import ArtistAnimation
from PIL import Image

# %%
Va=1.25
Cs=1.0
theta = np.linspace(0, 2*np.pi, 500)

xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
            
xf2=-np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
xs2=-np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)

xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)

plt.xlim(-1.5,1.5) 
plt.ylim(-1.5,1.5) 

#fig = plt.figure()
#ax = fig.add_subplot(111)
#ax.set_aspect('equal', adjustable='box')
plt.axes().set_aspect('equal', 'datalim')

plt.plot(xs1n, ys1n, '+');
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
plt.style.use("ggplot")



x = np.linspace(-3,3,100)
x2 = np.linspace(0,3,100)
f_y1 = np.exp(x)
f_y2 = np.log(x2)

plt.figure(figsize=(5,5))
g = plt.subplot()
g.plot(x,f_y1, color="red")
g.plot(x2,f_y2, color="blue")
g.set_ylim([-3,3])
g.set_xlim([-3,3])
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in log
# (-3, 3)

# %%
plt.style.use("ggplot")

Va=1.0
Cs=1.0
theta = np.linspace(0, 2*np.pi, 500)
theta1=0.4*np.pi

xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

xf1p=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
xs1p=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
            
#xf2=-np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
#xs2=-np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

yf1p= - (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xf1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))
ys1p= + (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xs1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))

xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)

xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)

xf1np=xf1p*np.cos(theta1)-yf1p*np.sin(theta1)
yf1np=xf1p*np.sin(theta1)+yf1p*np.cos(theta1)

xs1np=xs1p*np.cos(theta1)-ys1p*np.sin(theta1)
ys1np=xs1p*np.sin(theta1)+ys1p*np.cos(theta1)



plt.figure(figsize=(5,5))
g = plt.subplot()
g.plot(xs1n, ys1n, '+')
g.plot(xf1n, yf1n, '+', color="blue")
g.plot(xs1np, ys1np, '+', color="green")
g.plot(xf1np, yf1np, '+', color="black")
g.set_ylim([-1.5,1.5])
g.set_xlim([-1.5,1.5])

print(xs1np,ys1np,xf1np,yf1np)
# Out:
# 0.7325833073330399 -0.005413926081804021 0.3264336870419073 1.3626200626680907
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in true_divide
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in true_divide
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in true_divide
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in true_divide

# %%
Va=0.8
Cs=1.0
theta =0.4*np.pi

xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
            
xf2=-np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
xs2=-np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)

xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)

print(xs1n,ys1n)
# Out:
# 0.6460403720401406 -0.004532518921975148

# %%
plt.style.use("ggplot")

Va=1.0
Cs=1.0
theta = np.linspace(0, 2*np.pi, 500)
theta1=0.4*np.pi

xf1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)
xs1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)

yf1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)
ys1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)


plt.figure(figsize=(5,5))
g = plt.subplot()
g.plot(xs1ph, ys1ph, '+')
g.plot(xf1ph, yf1ph, '+', color="blue")
g.set_ylim([-1.5,1.5])
g.set_xlim([-1.5,1.5])
# Out:
# (-1.5, 1.5)

# %%
plt.style.use("ggplot")

vacs=0.99
Cs=1.0
Va=vacs*Cs

theta = np.linspace(0.0, 2.0*np.pi, 500)
theta1=0.499999*np.pi

xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

xf1p=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
xs1p=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
            
#xf2=-np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
#xs2=-np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

yf1p= - (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xf1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))
ys1p= + (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xs1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))

xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)

xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)

xf1np=xf1p*np.cos(theta1)-yf1p*np.sin(theta1)
yf1np=xf1p*np.sin(theta1)+yf1p*np.cos(theta1)

xs1np=xs1p*np.cos(theta1)-ys1p*np.sin(theta1)
ys1np=xs1p*np.sin(theta1)+ys1p*np.cos(theta1)


xf1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)
xs1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)

yf1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)
ys1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)

xf1php=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.cos(theta1)
xs1php=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.cos(theta1)

yf1php= np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.sin(theta1)
ys1php= np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.sin(theta1)

plt.figure(figsize=(5,5))
g = plt.subplot()
g.plot(xs1n, ys1n, '+')
g.plot(xf1n, yf1n, '+', color="blue")
g.plot(xf1ph, yf1ph, '+', color="purple")
g.plot(xs1ph, ys1ph, '+', color="orange")
g.plot(xs1np, +ys1np, 'o', color="green")
#g.plot(xs1np, -ys1np, 'o', color="yellowgreen")
g.plot(xf1np, yf1np, 'o', color="black")
g.plot(xf1php, yf1php, 'o', color="yellow")
g.plot(xs1php, ys1php, 'o', color="gray")

g.set_ylim([-1.5,1.5])
g.set_xlim([-1.5,1.5])

print(xs1np,ys1np,xf1np,yf1np)
# Out:
# 0.7035448930161207 -1.8541316544918598e-12 3.31565487971151e-06 1.4071602609459033

# %%
n=101

image_list = []
theta = np.linspace(0.0, 2.0*np.pi, 500)
theta1=0.1*np.pi


plt.style.use("ggplot")
fig=plt.figure(figsize=(5,5))
g = plt.subplot()
for i in range(0,n):
    
    vacs=0.02*i
    Cs=1.0
    Va=vacs*Cs

    xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
    xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

    xf1p=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
    xs1p=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))

    #xf2=-np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
    #xs2=-np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

    yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
    ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

    yf1p= - (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xf1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))
    ys1p= + (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xs1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))

    xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
    yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)

    xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
    ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)

    xf1np=xf1p*np.cos(theta1)-yf1p*np.sin(theta1)
    yf1np=xf1p*np.sin(theta1)+yf1p*np.cos(theta1)

    xs1np=xs1p*np.cos(theta1)-ys1p*np.sin(theta1)
    ys1np=xs1p*np.sin(theta1)+ys1p*np.cos(theta1)


    xf1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)
    xs1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)

    yf1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)
    ys1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)

    xf1php=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.cos(theta1)
    xs1php=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.cos(theta1)

    yf1php= np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.sin(theta1)
    ys1php= np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.sin(theta1)
    

    #plt.figure(figsize=(5,5))
    g = plt.subplot()
    image1 =g.plot(xs1n, ys1n, '+', color="red")
    image2 =g.plot(xf1n, yf1n, '+', color="blue")
    image3 =g.plot(xf1ph, yf1ph, '+', color="purple")
    image4 =g.plot(xs1ph, ys1ph, '+', color="orange")
    image5 =g.plot(xs1np, +ys1np, 'o', color="green")
    #g.plot(xs1np, -ys1np, 'o', color="yellowgreen")
    image6 =g.plot(xf1np, yf1np, 'o', color="black")
    image7 =g.plot(xf1php, yf1php, 'o', color="yellow")
    image8 =g.plot(xs1php, ys1php, 'o', color="gray")

    g.set_ylim([-2.5,2.5])
    g.set_xlim([-2.5,2.5])
    
    
    image_list.append(image1+image2+image3+image4+image5+image6+image7+image8)
    print(xs1np,ys1np,xf1np,yf1np)
    
    
# アニメーションを作成
ani = ArtistAnimation(fig, image_list, interval=50,repeat_delay=1000)
# gifに保存
#ani.save('/Users/maeda/Desktop/anim.gif', writer='pillow')
ani.save('/Users/maeda/Desktop/mhd_ph_gr.mp4', writer="ffmpeg")
plt.show()
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in double_scalars
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:59: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# nan nan 0.9510565162951535 0.3090169943749474
# 0.02000030907374782 -2.127193453273571e-06 0.9510383480678875 0.30913473560511084
# 0.04000247395118641 -1.7031150269753922e-05 0.9509837874010886 0.3094883932555131
# ...

# %%
xfm1= np.linspace(0.0, 21, 21)
xfm1
# Out:
# array([ 0.  ,  1.05,  2.1 ,  3.15,  4.2 ,  5.25,  6.3 ,  7.35,  8.4 ,
#         9.45, 10.5 , 11.55, 12.6 , 13.65, 14.7 , 15.75, 16.8 , 17.85,
#        18.9 , 19.95, 21.  ])

# %%
n=101

image_list = []
theta = np.linspace(0.0, 2.0*np.pi, 500)
theta1=0.499999*np.pi

plt.style.use("ggplot")
fig=plt.figure(figsize=(5,5))
g = plt.subplot()
for i in range(0,n):
    
    vacs=0.02*i
    Cs=1.0
    Va=vacs*Cs

    xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
    xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

    xf1p=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
    xs1p=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))

    #xf2=-np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
    #xs2=-np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

    yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
    ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

    yf1p= - (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xf1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))
    ys1p= + (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xs1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))

    xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
    yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)

    xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
    ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)

    xf1np=xf1p*np.cos(theta1)-yf1p*np.sin(theta1)
    yf1np=xf1p*np.sin(theta1)+yf1p*np.cos(theta1)

    xs1np=xs1p*np.cos(theta1)-ys1p*np.sin(theta1)
    ys1np=xs1p*np.sin(theta1)+ys1p*np.cos(theta1)

    

    #plt.figure(figsize=(5,5))
    g = plt.subplot()
    image1 =g.plot(xs1n, ys1n, '+', color="red")
    image2 =g.plot(xf1n, yf1n, '+', color="blue")

    g.set_ylim([-1.5,1.5])
    g.set_xlim([-1.5,1.5])
    
    
    image_list.append(image1+image2)
    print(xs1np,ys1np,xf1np,yf1np)
    
    
# アニメーションを作成
ani = ArtistAnimation(fig, image_list, interval=50,repeat_delay=1000)
# gifに保存
#ani.save('/Users/maeda/Desktop/anim.gif', writer='pillow')
ani.save('/Users/maeda/Desktop/mhd_gr.mp4', writer="ffmpeg")
plt.show()
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in double_scalars
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:46: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
n=101
vacs=1.25

image_list = []

plt.style.use("ggplot")
fig=plt.figure(figsize=(5,5))
g = plt.subplot()
for i in range(0,n):
    
    theta = np.linspace(0.0, 2.0*np.pi*i/(n-1), n-1)
    Cs=1.0
    Va=vacs*Cs

    xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
    xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

    xf1p=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
    xs1p=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))

    #xf2=-np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
    #xs2=-np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

    yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
    ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

    yf1p= - (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xf1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))
    ys1p= + (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xs1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))

    xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
    yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)

    xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
    ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)

    xf1np=xf1p*np.cos(theta1)-yf1p*np.sin(theta1)
    yf1np=xf1p*np.sin(theta1)+yf1p*np.cos(theta1)

    xs1np=xs1p*np.cos(theta1)-ys1p*np.sin(theta1)
    ys1np=xs1p*np.sin(theta1)+ys1p*np.cos(theta1)

    

    #plt.figure(figsize=(5,5))
    g = plt.subplot()
    image1 =g.plot(xs1n, ys1n, '+', color="red")
    image2 =g.plot(xf1n, yf1n, '+', color="blue")

    g.set_ylim([-1.5,1.5])
    g.set_xlim([-1.5,1.5])
    
    
    image_list.append(image1+image2)
    print(xs1np,ys1np,xf1np,yf1np)
    
    
# アニメーションを作成
ani = ArtistAnimation(fig, image_list, interval=50,repeat_delay=1000)
# gifに保存
#ani.save('/Users/maeda/Desktop/anim.gif', writer='pillow')
ani.save('/Users/maeda/Desktop/mhd_gr_vacs125.mp4', writer="ffmpeg")
plt.show()
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:45: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 1.0181383615918054 -0.2328729039193757 1.1494244202987351 0.754424004519282
# 1.0181383615918054 -0.2328729039193757 1.1494244202987351 0.754424004519282
# 1.0181383615918054 -0.2328729039193757 1.1494244202987351 0.754424004519282
# 1.0181383615918054 -0.2328729039193757 1.1494244202987351 0.754424004519282
# 1.0181383615918054 -0.2328729039193757 1.1494244202987351 0.754424004519282
# 1.0181383615918054 -0.2328729039193757 1.1494244202987351 0.754424004519282
# 1.0181383615918054 -0.2328729039193757 1.1494244202987351 0.754424004519282
# ...

# %%
n=101
vacs=1.25

image_list = []

plt.style.use("ggplot")
fig=plt.figure(figsize=(5,5))
g = plt.subplot()
for i in range(0,n):
    
    theta = np.linspace(0.0, 2.0*np.pi*i/(n-1), n-1)
    Cs=1.0
    Va=vacs*Cs

    xf1=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))
    xs1=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))

    yf1= - (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xf1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))
    ys1= + (-Cs**2.0*Va**2.0*np.sin(theta)*np.cos(theta))/(xs1*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0))

    xf1n=xf1*np.cos(theta)-yf1*np.sin(theta)
    yf1n=xf1*np.sin(theta)+yf1*np.cos(theta)
    xs1n=xs1*np.cos(theta)-ys1*np.sin(theta)
    ys1n=xs1*np.sin(theta)+ys1*np.cos(theta)
    
    xf1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)
    xs1ph=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.cos(theta)
    yf1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)
    ys1ph= np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta)**2.0)))*np.sin(theta)
    
    theta1=2.0*np.pi*i/(n-1)
    xf1p=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
    xs1p=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))
    yf1p= - (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xf1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))
    ys1p= + (-Cs**2.0*Va**2.0*np.sin(theta1)*np.cos(theta1))/(xs1p*np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0))
    xf1np=xf1p*np.cos(theta1)-yf1p*np.sin(theta1)
    yf1np=xf1p*np.sin(theta1)+yf1p*np.cos(theta1)
    xs1np=xs1p*np.cos(theta1)-ys1p*np.sin(theta1)
    ys1np=xs1p*np.sin(theta1)+ys1p*np.cos(theta1)

    xf1php=np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.cos(theta1)
    xs1php=np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.cos(theta1)
    yf1php= np.sqrt(0.5*(Va**2.0+Cs**2.0+np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.sin(theta1)
    ys1php= np.sqrt(0.5*(Va**2.0+Cs**2.0-np.sqrt((Va**2.0+Cs**2.0)**2.0-4.0*Va**2.0*Cs**2.0*np.cos(theta1)**2.0)))*np.sin(theta1)
    
    

    #plt.figure(figsize=(5,5))
    g = plt.subplot()
    image1 =g.plot(xs1n, ys1n, '+', color="red")
    image2 =g.plot(xf1n, yf1n, '+', color="blue")
    image3 =g.plot(xf1ph, yf1ph, '+', color="purple")
    image4 =g.plot(xs1ph, ys1ph, '+', color="orange")
    image6 = plt.plot([0, xf1np], [0, yf1np],color="blue")
    image7 = plt.plot([0, xs1np], [0, ys1np],color="red")
    image8 = plt.plot([0, xf1php], [0, yf1php],color="purple")
    image9 = plt.plot([0, xs1php], [0, ys1php],color="orange")
    image5 = plt.plot([0, 6.0*np.cos(theta1)], [0, 6.0*np.sin(theta1)],color="green")
    

    g.set_ylim([-1.5,1.5])
    g.set_xlim([-1.5,1.5])
    
    
    image_list.append(image1+image2+image3+image4+image6+image7+image8+image9+image5)
    print(xs1np,ys1np,xf1np,yf1np)
    
    
# アニメーションを作成
ani = ArtistAnimation(fig, image_list, interval=50,repeat_delay=1000)
# gifに保存
#ani.save('/Users/maeda/Desktop/anim.gif', writer='pillow')
ani.save('/Users/maeda/Desktop/mhd_ph_gr_vacs125_line.mp4', writer="ffmpeg")
plt.show()
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:49: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in true_divide
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in double_scalars
# 1.0 0.0 1.25 0.0
# 1.0032345519845152 -0.10579078568205809 1.2434226502806045 0.21216884075448
# 1.0103326273536222 -0.1828933283003512 1.22631897380827 0.3951281010918972
# ...
