# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.animation as animation
from matplotlib.animation import ArtistAnimation
from sympy import *
from sympy.codegen.cfunctions import log10
    

#dir = '/Users/maedarn/Dropbox/code/code/Cooling_Kim/'
dir = '/Users/maedarn/Dropbox/analysis/cooling/Kim/'

# %%
i=100+1
j=int(30*(3+32)/2+1)

print( j)

f90 = open(dir+'cool_rate.dat', 'rb')
ary = np.fromfile(f90, np.float32, count=i*j)
uvhpy = ary.reshape(j, i, order='F')

T=uvhpy[0,:]
H1=uvhpy[1,:]
H2=uvhpy[2,:]
H3=uvhpy[3,:]
M1=uvhpy[500,:]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-27), 10**(-18))
#plt.ylim(0.001, 0.1)
#plt.ylim(0.000000, 1.0)
#plt.ylim(0.01, 150)
#plt.xlim(100, 1000000)
ax.set_yscale('log')
ax.set_xscale('log')

#plt.plot(uvhpy[0,:], uvhpy[2,:])
for k in range(1,526):
    plt.plot(uvhpy[0,:], uvhpy[k,:])

#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/cooling_Code_H.pdf')
pp.savefig(fig)
pp.close()
# Out:
# 526

# %%
i=100+1
j=int(30*(3+32)/2+1)

print( j)

#data01,data02 ,data03,data04 = np.loadtxt(dir+'01.dat', unpack=True)
#data01,data02 ,data03,data04,data05 = np.loadtxt(dir+'02.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06   = np.loadtxt(dir+'03.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07= np.loadtxt(dir+'04.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08  = np.loadtxt(dir+'05.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09  = np.loadtxt(dir+'06.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10  = np.loadtxt(dir+'07.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11  = np.loadtxt(dir+'08.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12  = np.loadtxt(dir+'09.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13  = np.loadtxt(dir+'10.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14  = np.loadtxt(dir+'11.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15  = np.loadtxt(dir+'12.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16= np.loadtxt(dir+'13.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17   = np.loadtxt(dir+'14.dat', unpack=True)
data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18   = np.loadtxt(dir+'15.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19  = np.loadtxt(dir+'16.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20 = np.loadtxt(dir+'17.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21  = np.loadtxt(dir+'18.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22   = np.loadtxt(dir+'19.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23 = np.loadtxt(dir+'20.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24  = np.loadtxt(dir+'21.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25   = np.loadtxt(dir+'22.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26  = np.loadtxt(dir+'23.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26,data27  = np.loadtxt(dir+'24.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26,data27,data28   = np.loadtxt(dir+'25.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26,data27,data28,data29  = np.loadtxt(dir+'26.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26,data27,data28,data29,data30   = np.loadtxt(dir+'27.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26,data27,data28,data29,data30,data31  = np.loadtxt(dir+'28.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26,data27,data28,data29,data30,data31,data32   = np.loadtxt(dir+'29.dat', unpack=True)
#data01,data02 ,data03,data04,data05,data06,data07,data08,data09,data10,data11,data12 ,data13,data14,data15,data16,data17,data18,data19,data20,data21,data22 ,data23,data24,data25,data26,data27,data28,data29,data30,data31,data32 ,data33   = np.loadtxt(dir+'30.dat', unpack=True)
ndata01,ndata02   = np.loadtxt(dir+'Mtln15.dat', unpack=True)



fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-27), 10**(-18))
#plt.ylim(0.001, 0.1)
#plt.ylim(0.000000, 1.0)
#plt.ylim(0.01, 150)
#plt.xlim(100, 1000000)
ax.set_yscale('log')
ax.set_xscale('log')

#plt.plot(uvhpy[0,:], uvhpy[2,:])
plt.plot(data01, data18)
plt.plot(ndata01, ndata02,  linestyle="dashdot")
'''
plt.plot(data01, data02)
plt.plot(data01, data03)
plt.plot(data01, data04)
plt.plot(data01, data05)
plt.plot(data01, data06)
plt.plot(data01, data07)
plt.plot(data01, data08)
plt.plot(data01, data09)
plt.plot(data01, data10)
plt.plot(data01, data11)
plt.plot(data01, data12)
plt.plot(data01, data13)
plt.plot(data01, data14)
plt.plot(data01, data15)
plt.plot(data01, data16)
plt.plot(data01, data17)
plt.plot(data01, data18)
plt.plot(data01, data19)
plt.plot(data01, data20)
plt.plot(data01, data21)
plt.plot(data01, data22)
plt.plot(data01, data23)
plt.plot(data01, data24)
plt.plot(data01, data25)
plt.plot(data01, data26)
plt.plot(data01, data27)
plt.plot(data01, data28)
plt.plot(data01, data29)
plt.plot(data01, data30)
plt.plot(data01, data31)
plt.plot(data01, data32)
plt.plot(data01, data33)
'''

print(data01)

#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/cooling_GF_Zn.pdf')
pp.savefig(fig)
pp.close()
# Out:
# 526
# [1.00e+04 1.05e+04 1.10e+04 1.16e+04 1.22e+04 1.28e+04 1.34e+04 1.41e+04
#  1.48e+04 1.55e+04 1.63e+04 1.71e+04 1.80e+04 1.89e+04 1.99e+04 2.09e+04
#  2.20e+04 2.31e+04 2.43e+04 2.56e+04 2.69e+04 2.83e+04 2.98e+04 3.14e+04
#  3.30e+04 3.47e+04 3.65e+04 3.84e+04 4.04e+04 4.26e+04 4.48e+04 4.71e+04
#  4.96e+04 5.22e+04 5.49e+04 5.78e+04 6.08e+04 6.40e+04 6.74e+04 7.09e+04
#  7.46e+04 7.86e+04 8.27e+04 8.70e+04 9.16e+04 9.64e+04 1.02e+05 1.07e+05
#  1.12e+05 1.18e+05 1.24e+05 1.31e+05 1.38e+05 1.45e+05 1.53e+05 1.61e+05
#  1.69e+05 1.78e+05 1.88e+05 1.98e+05 2.08e+05 2.19e+05 2.30e+05 2.42e+05
#  2.55e+05 2.69e+05 2.83e+05 2.98e+05 3.13e+05 3.30e+05 3.47e+05 3.66e+05
#  3.85e+05 4.05e+05 4.26e+05 4.49e+05 4.72e+05 4.97e+05 5.23e+05 5.51e+05
#  5.80e+05 6.10e+05 6.43e+05 6.76e+05 7.12e+05 7.49e+05 7.89e+05 8.30e+05
#  8.74e+05 9.20e+05 9.69e+05 1.02e+06 1.07e+06 1.13e+06 1.19e+06 1.25e+06
#  1.32e+06 1.39e+06 1.46e+06 1.54e+06 1.62e+06 1.70e+06 1.79e+06 1.89e+06
# ...

# %%
d_data=[0] * 200
d_data2=[0] * 200
for i in range(0, 200-1, 1):
    d_data[i]=ndata01[i+1]-ndata01[i]
    d_data2[i]=np.log10(ndata01[i+1])-np.log10(ndata01[i])
    print(ndata01[i+1]-ndata01[i],ndata01[i+1],ndata01[i],d_data2[i])
#print(d_data)
# Out:
# 471.28520000000026 10471.2852 10000.0 0.019999988365944965
# 493.4969999999994 10964.7822 10471.2852 0.020000021083292907
# 516.7538999999997 11481.5361 10964.7822 0.019999986202011932
# 541.108400000001 12022.6445 11481.5361 0.02000000990540851
# 566.6093999999994 12589.2539 12022.6445 0.019999986924956303
# 593.3135000000002 13182.5674 12589.2539 0.02000000799397128
# 621.2754000000004 13803.8428 13182.5674 0.02000000436863214
# 650.5546999999988 14454.3975 13803.8428 0.01999998892249444
# 681.2148000000016 15135.6123 14454.3975 0.020000000943284135
# 713.3192999999992 15848.9316 15135.6123 0.019999996394966857
# 746.9375 16595.8691 15848.9316 0.020000009565596777
# 782.1386999999995 17378.0078 16595.8691 0.01999998714646445
# 819.0 18197.0078 17378.0078 0.019999993421714102
# 857.5996000000014 19054.6074 18197.0078 0.020000023783899756
# 898.0155999999988 19952.623 19054.6074 0.019999991719192423
# 940.3378999999986 20892.9609 19952.623 0.01999999476598635
# ...

# %%
i=189
j=4


f90 = open(dir+'test_cool_rate.dat', 'rb')
ary = np.fromfile(f90, np.float32, count=i*j)
uvhpy = ary.reshape(j, i, order='F')

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.set_yscale('log')
ax.set_xscale('log')

#plt.plot(uvhpy[0,:], uvhpy[2,:])
for k in range(1,4):
    plt.plot(uvhpy[0,:], uvhpy[k,:])

#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/cooling.pdf')
pp.savefig(fig)
pp.close()

# %%
i=100+1
j=5

print( j)

f90 = open(dir+'cool_rate_net.dat', 'rb')
ary = np.fromfile(f90, np.float32, count=i*j)
uvhpy = ary.reshape(j, i, order='F')

T=uvhpy[0,:]
Lmeta=uvhpy[1,:]
LHe=uvhpy[2,:]
Lff=uvhpy[3,:]
Lrr=uvhpy[4,:]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)
#plt.xlim(0.000001, 1.0)
plt.ylim(10**(-28), 10**(-21))
plt.xlim(4*10**(3), 10**(8))
#plt.ylim(0.001, 0.1)
#plt.ylim(0.000000, 1.0)
#plt.ylim(0.01, 150)
#plt.xlim(100, 1000000)
ax.set_yscale('log')
ax.set_xscale('log')

#plt.plot(uvhpy[0,:], uvhpy[2,:])
#plt.plot(T, Lmeta,color='red')
#plt.plot(T, LHe,color='blue')
#plt.plot(T, Lff,color='green')
#plt.plot(T, Lrr,color='magenta')
plt.plot(T, Lmeta+ LHe,color='red',  linestyle="dashdot", linewidth=3)
plt.plot(T, Lff+ Lrr,color='blue', linestyle="dashdot", linewidth=3)
plt.plot(T, Lff+ Lrr+Lmeta+ LHe,color='black', linestyle="dashdot", linewidth=3)

#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/cooling_net.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# 5

# %%
i=100
j=13

print( j)

f90 = open(dir+'chem_abnd.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j)
uvhpy = ary.reshape(j, i, order='F')

#T=uvhpy[0,:]
#H1=uvhpy[1,:]
#H2=uvhpy[2,:]
#H3=uvhpy[3,:]
#M1=uvhpy[4,:]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-27), 10**(-18))
#plt.ylim(0.001, 0.1)
#plt.ylim(0.000000, 1.0)
#plt.ylim(0.0000000001, 10)
#plt.xlim(100, 1000000)
ax.set_yscale('log')
ax.set_xscale('log')

print(uvhpy[0,:])

#plt.plot(uvhpy[0,:], uvhpy[2,:])
for k in range(1,11):
    plt.plot(uvhpy[0,:],uvhpy[k,:])

#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/cooling_Code_H.pdf')
pp.savefig(fig)
pp.close()
# Out:
# 13
# [0.0001 0.0002 0.0003 0.0004 0.0005 0.0006 0.0007 0.0008 0.0009 0.001
#  0.0011 0.0012 0.0013 0.0014 0.0015 0.0016 0.0017 0.0018 0.0019 0.002
#  0.0021 0.0022 0.0023 0.0024 0.0025 0.0026 0.0027 0.0028 0.0029 0.003
#  0.0031 0.0032 0.0033 0.0034 0.0035 0.0036 0.0037 0.0038 0.0039 0.004
#  0.0041 0.0042 0.0043 0.0044 0.0045 0.0046 0.0047 0.0048 0.0049 0.005
#  0.0051 0.0052 0.0053 0.0054 0.0055 0.0056 0.0057 0.0058 0.0059 0.006
#  0.0061 0.0062 0.0063 0.0064 0.0065 0.0066 0.0067 0.0068 0.0069 0.007
#  0.0071 0.0072 0.0073 0.0074 0.0075 0.0076 0.0077 0.0078 0.0079 0.008
#  0.0081 0.0082 0.0083 0.0084 0.0085 0.0086 0.0087 0.0088 0.0089 0.009
#  0.0091 0.0092 0.0093 0.0094 0.0095 0.0096 0.0097 0.0098 0.0099 0.01  ]

# %%
i=100
j=13

print( j)

f90 = open(dir+'chem_abnd.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j)
uvhpy = ary.reshape(j, i, order='F')

T         =uvhpy[0,:]
Tmp    =uvhpy[1,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-27), 10**(-18))
#plt.ylim(0.001, 0.1)
#plt.ylim(0.00001, 1000.0)
#plt.ylim(0.0000000001, 10)
#plt.xlim(100, 1000000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndCOl)

plt.plot(T, ndpl ,color='red')
plt.plot(T, ndHl ,color='blue')
plt.plot(T, ndH2l ,color='green')
plt.plot(T, ndHml ,color='magenta')
plt.plot(T, ndHel ,color='yellow')
plt.plot(T, ndHepl ,color='black')
plt.plot(T, ndCl ,color='brown')
plt.plot(T, ndCpl ,color='orange')
plt.plot(T, ndCOl ,color='cyan')
plt.plot(T, ndel ,color='gray')
plt.plot(T, ndtotl ,color='purple')
#plt.plot(T, ndel ,color='gray')


#for k in range(1,11):
#   plt.plot(uvhpy[0,:],uvhpy[k,:])

#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/cooling_Code_H.pdf')
pp.savefig(fig)
pp.close()
# Out:
# 13
# [8.52231586e-19 1.00084284e-21 1.74608775e-22 6.78201577e-23
#  4.07786315e-23 3.10488836e-23 2.68371977e-23 2.48267145e-23
#  2.38158040e-23 2.32932447e-23 2.30191138e-23 2.28741725e-23
#  2.27972159e-23 2.27562644e-23 2.27344467e-23 2.27228154e-23
#  2.27166125e-23 2.27133039e-23 2.27115390e-23 2.27105975e-23
#  2.27100952e-23 2.27098273e-23 2.27096843e-23 2.27096080e-23
#  2.27095673e-23 2.27095456e-23 2.27095341e-23 2.27095279e-23
#  2.27095246e-23 2.27095228e-23 2.27095218e-23 2.27095212e-23
#  2.27095211e-23 2.27095210e-23 2.27095209e-23 2.27095208e-23
#  2.27095208e-23 2.27095208e-23 2.27095208e-23 2.27095208e-23
#  2.27095208e-23 2.27095208e-23 2.27095208e-23 2.27095208e-23
#  2.27095207e-23 2.27095207e-23 2.27095208e-23 2.27095208e-23
#  2.27095208e-23 2.27095208e-23 2.27095207e-23 2.27095208e-23
#  2.27095208e-23 2.27095208e-23 2.27095208e-23 2.27095208e-23
#  2.27095208e-23 2.27095208e-23 2.27095208e-23 2.27095208e-23
# ...

# %%
i=31
j=29
ni=21

print( j)

#f90 = open(dir+'thermal_eq_curve_md_lmt.dat', 'rb')
#f90 = open(dir+'Thermal_optthick_Z10m0_md2.dat', 'rb')
f90 = open(dir+'Thermal_bialyi_Z10m1_md_mid.dat', 'rb')
nf90 = open(dir+'Thermal_bialy_Z10m3_md_mid.dat', 'rb')
of90 = open(dir+'Thermal_bialy_Z10m3_md_hot.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j)
uvhpy = ary.reshape(j, i, order='F')
nary = np.fromfile(nf90, np.float64, count=ni*j)
nuvhpy = nary.reshape(j, ni, order='F')
oary = np.fromfile(of90, np.float64, count=ni*j)
ouvhpy = oary.reshape(j, ni, order='F')

T         =uvhpy[1,:]
Rho    =uvhpy[0,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]
Lamll =uvhpy[13,:]
Lamcl =uvhpy[14,:]
Lamol =uvhpy[15,:]
Lamdl =uvhpy[16,:]
LCOrl =uvhpy[17,:]
LCOHl =uvhpy[18,:]
LCOH2l =uvhpy[19,:]
LamH2l =uvhpy[20,:]
Lffl =uvhpy[21,:]
Lrrl =uvhpy[22,:]
LCIEl =uvhpy[23,:]
LCIEHel =uvhpy[24,:]
Gampel =uvhpy[25,:]
Gamcrl   =uvhpy[26,:]
Gampdl =uvhpy[27,:]

nT         =nuvhpy[1,:]
nndtotl =nuvhpy[12,:]
nRho =nuvhpy[0,:]

oT         =ouvhpy[1,:]
ondtotl =ouvhpy[12,:]
oRho =ouvhpy[0,:]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-28), 10**(-25))
#plt.ylim(0.001, 0.1)
plt.ylim(300, 50000000.0)
#plt.ylim(1, 500000)
plt.xlim(0.01, 100000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndtotl)

plt.plot(ndtotl, ndtotl*T*1000.0 ,color='green',linestyle='solid')
#plt.plot(nndtotl, nndtotl*nT*1000.0 ,color='green',linestyle='solid')
#plt.plot(ondtotl, ondtotl*oT*1000.0 ,color='green',linestyle='solid')
#plt.plot(Rho/1.27, Rho/1.27*T*1000.0 ,color='green',linestyle='solid')
#plt.plot(nRho/1.27, nRho/1.27*nT*1000.0 ,color='green',linestyle='solid')
#plt.plot(oRho/1.27, oRho/1.27*oT*1000.0 ,color='green',linestyle='solid')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red',linestyle='dashed')
#plt.plot(ndtotl, T*1000.0 ,color='red')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red')
#plt.plot(Rho/1.27, Lamll/1.9733e27/(Rho/1.27) ,color='red')
#plt.plot(Rho/1.27, Lamcl/1.9733e27/(Rho/1.27),color='green')
#plt.plot(Rho/1.27, Lamol/1.9733e27/(Rho/1.27),color='blue')
#plt.plot(Rho/1.27, Lamdl/1.9733e27 /(Rho/1.27),color='purple')
#plt.plot(Rho/1.27, Gampel /1.9733e27 /(Rho/1.27),color='yellow')
#plt.plot(Rho/1.27, Gamcrl /1.9733e27/(Rho/1.27),color='gray')
#plt.plot(Rho/1.27, Gampdl /1.9733e27 /(Rho/1.27),color='magenta')

#plt.plot(ndtotl, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(ndtotl, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(ndtotl, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(ndtotl, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(ndtotl, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(ndtotl, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(ndtotl, Gampdl /1.9733e27 /(ndtotl),color='magenta')
#plt.plot(ndtotl, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
#plt.plot(ndtotl, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl)/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl)/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl)/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl)/(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl)/(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl)/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl)/(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl)/(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl)/(ndtotl),color='brown')

#for k in range(1,11):
#plt.plot(uvhpy[0,:],uvhpy[k,:])
#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Cooling_Code_Hot.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# 29
# [6.05747368e-02 7.98530550e-02 1.05266828e-01 1.38768705e-01
#  1.82932781e-01 2.41152371e-01 3.17900737e-01 4.19074789e-01
#  5.52448165e-01 7.28268516e-01 9.60044879e-01 1.26558563e+00
#  1.66836679e+00 2.19933576e+00 2.89928919e+00 3.82200751e+00
#  5.03838715e+00 6.64188781e+00 8.75571337e+00 1.15422781e+01
#  1.52156859e+01 2.00581805e+01 2.64418316e+01 3.48571227e+01
#  4.59506369e+01 6.05747368e+01 7.98530550e+01 1.05266828e+02
#  1.38768705e+02 1.82932781e+02 2.41152371e+02]

# %%
i=31
j=28

i1=51

print( j)

f90 = open(dir+'thermal_eq_curve_md_hot2.dat', 'rb')
f91 = open(dir+'thermal_eq_curve_md2.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j)
uvhpy = ary.reshape(j, i, order='F')
ary1 = np.fromfile(f91, np.float64, count=i1*j)
uvhpy1 = ary1.reshape(j, i1, order='F')

T         =uvhpy[1,:]
Rho    =uvhpy[0,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]
Lamll =uvhpy[13,:]
Lamcl =uvhpy[14,:]
Lamol =uvhpy[15,:]
Lamdl =uvhpy[16,:]
LCOrl =uvhpy[17,:]
LCOHl =uvhpy[18,:]
LCOH2l =uvhpy[19,:]
LamH2l =uvhpy[20,:]
Lffl =uvhpy[21,:]
Lrrl =uvhpy[22,:]
LCIEl =uvhpy[23,:]
LCIEHel =uvhpy[24,:]
Gampel =uvhpy[25,:]
Gamcrl   =uvhpy[26,:]
Gampdl =uvhpy[27,:]

T1         =uvhpy1[1,:]
Rho1    =uvhpy1[0,:]
ndtotl1 =uvhpy1[12,:]
Lamll1 =uvhpy1[13,:]
Lamcl1 =uvhpy1[14,:]
Lamol1 =uvhpy1[15,:]
Lamdl1 =uvhpy1[16,:]
LCOrl1 =uvhpy1[17,:]
LCOHl1 =uvhpy1[18,:]
LCOH2l1 =uvhpy1[19,:]
LamH2l1 =uvhpy1[20,:]
Lffl1 =uvhpy1[21,:]
Lrrl1 =uvhpy1[22,:]
LCIEl1 =uvhpy1[23,:]
LCIEHel1 =uvhpy1[24,:]
Gampel1 =uvhpy1[25,:]
Gamcrl1   =uvhpy1[26,:]
Gampdl1 =uvhpy1[27,:]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-29), 5*10**(-25))
#plt.ylim(0.001, 0.1)
#plt.ylim(0.00001, 1000.0)
#plt.ylim(1, 500000)
plt.xlim(0.001, 1000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndCOl)

#plt.plot(ndtotl, T*1000.0 ,color='red')
#plt.plot(ndtotl1, T1*1000.0 ,color='red')
#plt.plot(ndtotl, T*1000.0 ,color='red')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red')
#plt.plot(Rho/1.27, Lamll/1.9733e27/(Rho/1.27) ,color='red')
#plt.plot(Rho/1.27, Lamcl/1.9733e27/(Rho/1.27),color='green')
#plt.plot(Rho/1.27, Lamol/1.9733e27/(Rho/1.27),color='blue')
#plt.plot(Rho/1.27, Lamdl/1.9733e27 /(Rho/1.27),color='purple')
#plt.plot(Rho/1.27, Gampel /1.9733e27 /(Rho/1.27),color='yellow')
#plt.plot(Rho/1.27, Gamcrl /1.9733e27/(Rho/1.27),color='gray')
#plt.plot(Rho/1.27, Gampdl /1.9733e27 /(Rho/1.27),color='magenta')

#plt.plot(ndtotl, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(ndtotl, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(ndtotl, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(ndtotl, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(ndtotl, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(ndtotl, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(ndtotl, Gampdl /1.9733e27 /(ndtotl),color='magenta')

plt.plot(ndtotl, Lamll/1.9733e27/(ndtotl) ,color='red')
plt.plot(ndtotl, Lamcl/1.9733e27/(ndtotl),color='green')
plt.plot(ndtotl, Lamol/1.9733e27/(ndtotl),color='blue')
plt.plot(ndtotl, Lamdl/1.9733e27 /(ndtotl),color='purple')
plt.plot(ndtotl, LamH2l/1.9733e27 /(ndtotl),color='orange')
plt.plot(ndtotl, Gampel /1.9733e27 /(ndtotl),color='yellow')
plt.plot(ndtotl, Gamcrl /1.9733e27/(ndtotl),color='gray')
plt.plot(ndtotl, Gampdl /1.9733e27 /(ndtotl),color='magenta')
plt.plot(ndtotl, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
plt.plot(ndtotl, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

plt.plot(ndtotl1, Lamll1/1.9733e27/(ndtotl1) ,color='red')
plt.plot(ndtotl1, Lamcl1/1.9733e27/(ndtotl1),color='green')
plt.plot(ndtotl1, Lamol1/1.9733e27/(ndtotl1),color='blue')
plt.plot(ndtotl1, Lamdl1/1.9733e27 /(ndtotl1),color='purple')
plt.plot(ndtotl1, LamH2l1/1.9733e27 /(ndtotl1),color='orange')
plt.plot(ndtotl1, Gampel1 /1.9733e27 /(ndtotl1),color='yellow')
plt.plot(ndtotl1, Gamcrl1 /1.9733e27/(ndtotl1),color='gray')
plt.plot(ndtotl1, Gampdl1 /1.9733e27 /(ndtotl1),color='magenta')
plt.plot(ndtotl1, (Lffl1+Lrrl1) /1.9733e27 /(ndtotl1),color='black')
plt.plot(ndtotl1, (LCIEl1+LCIEHel1 )/1.9733e27 /(ndtotl1),color='brown')

#for k in range(1,11):
#plt.plot(uvhpy[0,:],uvhpy[k,:])
#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Cooling_Code_Hot.pdf')
pp.savefig(fig,transparent=True)
pp.close()

# %%
i=101
j=33

print( j)

f90 = open(dir+'thermal_eq_curve_l_rho3.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j)
uvhpy = ary.reshape(j, i, order='F')

T         =uvhpy[1,:]
Rho    =uvhpy[0,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]
Lamll =uvhpy[13,:]
Lamcl =uvhpy[14,:]
Lamol =uvhpy[15,:]
Lamdl =uvhpy[16,:]
LCOrl =uvhpy[17,:]
LCOHl =uvhpy[18,:]
LCOH2l =uvhpy[19,:]
LamH2l =uvhpy[20,:]
Lffl =uvhpy[21,:]
Lrrl =uvhpy[22,:]
LCIEl =uvhpy[23,:]
LCIEHel =uvhpy[24,:]
Gampel =uvhpy[25,:]
Gamcrl   =uvhpy[26,:]
Gampdl =uvhpy[27,:]
Lneb =uvhpy[28,:]
ndHtot =uvhpy[29,:]
testLya1 =uvhpy[30,:]
testLya2 =uvhpy[31,:]
testLya3 =uvhpy[32,:]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
plt.ylim(10**(-28), 10**(-21))
#plt.ylim(0.001, 0.1)
plt.xlim(4000, 100000000)
#plt.ylim(1, 500000)
#plt.xlim(0.1, 10000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndCOl)

plt.plot(T*1000.0, Lamll/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl ,color='turquoise')
plt.plot(T*1000.0, (Lamcl+Lamol+Lneb+Lamdl)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='goldenrod')
#plt.plot(T*1000.0, Lamol/1.9733e27 ,color='green')
#plt.plot(T*1000.0, Lneb/1.9733e27 ,color='purple')
plt.plot(T*1000.0, (Lffl+Lrrl)/1.9733e27 /ndHtot/ndHtot* ndtotl *ndtotl ,color='dodgerblue')
plt.plot(T*1000.0, (LCIEl+LCIEHel)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='red')
#plt.plot(T*1000.0, (LCIEHel)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='black')
plt.plot(T*1000.0, (testLya1)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='turquoise', linestyle = "dashdot")
plt.plot(T*1000.0, (testLya2)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='turquoise', linestyle = "dashed")
plt.plot(T*1000.0, (testLya3)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='turquoise', linestyle = "dotted")
plt.plot(T*1000.0, (Lamcl)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='olive', linestyle = "solid")
plt.plot(T*1000.0, (Lamol)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='purple', linestyle = "solid")
plt.plot(T*1000.0, (Lneb)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='brown', linestyle = "solid")
plt.plot(T*1000.0, (Lamdl)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='magenta', linestyle = "solid")
plt.plot(T*1000.0, (LCIEl+LCIEHel+Lffl+Lrrl+Lamcl+Lamol+Lneb+Lamdl+Lamll)/1.9733e27/ndHtot/ndHtot* ndtotl *ndtotl  ,color='black')
#plt.plot(ndtotl, T*1000.0 ,color='red')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red')
#plt.plot(Rho/1.27, Lamll/1.9733e27/(Rho/1.27) ,color='red')
#plt.plot(Rho/1.27, Lamcl/1.9733e27/(Rho/1.27),color='green')
#plt.plot(Rho/1.27, Lamol/1.9733e27/(Rho/1.27),color='blue')
#plt.plot(Rho/1.27, Lamdl/1.9733e27 /(Rho/1.27),color='purple')
#plt.plot(Rho/1.27, Gampel /1.9733e27 /(Rho/1.27),color='yellow')
#plt.plot(Rho/1.27, Gamcrl /1.9733e27/(Rho/1.27),color='gray')
#plt.plot(Rho/1.27, Gampdl /1.9733e27 /(Rho/1.27),color='magenta')

#plt.plot(ndtotl, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(ndtotl, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(ndtotl, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(ndtotl, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(ndtotl, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(ndtotl, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(ndtotl, Gampdl /1.9733e27 /(ndtotl),color='magenta')
#plt.plot(ndtotl, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
#plt.plot(ndtotl, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl)/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl)/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl)/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl)/(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl)/(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl)/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl)/(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl)/(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl)/(ndtotl),color='brown')

#for k in range(1,11):
#plt.plot(uvhpy[0,:],uvhpy[k,:])
#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Cooling_Code_Hot.pdf')
pp.savefig(fig,transparent=True)
pp.close()

# %%
i=101
j=29

print( j)

f90 = open(dir+'thermal_eq_curve_l_rho1.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j)
uvhpy = ary.reshape(j, i, order='F')

T         =uvhpy[1,:]
Rho    =uvhpy[0,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]
Lamll =uvhpy[13,:]
Lamcl =uvhpy[14,:]
Lamol =uvhpy[15,:]
Lamdl =uvhpy[16,:]
LCOrl =uvhpy[17,:]
LCOHl =uvhpy[18,:]
LCOH2l =uvhpy[19,:]
LamH2l =uvhpy[20,:]
Lffl =uvhpy[21,:]
Lrrl =uvhpy[22,:]
LCIEl =uvhpy[23,:]
LCIEHel =uvhpy[24,:]
Gampel =uvhpy[25,:]
Gamcrl   =uvhpy[26,:]
Gampdl =uvhpy[27,:]
Lneb =uvhpy[28,:]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
plt.ylim(10**(-4), 10**(1))
#plt.ylim(0.001, 0.1)
#plt.ylim(1000, 500000.0)
#plt.ylim(1, 500000)
#plt.xlim(0.1, 10000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndHl  )

plt.plot(T*1000.0, ndel /ndtotl  ,color='blue')
plt.plot(T*1000.0, ndHl /ndtotl  ,color='red')
plt.plot(T*1000.0, ndpl /ndtotl  ,color='green')
plt.plot(T*1000.0, ndH2l/ndtotl  ,color='black')
plt.plot(T*1000.0, ndHel/ndtotl  ,color='purple')
plt.plot(T*1000.0, ndHepl/ndtotl  ,color='magenta')
plt.plot(T*1000.0, ndHml/ndtotl  ,color='brown')





plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Cooling_Code_xn.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# 29
# [8.99436491e-001 8.99001236e-001 8.98544954e-001 8.98066364e-001
#  8.97564082e-001 8.97036609e-001 8.96482322e-001 8.95899455e-001
#  8.95286088e-001 8.94640124e-001 8.93959268e-001 8.93241006e-001
#  8.92482570e-001 8.91680912e-001 8.90832656e-001 8.89934056e-001
#  8.88980874e-001 8.87967317e-001 8.86874217e-001 8.85564895e-001
#  8.83053041e-001 8.72715729e-001 8.12663402e-001 6.02968671e-001
#  3.43459476e-001 1.33876016e-001 4.75100701e-002 1.73742150e-002
#  6.76990517e-003 2.80458009e-003 1.21633002e-003 5.40623294e-004
#  2.39566597e-004 1.02041557e-004 3.98249778e-005 1.34043889e-005
#  3.62695906e-006 7.35572514e-007 1.05518741e-007 1.02771319e-008
#  6.61563264e-010 2.76670482e-011 7.44254978e-013 1.28251173e-014
#  1.41642751e-016 1.00640338e-018 4.62730223e-021 1.38598769e-023
#  2.72190623e-026 3.52373427e-029 3.01790695e-032 1.71209708e-035
#  6.42453184e-039 1.58754897e-042 2.56395524e-046 2.67747436e-050
# ...

# %%
i=50
j=50
k=6

print( j)

ci=31
cj=29
#f90 = open(dir+'thermal_eq_curve_md_lmt.dat', 'rb')
f90 = open(dir+'Thermal_inst2_br2.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j*k)
uvhpy = ary.reshape(i,j,k,order='F')
#uvhpy = ary.reshape(k,j,i,order='F')

#cool  =uvhpy[0,:,:]
#Rho    =uvhpy[1,:,:]
#T   =uvhpy[2,1,:]
#dLdRho    =uvhpy[3,:,:]
#dLdT   =uvhpy[4,:,:]
#Gmm   =uvhpy[5,:,:]

cool  =uvhpy[:,:,0]
Rho    =uvhpy[:,1,1]
T   =uvhpy[:,:,2]
dLdRho    =uvhpy[:,:,3]
dLdT   =uvhpy[:,:,4]
Gmm   =uvhpy[:,:,5]

print(Rho,T)
# Out:
# 50
# [ 7.12642790e-01  1.10113222e+03  9.06502011e+01 -4.60978220e-02
#   7.90592535e+02  1.66666667e+00  7.12642790e-01  1.32385210e+03
#   8.11368551e+01 -3.91213444e-02  8.06217650e+02  1.66666667e+00
#   7.12642790e-01  1.59162030e+03  7.17877656e+01 -3.19778889e-02
#   8.22265017e+02  1.66666667e+00  7.12642790e-01  1.91354848e+03
#   6.30448615e+01 -2.48734594e-02  8.39366316e+02  1.66666667e+00
#   7.12642790e-01  2.30059128e+03  5.54487670e+01 -1.79750801e-02
#   8.58357110e+02  1.66666667e+00  7.12642790e-01  2.76591908e+03
#   4.96492681e+01 -1.14148694e-02  8.80309119e+02  1.66666667e+00
#   7.12642790e-01  3.32536613e+03  4.64157012e+01 -5.29373660e-03
#   9.06563254e+02  1.66666667e+00  7.12642790e-01  3.99796944e+03
#   4.66471674e+01  3.15186794e-04  9.38762805e+02  1.66666667e+00
#   7.12642790e-01  4.80661646e+03] [[5.72031788e+04 4.31950430e+04 5.66072289e+00 ... 2.83708205e+01
#   2.94195425e+06 3.35940764e+05]
# ...

# %%
i=50
j=50
k=6

print( j)

cf90 = open(dir+'Thermal_Z10m0_TI_md.dat', 'rb')
cary = np.fromfile(cf90, np.float64, count=ci*cj)
cuvhpy = cary.reshape(cj, ci, order='F')

f90 = open(dir+'thermal_eq_curve_md_lmt.dat', 'rb')
nf90 = open(dir+'Thermal_inst5_br_KI.dat', 'rb')
f90 = open(dir+'Thermal_inst5_br_Tmp_KI.dat', 'rb')
f91 = open(dir+'Thermal_inst5_br_Rho_KI.dat', 'rb')
f92 = open(dir+'Thermal_inst5_br_dLdR_KI.dat', 'rb')
f93 = open(dir+'Thermal_inst5_br_dLdT_KI.dat', 'rb')
f94 = open(dir+'Thermal_inst5_br_gmm_KI.dat', 'rb')
of90 = open(dir+'Thermal_inst5_br_T_KI.dat', 'rb')
of91 = open(dir+'Thermal_inst5_br_R_KI.dat', 'rb')

cT         =cuvhpy[1,:]
cndtotl =cuvhpy[12,:]

#nf90 = open(dir+'Thermal_inst5_br.dat', 'rb')
#f90 = open(dir+'Thermal_inst5_br_Tmp.dat', 'rb')
#f91 = open(dir+'Thermal_inst5_br_Rho.dat', 'rb')
#f92 = open(dir+'Thermal_inst5_br_dLdR.dat', 'rb')
#f93 = open(dir+'Thermal_inst5_br_dLdT.dat', 'rb')
#f94 = open(dir+'Thermal_inst5_br_gmm.dat', 'rb')

#of90 = open(dir+'Thermal_inst5_br_T.dat', 'rb')
#of91 = open(dir+'Thermal_inst5_br_R.dat', 'rb')

#ary    = np.fromfile(f90, np.float64, count=j)
nary    = np.fromfile(nf90, np.float64, count=i*j*k)
ary    = np.fromfile(f90, np.float64, count=j)
ary1 = np.fromfile(f91, np.float64, count=i)
ary2 = np.fromfile(f92, np.float64, count=i*j)
ary3 = np.fromfile(f93, np.float64, count=i*j)
ary4 = np.fromfile(f94, np.float64, count=i*j)

oary    = np.fromfile(of90, np.float64, count=i*j)
oary1 = np.fromfile(of91, np.float64, count=i*i)

uvhpy    = ary.reshape(j,order='F')
#uvhpy    = ary.reshape(i,j,order='F')
uvhpy1 = ary1.reshape(i,order='F')
uvhpy2 = ary2.reshape(i,j,order='F')
uvhpy3 = ary3.reshape(i,j,order='F')
uvhpy4 = ary4.reshape(i,j,order='F')
nuvhpy = nary.reshape(k,j,i,order='F')

ouvhpy1 = oary1.reshape(i,i,order='F')
ouvhpy = oary.reshape(i,j,order='F')

cool  =nuvhpy[0,:,:]
#Rho    =nuvhpy[1,:,:]
#T   =nuvhpy[2,:,:]
dLdRho    =nuvhpy[3,:,:]
dLdT   =nuvhpy[4,:,:]
Gmm   =nuvhpy[5,:,:]

Rho    =ouvhpy[:,:]
#T   =ouvhpy1[:,:]
Prs   =ouvhpy1[:,:]

#Rho    =uvhpy1[:]
#T   =uvhpy[:]
#print(Rho ,T)
#dLdRho    =uvhpy2[:,:]
#dLdT   =uvhpy3[:,:]
#Gmm  =uvhpy4[:,:]

#print(uvhpy )
#print(dLdT)

x=np.linspace(-1, 4, i) 
y=np.linspace(1, 5, j) 


#X, Y = np.meshgrid(np.log10(Rho),np.log10(T*1000.0))
#X, Y = np.meshgrid(x,y)
#Z = np.sin(X) + np.cos(Y)   # 表示する計算式の指定。等高線はZに対して作られる。

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.scatter(X, Y, s=100, c=dLdT+Rho/T*dLdRho/(Gmm-1) , cmap='cool', vmin=-1.0, vmax=1.0)
#plt.scatter(X, Y, s=100, c= dLdT , cmap='cool', vmin=-1.0, vmax=1.0)
#plt.scatter(np.log10(np.array(Rho).T), np.log10(np.array(Prs).T), s=10, c= np.array(dLdT).T, cmap='cool', vmin=-1.0, vmax=1.0)
plt.scatter(np.log10((Prs)), np.log10((Rho)), s=10, c= np.array(dLdRho).T, cmap='cool', vmin=-1.0, vmax=1.0)
#plt.scatter(np.log10((Rho)), np.log10((Prs)), s=10, c= np.array(dLdT).T, cmap='cool', vmin=-1.0, vmax=1.0)
plt.colorbar()

plt.plot(np.log10(cndtotl), np.log10(cT*cndtotl*1000.0) ,color='red',linestyle='solid')

#plt.ylim(3, 5)
#plt.xlim(-1, 4)

plt.ylim(3, 6)
plt.xlim(0, 3)

# 等高線図の生成。
#cont=plt.contour(X,Y,uvhpy2,  5, vmin=-1,vmax=1, colors=['black'])
#cont.clabel(fmt='%1.1f', fontsize=14)


plt.xlabel('X', fontsize=24)
plt.ylabel('Y', fontsize=24)


#plt.pcolormesh(X,Y,Z, cmap='cool') #カラー等高線図
#pp=plt.colorbar (orientation="vertical") # カラーバーの表示 
#pp.set_label("Label",  fontsize=24)

plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Thermal_inst1.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# 50

# %%
ci=51
cj=29+2+6

#f90 = open(dir+'thermal_eq_curve_md_lmt.dat', 'rb')
cf90 = open(dir+'Thermal_bialyn_Z10m0_md_mid.dat', 'rb')
cary = np.fromfile(cf90, np.float64, count=ci*cj)
cuvhpy = cary.reshape(cj, ci, order='F')

cT         =cuvhpy[1,:]
cRho    =cuvhpy[0,:]
cndpl    =cuvhpy[2,:]
cndHl    =cuvhpy[3,:]
cndH2l  =cuvhpy[4,:]
cndHml =cuvhpy[5,:]
cndHel  =cuvhpy[6,:]
cndHepl=cuvhpy[7,:]
cndCl    =cuvhpy[8,:]
cndCpl  =cuvhpy[9,:]
cndCOl =cuvhpy[10,:]
cndel    =cuvhpy[11,:]
cndtotl =cuvhpy[12,:]
cLamll =cuvhpy[13,:]
cLamcl =cuvhpy[14,:]
cLamol =cuvhpy[15,:]
cLamdl =cuvhpy[16,:]
cLCOrl =cuvhpy[17,:]
cLCOHl =cuvhpy[18,:]
cLCOH2l =cuvhpy[19,:]
cLamH2l =cuvhpy[20,:]
cLffl =cuvhpy[21,:]
cLrrl =cuvhpy[22,:]
cLCIEl =cuvhpy[23,:]
cLCIEHel =cuvhpy[24,:]
cGampel =cuvhpy[25,:]
cGamcrl   =cuvhpy[26,:]
cGampdl =cuvhpy[27,:]

print(cndtotl)


i=50
j=50
k=6

nf90 = open(dir+'Thermal_instF_balbus_br.dat', 'rb')
f90 = open(dir+'Thermal_instF_balbus_br_Tmp.dat', 'rb')
f91 = open(dir+'Thermal_instF_balbus_br_Rho.dat', 'rb')
f92 = open(dir+'Thermal_instF_balbus_br_dLdR.dat', 'rb')
f93 = open(dir+'Thermal_instF_balbus_br_dLdT.dat', 'rb')
f94 = open(dir+'Thermal_instF_balbus_br_gmm.dat', 'rb')
f95 = open(dir+'Thermal_instF_balbus_br_KI.dat', 'rb')

of90 = open(dir+'Thermal_instF_balbus_br_T.dat', 'rb')
of91 = open(dir+'Thermal_instF_balbus_br_R.dat', 'rb')

nary    = np.fromfile(nf90, np.float64, count=i*j*k)
ary    = np.fromfile(f90, np.float64, count=j)
ary1 = np.fromfile(f91, np.float64, count=i)
ary2 = np.fromfile(f92, np.float64, count=i*j)
ary3 = np.fromfile(f93, np.float64, count=i*j)
ary4 = np.fromfile(f94, np.float64, count=i*j)
#ary5 = np.fromfile(f95, np.float64, count=i*j)

oary    = np.fromfile(of90, np.float64, count=i*j)
oary1 = np.fromfile(of91, np.float64, count=i*i)

uvhpy    = ary.reshape(j,order='F')
uvhpy1 = ary1.reshape(i,order='F')
uvhpy2 = ary2.reshape(i,j,order='F')
uvhpy3 = ary3.reshape(i,j,order='F')
uvhpy4 = ary4.reshape(i,j,order='F')
#uvhpy5 = ary5.reshape(i,j,order='F')
nuvhpy = nary.reshape(k,j,i,order='F')

ouvhpy1 = oary1.reshape(i,i,order='F')
ouvhpy = oary.reshape(i,j,order='F')

cool  =nuvhpy[0,:,:]
#Rho    =nuvhpy[1,:,:]
#T   =nuvhpy[2,:,:]
dLdRho    =nuvhpy[3,:,:]
dLdT   =nuvhpy[4,:,:]
Gmm   =nuvhpy[5,:,:]
Rho    =ouvhpy[:,:]
Prs   =ouvhpy1[:,:]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.scatter(np.log10((Prs)), np.log10((Rho)), s=10, c= np.array(dLdT), cmap='summer', vmin=-1.0, vmax=1.0) #isobaric
#plt.scatter(np.log10((Prs)), np.log10((Rho)), s=10, c= np.array(dLdRho).T, cmap='Wistia', vmin=-1.0, vmax=1.0) #isochoric
plt.scatter(np.log10((Prs)), np.log10((Rho)), s=10, c= np.array(Gmm).T, cmap='spring', vmin=-1.0, vmax=1.0) #isentropic
plt.colorbar()

plt.plot(np.log10(cndtotl), np.log10(cT*cndtotl*1000.0) ,color='red',linestyle='solid')
#plt.plot( np.log10(cT*cndtotl*1000.0),np.log10(cndtotl) ,color='red',linestyle='solid')

plt.ylim(3, 6)
plt.xlim(0, 3)

plt.show()

pp = PdfPages('/Users/maedarn/Desktop/TI_TEC.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# [6.05747368e-02 7.98530550e-02 1.05266828e-01 1.38768705e-01
#  1.82932781e-01 2.41152371e-01 3.17900738e-01 4.19074790e-01
#  5.52448166e-01 7.28268517e-01 9.60044881e-01 1.26558563e+00
#  1.66836679e+00 2.19933576e+00 2.89928919e+00 3.82200751e+00
#  5.03838716e+00 6.64188783e+00 8.75571338e+00 1.15422782e+01
#  1.52156860e+01 2.00581806e+01 2.64418317e+01 3.48571228e+01
#  4.59506370e+01 6.05747369e+01 7.98530551e+01 1.05266828e+02
#  1.38768705e+02 1.82932781e+02 2.41152371e+02 3.17900738e+02
#  4.19074790e+02 5.52448166e+02 7.28268518e+02 9.60044881e+02
#  1.26558563e+03 1.66836679e+03 2.19933576e+03 2.89928919e+03
#  3.82200751e+03 5.03838716e+03 6.64188782e+03 8.75571338e+03
#  1.15422782e+04 1.52156860e+04 2.00581806e+04 2.64418317e+04
#  3.48571228e+04 4.59506370e+04 6.05747369e+04]

# %%
t=1.8e5
R1=28.0*(t/1.e6)**(3/5)
print(R1)

Tb=(8.0*4.0*7.0/5.0/3.0/25.0*3.14)**(2/7)* (125.0/154.0/3.14)**(8/35)*(1.8e5/1.e6)**(-6/35)
# Out:
# 10.007406344603568

# %%
i=51
j=29
ni=21
nnj=31
nnnj=31+6

print( j)

#f90 = open(dir+'thermal_eq_curve_md_lmt.dat', 'rb')
#f90 = open(dir+'Thermal_optthick_Z10m0_md2.dat', 'rb')
f90 = open(dir+'Thermal_bialyk_Z10m4_md_mid.dat', 'rb')
nf90 = open(dir+'Thermal_bialy_Z10m3_md_mid.dat', 'rb')
of90 = open(dir+'Thermal_bialy_Z10m3_md_hot.dat', 'rb')
lm1f90 = open(dir+'Thermal_bialyn_Z10m0_l_mid.dat', 'rb')
lm2f90 = open(dir+'Thermal_bialyi_Z10m2_md_mid.dat', 'rb')
lm3f90 = open(dir+'Thermal_bialyi_Z10m3_md_mid.dat', 'rb')

ary = np.fromfile(f90, np.float64, count=i*nnnj)
uvhpy = ary.reshape(nnnj, i, order='F')
nary = np.fromfile(nf90, np.float64, count=ni*j)
nuvhpy = nary.reshape(j, ni, order='F')
oary = np.fromfile(of90, np.float64, count=ni*j)
ouvhpy = oary.reshape(j, ni, order='F')

ary1 = np.fromfile(lm1f90, np.float64, count=i*nnj)
uvhpy1 = ary1.reshape(nnj, i, order='F')
ary2 = np.fromfile(lm2f90, np.float64, count=i*nnj)
uvhpy2 = ary2.reshape(nnj, i, order='F')
ary3 = np.fromfile(lm3f90, np.float64, count=i*nnj)
uvhpy3 = ary3.reshape(nnj, i, order='F')

T         =uvhpy[1,:]
Rho    =uvhpy[0,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]
Lamll =uvhpy[13,:]
Lamcl =uvhpy[14,:]
Lamol =uvhpy[15,:]
Lamdl =uvhpy[16,:]
LCOrl =uvhpy[17,:]
LCOHl =uvhpy[18,:]
LCOH2l =uvhpy[19,:]
LamH2l =uvhpy[20,:]
Lffl =uvhpy[21,:]
Lrrl =uvhpy[22,:]
LCIEl =uvhpy[23,:]
LCIEHel =uvhpy[24,:]
Gampel =uvhpy[25,:]
Gamcrl   =uvhpy[26,:]
Gampdl =uvhpy[27,:]
Lneb =uvhpy[28,:]
Gampdl1 =uvhpy[29,:]
Gampdl2 =uvhpy[30,:]
Lamdg =uvhpy[31,:]
LH2a =uvhpy[32,:]
LH2b =uvhpy[33,:]
LH2c =uvhpy[34,:]
LH2d =uvhpy[35,:]
LH2e =uvhpy[36,:]

nT         =nuvhpy[1,:]
nndtotl =nuvhpy[12,:]
nRho =nuvhpy[0,:]

oT         =ouvhpy[1,:]
ondtotl =ouvhpy[12,:]
oRho =ouvhpy[0,:]

T1         =uvhpy1[1,:]
ndtotl1 =uvhpy1[12,:]
Rho1     =uvhpy1[0,:]
T2         =uvhpy2[1,:]
ndtotl2 =uvhpy2[12,:]
Rho2     =uvhpy2[0,:]
T3         =uvhpy3[1,:]
ndtotl3 =uvhpy3[12,:]
Rho3     =uvhpy3[0,:]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-28), 10**(-25))
#plt.ylim(0.001, 0.1)
plt.ylim(300, 50000000.0)
#plt.ylim(100, 10000000.0)
#plt.ylim(1.e-28,1.e-21)
plt.xlim(0.01, 100000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndtotl)

#plt.plot(ndtotl, ndtotl*T*8.63359*90.8 ,color='green',linestyle='solid')
#plt.plot(ndtotl, ndtotl*T*1000.0 ,color='purple',linestyle='dashdot')
plt.plot(ndtotl1, ndtotl1*T1*1000.0 ,color='blue',linestyle='dashdot')
#plt.plot(ndtotl2, ndtotl2*T2*1000.0 ,color='red',linestyle='dashdot')
#plt.plot(ndtotl3, ndtotl3*T3*1000.0 ,color='orange',linestyle='dashdot')
#plt.plot(ndtotl, ndtotl*T ,color='green',linestyle='solid')
#plt.plot(nndtotl, nndtotl*nT*1000.0 ,color='green',linestyle='solid')
#plt.plot(ondtotl, ondtotl*oT*1000.0 ,color='green',linestyle='solid')
#plt.plot(Rho/1.27, Rho/1.27*T*1000.0 ,color='green',linestyle='solid')
#plt.plot(nRho/1.27, nRho/1.27*nT*1000.0 ,color='green',linestyle='solid')
#plt.plot(oRho/1.27, oRho/1.27*oT*1000.0 ,color='green',linestyle='solid')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red',linestyle='dashed')
#plt.plot(ndtotl, T*1000.0 ,color='red')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red')

#plt.plot(Rho/1.27, Lamll/1.9733e27/(Rho/1.27) ,color='red')
#plt.plot(Rho/1.27, Lamcl/1.9733e27/(Rho/1.27),color='green')
#plt.plot(Rho/1.27, Lamol/1.9733e27/(Rho/1.27),color='blue')
#plt.plot(Rho/1.27, Lamdl/1.9733e27 /(Rho/1.27),color='purple')
#plt.plot(Rho/1.27, Gampel /1.9733e27 /(Rho/1.27),color='yellow')
#plt.plot(Rho/1.27, Gamcrl /1.9733e27/(Rho/1.27),color='gray')
#plt.plot(Rho/1.27, Gampdl /1.9733e27 /(Rho/1.27),color='magenta')


plt.plot(ndtotl, Lamll/1.9733e27/(ndtotl) ,color='green',linestyle='dashdot')
plt.plot(ndtotl, Lamcl/1.9733e27/(ndtotl),color='red',linestyle='dashdot')
plt.plot(ndtotl, Lamol/1.9733e27/(ndtotl),color='blue',linestyle='dashdot')
plt.plot(ndtotl, Lamdl/1.9733e27 /(ndtotl),color='orange',linestyle='dashdot')
#plt.plot(ndtotl, Gampel /1.9733e27 /(ndtotl),color='blue',linestyle='dashdot')
#plt.plot(ndtotl, Gamcrl /1.9733e27/(ndtotl),color='red',linestyle='dashdot')
#plt.plot(ndtotl, Gampdl /1.9733e27 /(ndtotl),color='green',linestyle='dashdot')
#plt.plot(ndtotl, Gampdl1 /1.9733e27 /(ndtotl),color='purple',linestyle='dashdot')
#plt.plot(ndtotl, Gampdl2 /1.9733e27 /(ndtotl),color='orange',linestyle='dashdot')
plt.plot(ndtotl, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black',linestyle='dashdot')
plt.plot(ndtotl, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown',linestyle='dashdot')
plt.plot(ndtotl, Lneb/1.9733e27 /(ndtotl),color='cyan',linestyle='dashdot')
plt.plot(ndtotl, LamH2l/1.9733e27 /(ndtotl),color='goldenrod',linestyle='dashdot')
plt.plot(ndtotl, (LCOH2l+LCOHl+LCOrl)/1.9733e27 /(ndtotl),color='indigo',linestyle='dashdot')
plt.plot(ndtotl, Lamdg/1.9733e27 /(ndtotl),color='magenta',linestyle='dashdot')
plt.plot(ndtotl, LH2a /1.9733e27/(ndtotl),color='coral',linestyle='dashdot')
plt.plot(ndtotl, LH2b/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')
plt.plot(ndtotl, LH2c/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')
plt.plot(ndtotl, LH2d/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')
plt.plot(ndtotl, LH2e/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')



#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

#print(LCIEl+LCIEHel)

#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl)/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl)/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl)/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl)/(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl)/(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl)/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl)/(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl)/(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl)/(ndtotl),color='brown')

#for k in range(1,11):
#plt.plot(uvhpy[0,:],uvhpy[k,:])
#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Cooling_Code_Hot.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# 29
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 26
#      23 ouvhpy = oary.reshape(j, ni, order='F')
#      25 ary1 = np.fromfile(lm1f90, np.float64, count=i*nnj)
# ---> 26 uvhpy1 = ary1.reshape(nnnj, i, order='F')
#      27 ary2 = np.fromfile(lm2f90, np.float64, count=i*nnj)
#      28 uvhpy2 = ary2.reshape(nnj, i, order='F')
#
# ValueError: cannot reshape array of size 1479 into shape (37,51)

# %%
a=0.5*(3.0/2.0/3.14)**0.25 * (3.0*1.e7*1.e6)**(-0.5) * (1.67*1.e-24)**(-0.25) * ((2.0*62.e37*1.e-6*2.0*1.e33/(3.0*1.e7))**0.5)**0.25/1.e5
print(a)

# %%
i=51
j=29
ni=21
nnj=31+6
nnnj=31+6

lm1f90 = open(dir+'Thermal_bialyo_Z10m0_md_mid.dat', 'rb')

ary1 = np.fromfile(lm1f90, np.float64, count=i*nnj)
uvhpy = ary1.reshape(nnj, i, order='F')

T         =uvhpy[1,:]
Rho    =uvhpy[0,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]
Lamll =uvhpy[13,:]
Lamcl =uvhpy[14,:]
Lamol =uvhpy[15,:]
Lamdl =uvhpy[16,:]
LCOrl =uvhpy[17,:]
LCOHl =uvhpy[18,:]
LCOH2l =uvhpy[19,:]
LamH2l =uvhpy[20,:]
Lffl =uvhpy[21,:]
Lrrl =uvhpy[22,:]
LCIEl =uvhpy[23,:]
LCIEHel =uvhpy[24,:]
Gampel =uvhpy[25,:]
Gamcrl   =uvhpy[26,:]
Gampdl =uvhpy[27,:]
Lneb =uvhpy[28,:]
Gampdl1 =uvhpy[29,:]
Gampdl2 =uvhpy[30,:]
'''
Lamdg =uvhpy[31,:]
LH2a =uvhpy[32,:]
LH2b =uvhpy[33,:]
LH2c =uvhpy[34,:]
LH2d =uvhpy[35,:]
LH2e =uvhpy[36,:]
'''


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-28), 10**(-25))
#plt.ylim(0.001, 0.1)
plt.ylim(300, 50000000.0)
#plt.ylim(100, 10000000.0)
#plt.ylim(1.e-28,1.e-21)
plt.xlim(0.01, 100000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndtotl)

#plt.plot(ndtotl, ndtotl*T*8.63359*90.8 ,color='green',linestyle='solid')
plt.plot(ndtotl, ndtotl*T*1000.0 ,color='purple',linestyle='dashdot')
#plt.plot(ndtotl1, ndtotl1*T1*1000.0 ,color='blue',linestyle='dashdot')


plt.plot(ndtotl, Lamll/1.9733e27/(ndtotl) ,color='green',linestyle='dashdot')
plt.plot(ndtotl, Lamcl/1.9733e27/(ndtotl),color='red',linestyle='dashdot')
plt.plot(ndtotl, Lamol/1.9733e27/(ndtotl),color='blue',linestyle='dashdot')
plt.plot(ndtotl, Lamdl/1.9733e27 /(ndtotl),color='orange',linestyle='dashdot')
#plt.plot(ndtotl, Gampel /1.9733e27 /(ndtotl),color='blue',linestyle='dashdot')
#plt.plot(ndtotl, Gamcrl /1.9733e27/(ndtotl),color='red',linestyle='dashdot')
#plt.plot(ndtotl, Gampdl /1.9733e27 /(ndtotl),color='green',linestyle='dashdot')
#plt.plot(ndtotl, Gampdl1 /1.9733e27 /(ndtotl),color='purple',linestyle='dashdot')
#plt.plot(ndtotl, Gampdl2 /1.9733e27 /(ndtotl),color='orange',linestyle='dashdot')
plt.plot(ndtotl, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black',linestyle='dashdot')
plt.plot(ndtotl, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown',linestyle='dashdot')
plt.plot(ndtotl, Lneb/1.9733e27 /(ndtotl),color='cyan',linestyle='dashdot')
plt.plot(ndtotl, LamH2l/1.9733e27 /(ndtotl),color='goldenrod',linestyle='dashdot')
plt.plot(ndtotl, (LCOH2l+LCOHl+LCOrl)/1.9733e27 /(ndtotl),color='indigo',linestyle='dashdot')
#plt.plot(ndtotl, Lamdg/1.9733e27 /(ndtotl),color='magenta',linestyle='dashdot')
#plt.plot(ndtotl, LH2a /1.9733e27/(ndtotl),color='coral',linestyle='dashdot')
#plt.plot(ndtotl, LH2b/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')
#plt.plot(ndtotl, LH2c/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')
#plt.plot(ndtotl, LH2d/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')
#plt.plot(ndtotl, LH2e/1.9733e27 /(ndtotl),color='coral',linestyle='dashdot')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Cooling_Code_Hot.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# [6.05747367e-02 7.98530548e-02 1.05266828e-01 1.38768705e-01
#  1.82932780e-01 2.41152370e-01 3.17900737e-01 4.19074789e-01
#  5.52448164e-01 7.28268516e-01 9.60044878e-01 1.26558563e+00
#  1.66836678e+00 2.19933576e+00 2.89928918e+00 3.82200750e+00
#  5.03838714e+00 6.64188780e+00 8.75571335e+00 1.15422781e+01
#  1.52156859e+01 2.00581805e+01 2.64418316e+01 3.48571227e+01
#  4.59506368e+01 6.05747366e+01 7.98530548e+01 1.05266828e+02
#  1.38768705e+02 1.82932780e+02 2.41152370e+02 3.17900737e+02
#  4.19074789e+02 5.52448164e+02 7.28268515e+02 9.60044877e+02
#  1.26558563e+03 1.66836678e+03 2.19933576e+03 2.89928918e+03
#  3.82200750e+03 5.03838714e+03 6.64188780e+03 8.75571335e+03
#  1.15422781e+04 1.52156859e+04 2.00581805e+04 2.64418316e+04
#  3.48571227e+04 4.59506368e+04 6.05747367e+04]

# %%
import matplotlib.pyplot as plt
import numpy as np

# tanh関数
#y = (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x)

a=0.50
x = np.arange(-5, 5, 0.1)
#
y = np.tanh(a*x)
#y = (np.exp(a*x) - np.exp(-a*x)) / (np.exp(a*x) + np.exp(-a*x))

plt.plot(x, y)
plt.title("tanh")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
print(np.log(5))
# Out:
# 1.6094379124341003

# %%
i=100
j=31+6
ni=100

print(j)

#f90 = open(dir+'thermal_eq_curve_md_lmt.dat', 'rb')
#f90 = open(dir+'Thermal_optthick_Z10m0_md2.dat', 'rb')
f90 = open(dir+'Fcool_n1_z10m0.dat', 'rb')
nf90 = open(dir+'Fcool_n1_z10m2.dat', 'rb')
of90 = open(dir+'Fcool_n1_z10m0.dat', 'rb')
ary = np.fromfile(f90, np.float64, count=i*j)
uvhpy = ary.reshape(j, i, order='F')
nary = np.fromfile(nf90, np.float64, count=ni*j)
nuvhpy = nary.reshape(j, ni, order='F')
oary = np.fromfile(of90, np.float64, count=ni*j)
ouvhpy = oary.reshape(j, ni, order='F')

T         =uvhpy[1,:]
Rho    =uvhpy[0,:]
ndpl    =uvhpy[2,:]
ndHl    =uvhpy[3,:]
ndH2l  =uvhpy[4,:]
ndHml =uvhpy[5,:]
ndHel  =uvhpy[6,:]
ndHepl=uvhpy[7,:]
ndCl    =uvhpy[8,:]
ndCpl  =uvhpy[9,:]
ndCOl =uvhpy[10,:]
ndel    =uvhpy[11,:]
ndtotl =uvhpy[12,:]
Lamll =uvhpy[13,:]
Lamcl =uvhpy[14,:]
Lamol =uvhpy[15,:]
Lamdl =uvhpy[16,:]
LCOrl =uvhpy[17,:]
LCOHl =uvhpy[18,:]
LCOH2l =uvhpy[19,:]
LamH2l =uvhpy[20,:]
Lffl =uvhpy[21,:]
Lrrl =uvhpy[22,:]
LCIEl =uvhpy[23,:]
LCIEHel =uvhpy[24,:]
Gampel =uvhpy[25,:]
Gamcrl   =uvhpy[26,:]
Gampdl =uvhpy[27,:]

nndpl   =nuvhpy[2,:]
nRho    =nuvhpy[0,:]
nT      =nuvhpy[1,:]
nndHl   =nuvhpy[3,:]
nndH2l  =nuvhpy[4,:]
nndHml  =nuvhpy[5,:]
nndHel  =nuvhpy[6,:]
nndHepl =nuvhpy[7,:]
nndCl   =nuvhpy[8,:]
nndCpl  =nuvhpy[9,:]
nndCOl  =nuvhpy[10,:]
nndel   =nuvhpy[11,:]
nndtotl =nuvhpy[12,:]
nLamll  =nuvhpy[13,:]
nLamcl  =nuvhpy[14,:]
nLamol  =nuvhpy[15,:]
nLamdl  =nuvhpy[16,:]
nLCOrl  =nuvhpy[17,:]
nLCOHl  =nuvhpy[18,:]
nLCOH2l =nuvhpy[19,:]
nLamH2l =nuvhpy[20,:]
nLffl   =nuvhpy[21,:]
nLrrl   =nuvhpy[22,:]
nLCIEl  =nuvhpy[23,:]
nLCIEHel=nuvhpy[24,:]
nGampel =nuvhpy[25,:]
nGamcrl =nuvhpy[26,:]
nGampdl =nuvhpy[27,:]



fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#plt.xlim(0.1, 100)a
#plt.xlim(0.000001, 1.0)
#plt.ylim(10**(-28), 10**(-25))
#plt.ylim(0.001, 0.1)
#plt.ylim(300, 50000000.0)
#plt.ylim(1, 500000)
plt.xlim(100, 100000000)
ax.set_yscale('log')
ax.set_xscale('log')

print(ndtotl)

Ltot=Lamll+Lamcl+Lamol+Lamdl+LCOrl+LCOHl+LCOH2l+LamH2l+Lffl+Lrrl+LCIEl+LCIEHel 
nLtot=nLamll+nLamcl+nLamol+nLamdl+nLCOrl+nLCOHl+nLCOH2l+nLamH2l+nLffl+nLrrl+nLCIEl+nLCIEHel 

xT = np.arange(1.9, 8, 0.1)
xT10 = 10**xT
Lmk = [0]*len(xT)
for i in range(1,len(xT)):
    print(i, xT[i])
    TMK = xT[i]
    if 10.0**TMK<14577.0:
        Lmk[i] = (10.0**7 * np.exp(-118400.0/(10.0**TMK+1000.0)) + 1.4 * 1.e-2 * np.sqrt(10.0**TMK) * np.exp(-92.0/(10.0**TMK)))/2.e26
    elif (10.0**TMK>14577.0) and (10.0**TMK<19449.0):
        Lmk[i] = (5.e3 + 1.4 * 1.e-2 * np.sqrt(10.0**TMK) * np.exp(-92.0/(10.0**TMK)))/2.e26
    elif (10.0**TMK>19449.0):
        Lmk[i] = (3.75e4 * (1.e0 - np.tanh((10.0**TMK-2.e5)/(2.e5))) * np.exp(-5.e4/(10.0**TMK)) + 1.e3 * np.exp(-5.e4/(10.0**TMK)))/2.e26



#plt.plot(ndtotl, ndtotl*T*1000.0 ,color='green',linestyle='solid')
plt.plot(T*1.e3,  Ltot/1.9733e27,color='red',linestyle='dashed', linewidth=2)
plt.plot(nT*1.e3,  nLtot/1.9733e27,color='blue',linestyle='dashed', linewidth=2)
plt.plot(xT10, Lmk ,color='green',linestyle='solid', linewidth=2)
#plt.plot(ondtotl, ondtotl*oT*1000.0 ,color='green',linestyle='solid')
#plt.plot(Rho/1.27, Rho/1.27*T*1000.0 ,color='green',linestyle='solid')
#plt.plot(nRho/1.27, nRho/1.27*nT*1000.0 ,color='green',linestyle='solid')
#plt.plot(oRho/1.27, oRho/1.27*oT*1000.0 ,color='green',linestyle='solid')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red',linestyle='dashed')
#plt.plot(ndtotl, T*1000.0 ,color='red')
#plt.plot(Rho/1.27, T*Rho/1.27*1000.0 ,color='red')
#plt.plot(Rho/1.27, Lamll/1.9733e27/(Rho/1.27) ,color='red')
#plt.plot(Rho/1.27, Lamcl/1.9733e27/(Rho/1.27),color='green')
#plt.plot(Rho/1.27, Lamol/1.9733e27/(Rho/1.27),color='blue')
#plt.plot(Rho/1.27, Lamdl/1.9733e27 /(Rho/1.27),color='purple')
#plt.plot(Rho/1.27, Gampel /1.9733e27 /(Rho/1.27),color='yellow')
#plt.plot(Rho/1.27, Gamcrl /1.9733e27/(Rho/1.27),color='gray')
#plt.plot(Rho/1.27, Gampdl /1.9733e27 /(Rho/1.27),color='magenta')

#plt.plot(ndtotl, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(ndtotl, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(ndtotl, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(ndtotl, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(ndtotl, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(ndtotl, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(ndtotl, Gampdl /1.9733e27 /(ndtotl),color='magenta')
#plt.plot(ndtotl, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
#plt.plot(ndtotl, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl),color='brown')

#plt.plot(T*1000.0, Lamll/1.9733e27/(ndtotl)/(ndtotl) ,color='red')
#plt.plot(T*1000.0, Lamcl/1.9733e27/(ndtotl)/(ndtotl),color='green')
#plt.plot(T*1000.0, Lamol/1.9733e27/(ndtotl)/(ndtotl),color='blue')
#plt.plot(T*1000.0, Lamdl/1.9733e27 /(ndtotl)/(ndtotl),color='purple')
#plt.plot(T*1000.0, Gampel /1.9733e27 /(ndtotl)/(ndtotl),color='yellow')
#plt.plot(T*1000.0, Gamcrl /1.9733e27/(ndtotl)/(ndtotl),color='gray')
#plt.plot(T*1000.0, Gampdl /1.9733e27 /(ndtotl)/(ndtotl),color='magenta')
#plt.plot(T*1000.0, (Lffl+Lrrl) /1.9733e27 /(ndtotl)/(ndtotl),color='black')
#plt.plot(T*1000.0, (LCIEl+LCIEHel )/1.9733e27 /(ndtotl)/(ndtotl),color='brown')

#for k in range(1,11):
#plt.plot(uvhpy[0,:],uvhpy[k,:])
#plt.gca().set_aspect('equal')


plt.show()

pp = PdfPages('/Users/maedarn/Desktop/Cooling_Code_Hot.pdf')
pp.savefig(fig,transparent=True)
pp.close()
# Out:
# 37
# [0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
#  0.60574737 0.60574737 0.60574737 0.60574737 0.60574737 0.60574737
# ...
