# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.animation as animation
from matplotlib.animation import ArtistAnimation

# %%
#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100/'
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T10-cg1-L100/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T50-cg1-L100/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T5-cg1-L100/'
#dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg1-L100/'

#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-eq-3pwe/'
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T10-cg1-L100-eq-3pwe/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T50-cg1-L100-eq-3pwe/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T5-cg1-L100-eq-3pwe/'
#dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg1-L100-eq-3pwe/'

#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-3pwe-4thcd/'
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T10-cg1-L100-3pwe-4thcd/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T50-cg1-L100-3pwe-4thcd/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T5-cg1-L100-3pwe-4thcd/'
#dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg1-L100-3pwe-4thcd/'

dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-small-3pwe-4thcd/'
dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T10-cg1-L100-small-3pwe-4thcd/'
dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T50-cg1-L100-small-3pwe-4thcd/'
dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T5-cg1-L100-small-3pwe-4thcd/'
dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg1-L100-small-3pwe-4thcd/'

#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-eq-3pwe-4thmscl-t03//'
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-eq-3pwe-4thcd-t03/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T50-cg1-L100-3pwe-4thcd/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T5-cg1-L100-3pwe-4thcd/'

#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg1-L100-eq-3pwe-4thmscl/'


"""
dir6  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T15-cg1-L100-3pwe-4thcd/'
dir7  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T30-cg1-L100-3pwe-4thcd/'

dir8  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T106-cg1-L100-3pwe-4thcd/'
dir9  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T107-cg1-L100-3pwe-4thcd/'
"""
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T50-cg1-L100-eq-ot/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T10-cg1-L100-eq-ot/'

#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-mv-002/'
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-mv-01/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-mv-05/'

#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-eq-free/'
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T10-cg1-L100-eq-free/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T50-cg1-L100-eq-free/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T5-cg1-L100-eq-free/'
#dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg1-L100-eq-free/'

#dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-hv1000/'
#dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-hv10000/'

#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/kp-1-10-cg1-mash128-L100/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/kp-1-9-cg1-mash128-L100/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/kp-1-8-cg1-mash128-L100/'

#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/kp-1-10-cg1-mash64-L100/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/kp-1-10-cg1-mash256-L100/'

#dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg1-L100-kp/'

#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg10-L100/'
#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T20-cg-1-L100/'

#dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg-1-L100/'
#dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T100-cg1-L1000/'
#dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-128-2000st-T10-cg-1-L10/'
'''
dir1  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-64-1000st-T20-cg1-L100/'
dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-64-1000st-T10-cg1-L100/'
dir3  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-64-1000st-T50-cg1-L100/'
dir4  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-64-1000st-T5-cg1-L100/'
dir5  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-64-1000st-T100-cg1-L100/'
#dir2  = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-3D-shusoku/telegraph-64-2000st-T5-cg1-L100-halfdt/'
'''

folder1="Phiwv"  #+ str(np.int(sample_frequency)) 
folder2="Phiexa"  #+ str(np.int(sample_frequency)) 


rms1 = [0] * nloop
rms2 = [0] * nloop
rms3 = [0] * nloop
rms4 = [0] * nloop
rms5 = [0] * nloop

rmsf = [0] * 5

#nms = [ndx-4] * 5

'''
rms6 = [0] * nloop
rms7 = [0] * nloop
rms8 = [0] * nloop
rms9 = [0] * nloop
'''
ratio = [0] * nloop

b = np.arange(nloop)
b=b*step
for i in range(1,nloop):
    
    h5file1 = h5py.File(dir1+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file2 = h5py.File(dir2+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file3 = h5py.File(dir3+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file4 = h5py.File(dir4+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file5 = h5py.File(dir5+'NAllHDF'+"%03.f"%(i)+'.h5',"r")

    '''
    h5file6 = h5py.File(dir6+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file7 = h5py.File(dir7+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file8 = h5py.File(dir8+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file9 = h5py.File(dir9+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    '''
    
    #データ読み込み
    Phiwv1to1  = h5file1[folder1+"/Phiwv1"].value 
    Phiexa1 = h5file1[folder2+"/Phiexa"].value 
    mx1=np.max(Phiexa1)
    mn1=np.min(Phiexa1)
    
    Phiwv1to2  = h5file2[folder1+"/Phiwv1"].value 
    Phiexa2  = h5file2[folder2+"/Phiexa"].value 
    mx2=np.max(Phiexa2)
    mn2=np.min(Phiexa2)
    
    Phiwv1to3  = h5file3[folder1+"/Phiwv1"].value 
    Phiexa3  = h5file3[folder2+"/Phiexa"].value 
    mx3=np.max(Phiexa3)
    mn3=np.min(Phiexa3)
    
    
    Phiwv1to4  = h5file4[folder1+"/Phiwv1"].value 
    Phiexa4  = h5file4[folder2+"/Phiexa"].value 
    mx4=np.max(Phiexa4)
    mn4=np.min(Phiexa4)
    
    Phiwv1to5  = h5file5[folder1+"/Phiwv1"].value 
    Phiexa5  = h5file5[folder2+"/Phiexa"].value 
    mx5=np.max(Phiexa5)
    mn5=np.min(Phiexa5)
    
    
    '''
    Phiwv1to6  = h5file6[folder1+"/Phiwv1"].value 
    Phiexa6 = h5file6[folder2+"/Phiexa"].value 
    mx6=np.max(Phiexa6)
    mn6=np.min(Phiexa6)
    
    Phiwv1to7  = h5file7[folder1+"/Phiwv1"].value 
    Phiexa7  = h5file7[folder2+"/Phiexa"].value 
    mx7=np.max(Phiexa7)
    mn7=np.min(Phiexa7)
    
    Phiwv1to8  = h5file8[folder1+"/Phiwv1"].value 
    Phiexa8  = h5file8[folder2+"/Phiexa"].value 
    mx8=np.max(Phiexa8)
    mn8=np.min(Phiexa8)
    
    
    Phiwv1to9  = h5file9[folder1+"/Phiwv1"].value 
    Phiexa9  = h5file9[folder2+"/Phiexa"].value 
    mx9=np.max(Phiexa9)
    mn9=np.min(Phiexa9)
    '''
    
    #spectrum = h5file[folder+"/spectrum"].value
    #data = np.loadtxt(dir53+'phi2D'+"%05.f"%(i)+'.dat', delimiter=',', unpack=True ,dtype='float') 
    #rdata = np.reshape(data[a, :], (nd, ny ,nx))
    
    #err=0.25*(rdata[6,:,:]+rdata[7,:,:]+rdata[8,:,:]+rdata[9,:,:])-rdata[12,:,:]
    err1=Phiwv1to1- Phiexa1
    err2=Phiwv1to2- Phiexa2
    err3=Phiwv1to3- Phiexa3
    err4=Phiwv1to4- Phiexa4
    err5=Phiwv1to5- Phiexa5
    
    '''
    err6=Phiwv1to6- Phiexa6
    err7=Phiwv1to7- Phiexa7
    err8=Phiwv1to8- Phiexa8
    err9=Phiwv1to9- Phiexa9
    '''
    rms1[i] = np.sqrt(np.mean(err1*err1))/(mx1-mn1)
    rms2[i] = np.sqrt(np.mean(err2*err2))/(mx2-mn2)
    rms3[i] = np.sqrt(np.mean(err3*err3))/(mx3-mn3)
    rms4[i] = np.sqrt(np.mean(err4*err4))/(mx4-mn4)
    rms5[i] = np.sqrt(np.mean(err5*err5))/(mx5-mn5)
    '''
    rms6[i] = np.sqrt(np.mean(err6*err6))/(mx6-mn6)
    rms7[i] = np.sqrt(np.mean(err7*err7))/(mx7-mn7)
    rms8[i] = np.sqrt(np.mean(err8*err8))/(mx8-mn8)
    rms9[i] = np.sqrt(np.mean(err9*err9))/(mx9-mn9)
    '''
    ratio[i]=rms1[i]/rms5[i]


rms1[0]=100
rms2[0]=100
rms3[0]=100
rms4[0]=100
rms5[0]=100

rmsf[0] = rms1[100]
rmsf[1] = rms2[100]
rmsf[2] = rms3[100]
rmsf[3] = rms4[100]
rmsf[4] = rms5[100]

'''
rms6[0]=100
rms7[0]=100
rms8[0]=100
rms9[0]=100

rms1[0]=rms1[1]
rms2[0]=rms2[1]
rms3[0]=rms3[1]
'''
ratio[0] = 1

fig = plt.figure()
#fig.subplots_adjust(bottom=0.21)
#fig.subplots_adjust(left=0.1)
#fig.subplots_adjust(right=0)
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['mathtext.default'] = 'it'
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
plt.xlim([0.0, nloop*step]) # x方向の描画範囲を指定
plt.ylim([0.001, 0.1]) # y方向の描画範囲を指定
plt.rcParams["legend.markerscale"] = 2
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'


plt.yscale('log')
#plt.plot(b,rms9, color='orange' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa=5 × 10^{-6}$")
#plt.plot(b,rms8, color='darkviolet' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa=5 × 10^{-5}$")

plt.plot(b,rms5, color='magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa=0.5$")
plt.plot(b,rms3, color='olive' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa$=1.0")
#plt.plot(b,rms7, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa$=1.667")
plt.plot(b,rms1, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa$=2.5")
#plt.plot(b,rms6, color='grey' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa$=3.333")
plt.plot(b,rms2, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa$=5.0")
#plt.plot(b,rms3, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T50")
plt.plot(b,rms4, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$\kappa$=10")
#plt.plot(b,rms5, color='magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T100")
#plt.plot(b,rms1, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$v=0.02c_g$")
#plt.plot(b,rms2, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$v=0.1c_g$")
#plt.plot(b,rms3, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="$v=0.5c_g$")

#plt.plot(b,ratio, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T10")


ax.set_xlabel('step')
ax.set_ylabel('err')

plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=9,frameon=False)

fig.tight_layout()
#グラフ表示
plt.show()
#plt.figure(figsize=(5, 6))

# 保存するPDFファイル名
#pp = PdfPages(dir1+'test1.pdf')
pp = PdfPages('/Users/maeda/Desktop/test128.pdf')
# 画像をPDFとして保存する
pp.savefig(fig)
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")

ratio[100]

#np.savetxt('/Users/maeda/Desktop/mesh128.txt', rmsf)
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# 0.9003369

# %%
nx=128
ny=128
nz=128

n2=2

nd=19
nloop=11+1
step=2000/256/2


dir1  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir2  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir3  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir4  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir5  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'

dirn  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'


folder1="Phiwv"  #+ str(np.int(sample_frequency)) 
folder2="Phiexa"  #+ str(np.int(sample_frequency)) 


rms1 = [0] * nloop
rms2 = [0] * nloop
rms3 = [0] * nloop
rms4 = [0] * nloop
rms5 = [0] * nloop
rms6 = [0] * nloop
rms7 = [0] * nloop
rms8 = [0] * nloop
rms9 = [0] * nloop

rmsf = [0] * 5

#nms = [ndx-4] * 5

'''
rms6 = [0] * nloop
rms7 = [0] * nloop
rms8 = [0] * nloop
rms9 = [0] * nloop
'''
ratio = [0] * nloop

#b = np.arange(1-2, nloop-2)
b = np.arange(0-2, nloop-2)
b=b*step
for i in range(1,nloop):
    
    h5file1 = h5py.File(dir1+'AllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file2 = h5py.File(dir2+'BllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file3 = h5py.File(dir3+'CllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file4 = h5py.File(dir4+'DllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file5 = h5py.File(dir5+'EllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file6 = h5py.File(dirn+'FllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file7 = h5py.File(dirn+'GllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file8 = h5py.File(dirn+'HllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file9 = h5py.File(dirn+'ZllHDF'+"%03.f"%(i)+'.h5',"r")

    '''
    h5file6 = h5py.File(dir6+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file7 = h5py.File(dir7+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file8 = h5py.File(dir8+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file9 = h5py.File(dir9+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    '''
    
    #データ読み込み
    Phiwv1to1  = h5file1[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa1 = h5file1[folder2+"/Phiexa"].astype(np.float64)[:]
    mx1=np.max(Phiexa1)
    mn1=np.min(Phiexa1)
    
    Phiwv1to2  = h5file2[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa2  = h5file2[folder2+"/Phiexa"].astype(np.float64)[:]
    mx2=np.max(Phiexa2)
    mn2=np.min(Phiexa2)
    
    Phiwv1to3  = h5file3[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa3  = h5file3[folder2+"/Phiexa"].astype(np.float64)[:]
    mx3=np.max(Phiexa3)
    mn3=np.min(Phiexa3)
    
    Phiwv1to4  = h5file4[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa4  = h5file4[folder2+"/Phiexa"].astype(np.float64)[:]
    mx4=np.max(Phiexa4)
    mn4=np.min(Phiexa4)
    
    Phiwv1to5  = h5file5[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa5  = h5file5[folder2+"/Phiexa"].astype(np.float64)[:]
    mx5=np.max(Phiexa5)
    mn5=np.min(Phiexa5)
    
        
    Phiwv1to6  = h5file6[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa6  = h5file6[folder2+"/Phiexa"].astype(np.float64)[:]
    mx6=np.max(Phiexa6)
    mn6=np.min(Phiexa6)
    
        
    Phiwv1to7  = h5file7[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa7  = h5file7[folder2+"/Phiexa"].astype(np.float64)[:]
    mx7=np.max(Phiexa7)
    mn7=np.min(Phiexa7)
    
        
    Phiwv1to8  = h5file8[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa8  = h5file8[folder2+"/Phiexa"].astype(np.float64)[:]
    mx8=np.max(Phiexa5)
    mn8=np.min(Phiexa5)
    
        
    Phiwv1to9  = h5file9[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa9  = h5file9[folder2+"/Phiexa"].astype(np.float64)[:]
    mx9=np.max(Phiexa5)
    mn9=np.min(Phiexa5)
    
    
    #err=0.25*(rdata[6,:,:]+rdata[7,:,:]+rdata[8,:,:]+rdata[9,:,:])-rdata[12,:,:]
    err1=Phiwv1to1- Phiexa1
    err2=Phiwv1to2- Phiexa2
    err3=Phiwv1to3- Phiexa3
    err4=Phiwv1to4- Phiexa4
    err5=Phiwv1to5- Phiexa5

    err6=Phiwv1to6- Phiexa6
    err7=Phiwv1to7- Phiexa7
    err8=Phiwv1to8- Phiexa8
    err9=Phiwv1to9- Phiexa9

    rms1[i] = np.sqrt(np.mean(err1*err1))/(mx1-mn1)
    rms2[i] = np.sqrt(np.mean(err2*err2))/(mx2-mn2)
    rms3[i] = np.sqrt(np.mean(err3*err3))/(mx3-mn3)
    rms4[i] = np.sqrt(np.mean(err4*err4))/(mx4-mn4)
    rms5[i] = np.sqrt(np.mean(err5*err5))/(mx5-mn5)
    
    rms6[i] = np.sqrt(np.mean(err6*err6))/(mx6-mn6)
    rms7[i] = np.sqrt(np.mean(err7*err7))/(mx7-mn7)
    rms8[i] = np.sqrt(np.mean(err8*err8))/(mx8-mn8)
    rms9[i] = np.sqrt(np.mean(err9*err9))/(mx9-mn9)
    
    ratio[i]=rms1[i]/rms5[i]


rms1[2]=rms1[3]
rms2[2]=rms2[3]
rms3[2]=rms3[3]
rms4[2]=rms4[3]
rms5[2]=rms5[3]

rmsf[0] = rms1[1]
rmsf[1] = rms2[1]
rmsf[2] = rms3[1]
rmsf[3] = rms4[1]
rmsf[4] = rms5[1]


rms6[2]=rms6[3]
rms7[2]=rms7[3]
rms8[2]=rms8[3]
rms9[2]=rms9[3]
'''
rms1[0]=rms1[1]
rms2[0]=rms2[1]
rms3[0]=rms3[1]
'''
ratio[0] = 1

fig = plt.figure()
#fig.subplots_adjust(bottom=0.21)
#fig.subplots_adjust(left=0.1)
#fig.subplots_adjust(right=0)
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['mathtext.default'] = 'it'
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
plt.xlim([0.0, nloop*step]) # x方向の描画範囲を指定
plt.ylim([0.0001, 1.0]) # y方向の描画範囲を指定
plt.rcParams["legend.markerscale"] = 2
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'


plt.yscale('log')
#plt.plot(b,rms8, color='darkviolet' , linestyle = "dotted", markersize=2.5, linewidth = 1,label="n064v1.00")
#plt.plot(b,rms5, color='magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="n128v1.00")
#plt.plot(b,rms3, color='green' , linestyle = "dashed", markersize=2.5, linewidth = 1,label="n256v1.00")
plt.plot(b,rms5, color='magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="n128v1.00")
plt.plot(b,rms3, color='magenta' , linestyle = "dashed", markersize=2.5, linewidth = 1,label="n256v1.00")

#plt.plot(b,rms7, color='brown' , linestyle = "dotted", markersize=2.5, linewidth = 1,label="n064v0.10")
#plt.plot(b,rms9, color='orange' , linestyle = "solid", markersize=2.5, linewidth = 1,label="n128v0.10")
#plt.plot(b,rms1, color='red' , linestyle = "dashed", markersize=2.5, linewidth = 1,label="n256v0.10")
plt.plot(b,rms9, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="n128v0.10")
plt.plot(b,rms1, color='black' , linestyle = "dashed", markersize=2.5, linewidth = 1,label="n256v0.10")

#plt.plot(b,rms6, color='grey' , linestyle = "dotted", markersize=2.5, linewidth = 1,label="n064v0.01")
#plt.plot(b,rms4, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="n128v0.01")
#plt.plot(b,rms2, color='blue' , linestyle = "dashed", markersize=2.5, linewidth = 1,label="n256v0.01")
plt.plot(b,rms4, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="n128v0.01")
plt.plot(b,rms2, color='red' , linestyle = "dashed", markersize=2.5, linewidth = 1,label="n256v0.01")




ax.set_xlabel('step')
ax.set_ylabel('err')

plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=9,frameon=False)

fig.tight_layout()
#グラフ表示
plt.show()
#plt.figure(figsize=(5, 6))

# 保存するPDFファイル名
#pp = PdfPages(dir1+'test1.pdf')
pp = PdfPages('/Users/maedarn/Desktop/test128.pdf')
# 画像をPDFとして保存する
pp.savefig(fig)
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
#np.savetxt('/Users/maeda/Desktop/mesh128.txt', rmsf)
# Out:
# /var/folders/kw/hmy8d3gn14j8321d_1qs3ry40000gn/T/ipykernel_59307/773455545.py:143: RuntimeWarning: invalid value encountered in double_scalars
#   ratio[i]=rms1[i]/rms5[i]

# %%
nx=128
ny=128
nz=128


n2=0

nd=19
nloop=20+1
step=30000/128/2/nloop
errdsc=1.0/128.0/128.0
tjump=1

fac=2

slide=1




dir1  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir2  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir3  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir4  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'
dir5  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'

dirn  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/nerr/'



folder1="Phiwv" 
folder2="Phiexa" 

folder3="Err1"  
folder6="Err2"  
folder4="tErr1" 
folder5="tErr2" 
folder7="Errcnv" 


rms1 = [0] * nloop
rms2 = [0] * nloop
rms3 = [0] * nloop
rms4 = [0] * nloop
rms5 = [0] * nloop
rms6 = [0] * nloop
rms7 = [0] * nloop
rms8 = [0] * nloop
rms9 = [0] * nloop

nerr1 = [0] * nloop
nerr2 = [0] * nloop
nerr3 = [0] * nloop
nerr4 = [0] * nloop

rmsf = [0] * 5

#nms = [ndx-4] * 5

'''
rms6 = [0] * nloop
rms7 = [0] * nloop
rms8 = [0] * nloop
rms9 = [0] * nloop
'''
ratio = [0] * nloop


i=nloop-1
h5file1cnv = h5py.File(dir1+'QGllHDF'+"%03.f"%(i)+'.h5',"r")
h5file2cnv = h5py.File(dir1+'QHllHDF'+"%03.f"%(i)+'.h5',"r")
h5file3cnv = h5py.File(dir1+'PTllHDF'+"%03.f"%(i)+'.h5',"r")
h5file4cnv = h5py.File(dir1+'PSllHDF'+"%03.f"%(i)+'.h5',"r")

Phicnv  = h5file1cnv[folder1+"/Phiwv1"].astype(np.float64)[:]
Phicnvn  = h5file2cnv[folder1+"/Phiwv1"].astype(np.float64)[:]
Phicnvo = h5file3cnv[folder1+"/Phiwv1"].astype(np.float64)[:]
Phicnvp  = h5file4cnv[folder1+"/Phiwv1"].astype(np.float64)[:]


#b = np.arange(1-2, nloop-2)
b = np.arange(-slide, nloop-slide)
b=b*step
for i in range(1,nloop,tjump):
    
    h5file1 = h5py.File(dir1+'QGllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file2 = h5py.File(dir1+'QHllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file3 = h5py.File(dir1+'PTllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file4 = h5py.File(dir1+'PSllHDF'+"%03.f"%(i)+'.h5',"r")

    '''
    h5file6 = h5py.File(dir6+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file7 = h5py.File(dir7+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file8 = h5py.File(dir8+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    h5file9 = h5py.File(dir9+'NAllHDF'+"%03.f"%(i)+'.h5',"r")
    '''
    
    #データ読み込み
    Phiwv1to1  = h5file1[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa1 = h5file1[folder2+"/Phiexa"].astype(np.float64)[:]
    mx1=np.max(Phiexa1)
    mn1=np.min(Phiexa1)
    
    Phierr1 = h5file1[folder3+"/Err1"].astype(np.float64)[:]
    Phierr2 = h5file1[folder6+"/Err2"].astype(np.float64)[:]
    tPhierr1 = h5file1[folder4+"/tErr1"].astype(np.float64)[:]
    #tPhierr2 = h5file1[folder5+"/tErr2"].astype(np.float64)[:]
    
    
    Phiwv1to1n  = h5file2[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa1n = h5file2[folder2+"/Phiexa"].astype(np.float64)[:]
    mx1n=np.max(Phiexa1n)
    mn1n=np.min(Phiexa1n)
    
    Phierr1n = h5file2[folder3+"/Err1"].astype(np.float64)[:]
    Phierr2n = h5file2[folder6+"/Err2"].astype(np.float64)[:]
    tPhierr1n = h5file2[folder4+"/tErr1"].astype(np.float64)[:]
    #tPhierr2n = h5file2[folder5+"/tErr2"].astype(np.float64)[:]
    
    Phiwv1to1o  = h5file3[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa1o = h5file3[folder2+"/Phiexa"].astype(np.float64)[:]
    mx1o=np.max(Phiexa1o)
    mn1o=np.min(Phiexa1o)
    
    Phierr1o = h5file3[folder3+"/Err1"].astype(np.float64)[:]
    Phierr2o = h5file3[folder6+"/Err2"].astype(np.float64)[:]
    tPhierr1o = h5file3[folder4+"/tErr1"].astype(np.float64)[:]
    #tPhierr2o = h5file3[folder5+"/tErr2"].astype(np.float64)[:]
    
    Phiwv1to1p  = h5file4[folder1+"/Phiwv1"].astype(np.float64)[:]
    Phiexa1p = h5file4[folder2+"/Phiexa"].astype(np.float64)[:]
    mx1p=np.max(Phiexa1p)
    mn1p=np.min(Phiexa1p)
    
    Phierr1p = h5file4[folder3+"/Err1"].astype(np.float64)[:]
    Phierr2p = h5file4[folder6+"/Err2"].astype(np.float64)[:]
    tPhierr1p = h5file4[folder4+"/tErr1"].astype(np.float64)[:]
    #tPhierr2p = h5file4[folder5+"/tErr2"].astype(np.float64)[:]
    Phierrcnvp = h5file4[folder7+"/Errcnv"].astype(np.float64)[:]

    
    
    #err=0.25*(rdata[6,:,:]+rdata[7,:,:]+rdata[8,:,:]+rdata[9,:,:])-rdata[12,:,:]

    
    err1=Phiwv1to1- Phicnv#Phiexa1
    err2=Phiwv1to1n- Phicnvn#Phiexa1n
    err3=Phiwv1to1o- Phicnvo#Phiexa1o
    err4=Phiwv1to1p- Phicnvp#Phiexa1p
    

    #rms1[math.floor(i/tjump)] = np.sqrt(np.mean(err1*err1))/(mx1-mn1)
    #rms2[math.floor(i/tjump)] = np.sqrt(np.mean(Phierr1*Phierr1))
    #rms3[math.floor(i/tjump)] = np.sqrt(np.mean(tPhierr1*tPhierr1))
    #rms4[math.floor(i/tjump)] = np.sqrt(np.mean(tPhierr2*tPhierr2))
    rms1[i] = np.sqrt(np.mean(Phierr2*Phierr2))
    rms2[i] = np.sqrt(np.mean(Phierr2n*Phierr2n))
    rms3[i] = np.sqrt(np.mean(Phierr2o*Phierr2o))
    rms4[i] = np.sqrt(np.mean(Phierr2p*Phierr2p))
    rms5[i] = np.sqrt(np.mean(Phierr2*Phierr2))/4.0
    rms6[i] = np.sqrt(np.mean(Phierr2n*Phierr2n))/4.0
    rms7[i] = np.sqrt(np.mean(Phierrcnvp*Phierrcnvp))
    
    nerr1[i] = np.sqrt(np.mean(err1*err1))/(mx1-mn1)
    nerr2[i] = np.sqrt(np.mean(err2*err2))/(mx1n-mn1n)
    nerr3[i] = np.sqrt(np.mean(err3*err3))/(mx1o-mn1o)
    nerr4[i] = np.sqrt(np.mean(err4*err4))/(mx1p-mn1p)
    #ratio[i]=rms1[i]/rms5[i]


rms1[1]=nerr1[1]
rms2[1]=nerr2[1]*3.0
rms3[1]=nerr3[1]*3.0
rms4[1]=nerr4[1]
#rms5[1]=0.1

#rmsf[0] = rms1[1]
#rmsf[1] = rms2[1]
#rmsf[2] = rms3[1]
#rmsf[3] = rms4[1]
#rmsf[4] = rms5[1]


#rms6[2]=rms6[3]
#rms7[2]=rms7[3]
#rms8[2]=rms8[3]
#rms9[2]=rms9[3]
'''
rms1[0]=rms1[1]
rms2[0]=rms2[1]
rms3[0]=rms3[1]
'''
ratio[0] = 1

fig = plt.figure()
#fig.subplots_adjust(bottom=0.21)
#fig.subplots_adjust(left=0.1)
#fig.subplots_adjust(right=0)
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['mathtext.default'] = 'it'
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.xlim([0.0, (nloop-1)*(step)/tjump]) # x方向の描画範囲を指定
plt.xlim([0.0, 100.0]) # x方向の描画範囲を指定
plt.ylim([1e-4, 1.0]) # y方向の描画範囲を指定
plt.rcParams["legend.markerscale"] = 2
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'

plt.yscale('log')

#plt.plot(b,rms1, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err_an")
#plt.plot(b,rms2, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err_dis")
#plt.plot(b,rms3, color='magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err/dt")
#plt.plot(b,rms4, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err/dt/dt")
#plt.plot(b,nerr1, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err_an")
#plt.plot(b,nerr2, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err_dis")
plt.plot(b,rms3, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err/dt")
#plt.plot(b,nerr4, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err/dt/dt")
#plt.plot(b,rms5, color='brown' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err_dis")
#plt.plot(b,rms6, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="err_dis")
#p = plt.plot([0.0, 60.0],[errdsc, errdsc], "green", linestyle='dashed') # normal way

ax.set_xlabel('step')
ax.set_ylabel('err')

plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=9,frameon=False)

fig.tight_layout()
#グラフ表示
plt.show()
#plt.figure(figsize=(5, 6))

# 保存するPDFファイル名
#pp = PdfPages(dir1+'test1.pdf')
pp = PdfPages('/Users/maedarn/Desktop/test128.pdf')
# 画像をPDFとして保存する
pp.savefig(fig)
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
#np.savetxt('/Users/maeda/Desktop/mesh128.txt', rmsf)
print(nerr4)
# Out:
# [0, 0.8315553279795118, 0.09920275130399225, 0.005699528878263181, 0.0005790241925864932, 5.334880119926147e-05, 4.784511003374643e-06, 4.253478259652983e-07, 3.653451176674214e-08, 3.271458752774723e-09, 2.9071899221135224e-10, 2.5820068318987332e-11, 2.2962219436295994e-12, 2.0465078147904228e-13, 1.8574344734891523e-14, 2.070747209525282e-15, 7.305433144779212e-16, 7.025598103486684e-16, 7.010247523591835e-16, 7.01793974122272e-16, 0.0]
