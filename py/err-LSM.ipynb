# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages


im = 2
jm = 4125
km=19433
dir = '/Users/maeda/Desktop/'

k20err=[0] * 3
#k20err=[0] * 4

k10err=[0] * 3
k50err=[0] * 3
k5err=[0] * 3
k100err=[0] * 3

msh=[0] * 3
#msh=[0] * 4


#k20err[0]=5.938533227890729904e-03
#k20err[1]=1.898119342513382435e-03
#20err[2]=1.082548638805747032e-03

#k20err[0]=1.467350986786186695e-03
#k20err[1]=6.860630819573998451e-04

#k20err[0]=1.378911663778126240e-03 
#k20err[1]=6.592101417481899261e-04
#k20err[2]=3.174670855514705181e-04

#k20err[0]=1.312663429416716099e-03
#k20err[1]=6.274526822380721569e-04
#k20err[2]=3.260703233536332846e-04

#k20err[0]=1.405453891493380070e-03
#k20err[1]=6.713665788993239403e-04

#k20err[2]=2.804053656291216612e-04
#k20err[3]=1.238898548763245344e-04

#k20err[0]=1.571042230352759361e-03
#k20err[1]=6.481706514023244381e-04
#k20err[2]=9.087398939300328493e-05

#k20err[0]=5.975505337119102478e-03  #this
#k20err[1]=7.994701736606657505e-04  #this
#k20err[2]=1.081753143807873130e-04  #this

#k20err[0]=9.702469687908887863e-04
#k20err[1]=2.735581656452268362e-04
#k20err[2]=1.081753143807873130e-04

k20err[0]=5.823193583637475967e-03
k20err[1]=7.850217516534030437e-04
k20err[2]=9.601427154848352075e-05

#k20err[0]=1.702184206806123257e-03
#k20err[1]=7.749282522127032280e-04
#k20err[2]=2.593076787889003754e-04



k10err[0]=5.823193583637475967e-03
k10err[1]=7.850217516534030437e-04
k10err[2]=9.601427154848352075e-05

k50err[0]=5.629010032862424850e-03
k50err[1]=7.810922106727957726e-04
k50err[2]=8.816869376460090280e-05

k5err[0]=5.562338512390851974e-03
k5err[1]=8.015199564397335052e-04
k5err[2]=8.904017158783972263e-05

k100err[0]=5.669934209436178207e-03
k100err[1]=8.301729685626924038e-04
k100err[2]=9.169646364171057940e-05


msh[0]=64.0
msh[1]=128.0
msh[2]=256.0
#msh[3]=512.0



fig = plt.figure()
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ


#plt.yscale('log')
#plt.xscale('log')

lgk20err=np.log10(k20err)
#lgk20err=np.e ** (lgk20err)
lgmsh=np.log10(msh)


lgk100err=np.log10(k100err)
lgk10err=np.log10(k10err)
lgk50err=np.log10(k50err)
lgk5err=np.log10(k5err)
#lgk20err=np.e ** (lgk20err)


plt.scatter(lgmsh, lgk100err, s=10.0,c='red')
plt.scatter(lgmsh, lgk50err, s=10.0,c='blue')
plt.scatter(lgmsh, lgk20err, s=10.0,c='green')
#plt.scatter(lgmsh, lgk5err, s=3.0,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)

plt.scatter(lgmsh, lgk10err, s=10.0,c='black')
plt.scatter(lgmsh, lgk5err, s=10.0,c='magenta')
#plt.scatter(lgmsh, lgk50err, s=5.0,c='blue')
#plt.scatter(lgmsh, lgk100err, s=5.0,c='red')

#plt.scatter(msh, k5err, s=3.0,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)
#plt.scatter(msh, k10err, s=3.0,c='blue')
#plt.scatter(msh, k20err, s=3.0,c='black')
#plt.scatter(msh, k50err, s=3.0,c='green')
#plt.scatter(msh, k100err, s=3.0,c='green')

#lgk20err=np.log(k20err)
#lgk20err=np.e ** (lgk20err)
#lgmsh=np.log(msh)
#lgmsh=np.e ** (lgmsh)

lgmsh[0]

coef_20 = np.polyfit(lgmsh,lgk20err,1) #係数
y_pred_20 = coef_20[0]*lgmsh+ coef_20[1] #フィッティング関数


coef_10 = np.polyfit(lgmsh,lgk10err,1) #係数
y_pred_10 = coef_10[0]*lgmsh+ coef_10[1] #フィッティング関数

coef_50 = np.polyfit(lgmsh,lgk50err,1) #係数
y_pred_50 = coef_50[0]*lgmsh+ coef_50[1] #フィッティング関数

coef_100 = np.polyfit(lgmsh,lgk100err,1) #係数
y_pred_100 = coef_100[0]*lgmsh+ coef_100[1] #フィッティング関数

coef_5 = np.polyfit(lgmsh,lgk5err,1) #係数
y_pred_5 = coef_5[0]*lgmsh+ coef_5[1] #フィッティング関数


#plt.plot(lgmsh,y_pred_100,color='red',label='$\kappa=0.5$') #1次式
#plt.plot(lgmsh,y_pred_50,c='blue',label='$\kappa=1.0$') #1次式
#plt.plot(lgmsh,y_pred_20,c='green',label='$\kappa=2.5$') #1次式
#plt.plot(lgmsh,y_pred_10,",c='black',label='$\kappa=5.0$') #1次式
#plt.plot(lgmsh,y_pred_5,c='magenta',label='$\kappa=10$') #1次式

#plt.plot(lgmsh,y_pred_100,label="d=1",color='red') #1次式
#plt.plot(lgmsh,y_pred_50,label="d=1",c='blue') #1次式
#plt.plot(lgmsh,y_pred_20,label="d=1",c='green') #1次式
#plt.plot(lgmsh,y_pred_10,label="d=1",c='black') #1次式
#plt.plot(lgmsh,y_pred_5,label="d=1",c='magenta') #1次式






#plt.scatter(R91, vesc91, s=0.1,c='blue')
#plt.xlim([0.0, 60.0]) # x方向の描画範囲を指定
#plt.ylim([0.0001, 0.01]) # y方向の描画範囲を指定
#plt.xticks(0.0, 50.0, 6)
#plt.yticks(0, 20, 4)
#ax.set_title('Scatter plot')
ax.set_xlabel('Cell')
ax.set_ylabel('err')
#ax.plot(t, y1, color=c1, label=l1)
#ax.plot(t, y2, color=c2, label=l2)
#ax.plot(t, y3, color=c3, label=l3)
#ax.plot(t, y4, color=c4, label=l4)
#ax.legend(loc=0)    # 凡例
#fig.tight_layout()  # レイアウトの設定
# plt.savefig('hoge.png') # 画像の保存
#plt.show()
#plt.xticks(np.arange(0, 60 + 1, 10))
#plt.yticks(np.arange(0, 20 + 1, 5))
#p = plt.plot([0.0, 60.0],[10.0, 10.0], "black", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[7.6, 7.6], "red", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[12.7, 12.7], "blue", linestyle='dashed') # normal way

#x = np.arange(60, 1000, 0.1)
x = np.arange(100, 200, 0.1)
x=np.log10(x)
y = -(x) * 3.0 + 4.0
plt.plot(x, y ,c='purple',label='$-3$')


# 保存するPDFファイル名
pp = PdfPages('/Users/maeda/Desktop/err.pdf')
# 画像をPDFとして保存する
pp.savefig(fig, bbox_inches='tight')
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
                    
#plt.savefig("R-Vesc.png")
lgk20err

coef_20,coef_10,coef_50,coef_100,coef_5
# Out:
# (array([-2.96120895,  3.12068193]),
#  array([-2.96120895,  3.12068193]),
#  array([-2.99823546,  3.1807279 ]),
#  array([-2.97516104,  3.14765541]),
#  array([-2.98254568,  3.15110258]))

# %%
tmyr=[0] * 9
rmax=[0] * 9

tmyr[0]=66/4.0   
rmax[0]=194757.391    
tmyr[1]=70/4.0   
rmax[1]=888624.000    
tmyr[2]=74/4.0   
rmax[2]=1769469.00    
tmyr[3]=78/4.0   
rmax[3]=2597706.75    
tmyr[4]=82/4.0   
rmax[4]=5033376.00    
tmyr[5]=86/4.0   
rmax[5]=4691714.50    
tmyr[6]=90/4.0   
rmax[6]=19552340.0    
tmyr[7]=94/4.0   
rmax[7]=40198368.0    
tmyr[8]=98/4.0   
rmax[8]=25852060.0

# %%
fig = plt.figure()
#ax = fig.add_subplot(111)
#ax1 = fig.add_subplot(111)
ax = fig.add_subplot(1,1,1)


ax.set_yscale('log')  # y軸をlogスケールで描く
#ax.set_xscale('log')  # x軸をlogスケールで描く
ax.set_xlim([15, 25]) # x方向の描画範囲を指定
ax.set_ylim([100000, 100000000])    # y方向の描画範囲を指定
p = plt.plot(tmyr , rmax, "black", linestyle='dashed') # normal way

                    
                    
plt.savefig("foo1.png")

# %%
a1=11.0*(0.1)**(0.333333)*(10)**(-0.6666666)
a1=11.0*(1.6)**(0.333333)*(50000)**(-0.6666666)

print (a1)
# Out:
# 0.009479517988755017

# %%
a2=a1*(1+7.0/4.0*15.0*0.45/a1*np.sqrt(4.0/3.0))**(4.0/7.0)
a4=a1*(1+7.0/4.0*10.0*0.45/a1*np.sqrt(4.0/3.0))**(4.0/7.0)
a3=a1*(1+7.0/4.0*15.0*0.45/a1)**(4.0/7.0)

er1=(a4-4.1)/a4
print (a2,a3,a4,er1)
# Out:
# 4.846755107401711 4.493688472467889 3.9257170825201335 -0.04439518024767703
