# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.animation as animation
from matplotlib.animation import ArtistAnimation

dir1 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T10-rho1-cen-128/'
dir2 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T100-rho1-cen-128/'
dir3 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T1-rho1-cen-128/'

dir4 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T10-rho1-cen-128-1000st/'
dir5 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T20-rho1-cen-128-1000st/'
dir6 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T30-rho1-cen-128-1000st/'
dir7 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T40-rho1-cen-128-1000st/'
dir8 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T50-rho1-cen-128-1000st/'

dir9 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T5-rho1-cen-128-1000st/'

dir10 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T22-rho1-cen-128-1000st/'

dir11 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T18-rho1-cen-128-1000st/'
dir12 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T16-rho1-cen-128-1000st/'
dir13 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T14-rho1-cen-128-1000st/'
dir14 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho1-cen-128-1000st/'

dir15 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T13-rho1-cen-128-1000st/'

dir16 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho100-cen-128-1000st/'
dir17 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho1-s-cen-128-1000st/'
dir18 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho1-b-cen-128-1000st/'
dir19 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho1-ncen-128-1000st/'

dir20 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T9-rho1-cen-128-1000st/'
dir21 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T8-rho1-cen-128-1000st/'
dir22 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T7-rho1-cen-128-1000st/'
dir23 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T6-rho1-cen-128-1000st/'

dir24 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T11-rho1-cen-128-1000st/'

dir25 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho1-cen-128-2000st/'
dir26 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho1-cen-64-1000st/'
dir27 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T12-rho1-cen-129-1000st/'


dir32 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T5-rho1-cen-64-1000st/'
dir33 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T-1-rho1-cen-64-1000st/'

dir34 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T100-rho1-cen-128-1000st/'

dir35 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T10-rho1-ncen-128-1000st/'
dir36 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T20-rho1-ncen-128-1000st/'
dir37 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T30-rho1-ncen-128-1000st/'
dir38 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T40-rho1-ncen-128-1000st/'

dir39 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-1D-1/cg1-T10-rho1-cen-128-1000st/'
dir40 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-1D-1/cg1-T20-rho1-cen-128-1000st/'
dir41 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-1D-1/cg1-T30-rho1-cen-128-1000st/'
dir42 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-1D-1/cg1-T40-rho1-cen-128-1000st/'
dir43 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-1D-1/cg1-T1-rho1-cen-128-1000st/'
dir44 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-1D-1/cg1-T01-rho1-cen-128-1000st/'

dir28 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T20-rho1-cen-64-1000st/'
dir29 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T30-rho1-cen-64-1000st/'
dir30 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T40-rho1-cen-64-1000st/'
dir31 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T10-rho1-cen-64-1000st/'
dir45 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T1-rho1-cen-64-1000st/'
dir46 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T3-rho1-cen-64-1000st/'
dir47 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T2-rho1-cen-64-1000st/'

dir48 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T10-rho1-cen-32-1000st/'
dir49 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T100-rho1-cen-32-1000st/'
dir50 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T50-rho1-cen-32-1000st/'
dir51 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T1-rho1-cen-32-1000st/'
dir52 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T5-rho1-cen-32-1000st/'
dir53 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T20-rho1-cen-32-1000st/'

dir54 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T10-rho1-outcen-128-1000st/'
dir55 = '/Users/maeda/Desktop/Dropbox/analysis/telegraph-test-2D-1/cg1-T20-rho1-outcen-128-1000st/'

data01,data02,data03,data04 = np.loadtxt(dir1+'err-phi.dat', delimiter=',', unpack=True)
eata01,eata02,eata03,eata04 = np.loadtxt(dir2+'err-phi.dat', delimiter=',', unpack=True)
fata01,fata02,fata03,fata04 = np.loadtxt(dir3+'err-phi.dat', delimiter=',', unpack=True)

gata01,gata02,gata03,gata04 = np.loadtxt(dir4+'err-phi-exa18.dat', delimiter=',', unpack=True)
hata01,hata02,hata03,hata04 = np.loadtxt(dir5+'err-phi-exa18.dat', delimiter=',', unpack=True)
iata01,iata02,iata03,iata04 = np.loadtxt(dir6+'err-phi-exa18.dat', delimiter=',', unpack=True)
jata01,jata02,jata03,jata04 = np.loadtxt(dir7+'err-phi-exa18.dat', delimiter=',', unpack=True)
kata01,kata02,kata03,kata04 = np.loadtxt(dir8+'err-phi-exa18.dat', delimiter=',', unpack=True)

lata01,lata02,lata03,lata04 = np.loadtxt(dir9+'err-phi-exa18.dat', delimiter=',', unpack=True)

mata01,mata02,mata03,mata04 = np.loadtxt(dir10+'err-phi.dat', delimiter=',', unpack=True)

nata01,nata02,nata03,nata04 = np.loadtxt(dir11+'err-phi-exa.dat', delimiter=',', unpack=True)
oata01,oata02,oata03,oata04 = np.loadtxt(dir12+'err-phi-exa.dat', delimiter=',', unpack=True)
pata01,pata02,pata03,pata04 = np.loadtxt(dir13+'err-phi-exa.dat', delimiter=',', unpack=True)
qata01,qata02,qata03,qata04 = np.loadtxt(dir14+'err-phi-exa.dat', delimiter=',', unpack=True)

rata01,rata02,rata03,rata04 = np.loadtxt(dir15+'err-phi.dat', delimiter=',', unpack=True)

sata01,sata02,sata03,sata04 = np.loadtxt(dir16+'err-phi.dat', delimiter=',', unpack=True)
tata01,tata02,tata03,tata04 = np.loadtxt(dir17+'err-phi.dat', delimiter=',', unpack=True)
uata01,uata02,uata03,uata04 = np.loadtxt(dir18+'err-phi.dat', delimiter=',', unpack=True)
vata01,vata02,vata03,vata04 = np.loadtxt(dir19+'err-phi.dat', delimiter=',', unpack=True)

wata01,wata02,wata03,wata04 = np.loadtxt(dir20+'err-phi-exa.dat', delimiter=',', unpack=True)
xata01,xata02,xata03,xata04 = np.loadtxt(dir21+'err-phi-exa.dat', delimiter=',', unpack=True)
yata01,yata02,yata03,yata04 = np.loadtxt(dir22+'err-phi-exa.dat', delimiter=',', unpack=True)
zata01,zata02,zata03,zata04 = np.loadtxt(dir23+'err-phi-exa.dat', delimiter=',', unpack=True)

aata01,aata02,aata03,aata04 = np.loadtxt(dir24+'err-phi.dat', delimiter=',', unpack=True)

bata01,bata02,bata03,bata04 = np.loadtxt(dir25+'err-phi.dat', delimiter=',', unpack=True)
cata01,cata02,cata03,cata04 = np.loadtxt(dir26+'err-phi.dat', delimiter=',', unpack=True)
ddata01,ddata02,ddata03,ddata04 = np.loadtxt(dir27+'err-phi.dat', delimiter=',', unpack=True)


idata01,idata02,idata03,idata04 = np.loadtxt(dir32+'err-phi-exa.dat', delimiter=',', unpack=True)
jdata01,jdata02,jdata03,jdata04 = np.loadtxt(dir33+'err-phi-exa.dat', delimiter=',', unpack=True)

kdata01,kdata02,kdata03,kdata04 = np.loadtxt(dir34+'err-phi-exa.dat', delimiter=',', unpack=True)

ldata01,ldata02,ldata03,ldata04 = np.loadtxt(dir35+'err-phi-exa.dat', delimiter=',', unpack=True)
mdata01,mdata02,mdata03,mdata04 = np.loadtxt(dir36+'err-phi-exa.dat', delimiter=',', unpack=True)
ndata01,ndata02,ndata03,ndata04 = np.loadtxt(dir37+'err-phi-exa.dat', delimiter=',', unpack=True)
odata01,odata02,odata03,odata04 = np.loadtxt(dir38+'err-phi-exa.dat', delimiter=',', unpack=True)

pdata01,pdata02,pdata03 = np.loadtxt(dir39+'err-phi-exa2.dat', delimiter=',', unpack=True)
qdata01,qdata02,qdata03 = np.loadtxt(dir40+'err-phi-exa2.dat', delimiter=',', unpack=True)
rdata01,rdata02,rdata03 = np.loadtxt(dir41+'err-phi-exa2.dat', delimiter=',', unpack=True)
sdata01,sdata02,sdata03 = np.loadtxt(dir42+'err-phi-exa2.dat', delimiter=',', unpack=True)
tdata01,tdata02,tdata03 = np.loadtxt(dir43+'err-phi-exa2.dat', delimiter=',', unpack=True)
udata01,udata02,udata03 = np.loadtxt(dir44+'err-phi-exa2.dat', delimiter=',', unpack=True)

edata01,edata02,edata03,edata04 = np.loadtxt(dir28+'err-phi-exa22.dat', delimiter=',', unpack=True)
fdata01,fdata02,fdata03,fdata04 = np.loadtxt(dir29+'err-phi-exa.dat', delimiter=',', unpack=True)
gdata01,gdata02,gdata03,gdata04 = np.loadtxt(dir30+'err-phi-exa22.dat', delimiter=',', unpack=True)
hdata01,hdata02,hdata03,hdata04 = np.loadtxt(dir31+'err-phi-exa22.dat', delimiter=',', unpack=True)
vdata01,vdata02,vdata03,vdata04 = np.loadtxt(dir45+'err-phi-exa.dat', delimiter=',', unpack=True)
wdata01,wdata02,wdata03,wdata04 = np.loadtxt(dir46+'err-phi-exa.dat', delimiter=',', unpack=True)
xdata01,xdata02,xdata03,xdata04 = np.loadtxt(dir47+'err-phi-exa.dat', delimiter=',', unpack=True)


ydata01,ydata02,ydata03,ydata04 = np.loadtxt(dir48+'err-phi-exa2.dat', delimiter=',', unpack=True)
zdata01,zdata02,zdata03,zdata04 = np.loadtxt(dir49+'err-phi-exa.dat', delimiter=',', unpack=True)
deata01,deata02,deata03,deata04 = np.loadtxt(dir50+'err-phi-exa2.dat', delimiter=',', unpack=True)
eeata01,eeata02,eeata03,eeata04 = np.loadtxt(dir51+'err-phi-exa2.dat', delimiter=',', unpack=True)
feata01,feata02,feata03,feata04 = np.loadtxt(dir52+'err-phi-exa2.dat', delimiter=',', unpack=True)
geata01,geata02,geata03,geata04 = np.loadtxt(dir53+'err-phi-exa2.dat', delimiter=',', unpack=True)

heata01,heata02,heata03,heata04 = np.loadtxt(dir54+'err-phi-exa6.dat', delimiter=',', unpack=True)
ieata01,ieata02,ieata03,ieata04 = np.loadtxt(dir55+'err-phi-exa6.dat', delimiter=',', unpack=True)

# %%
fig = plt.figure()
#fig.subplots_adjust(bottom=0.21)
#fig.subplots_adjust(left=0.1)
#fig.subplots_adjust(right=0)
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['mathtext.default'] = 'it'
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ
plt.xlim([-1.0, 2000.0]) # x方向の描画範囲を指定
plt.ylim([0.001, 1.0]) # y方向の描画範囲を指定
plt.rcParams["legend.markerscale"] = 2
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'

#plt.figure(1)
'''
plt.plot(data[data_col[0]],data[data_col[6]],marker="o")
plt.plot(data[data_col[0]],data[data_col[7]],marker="o")
plt.plot(data[data_col[0]],data[data_col[8]]*100,marker="o")
plt.plot(data[data_col[0]],data[data_col[9]],marker="o")
'''
plt.yscale('log')
#plt.plot(data01,data02/128, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T10")
#plt.plot(eata01,eata02/128, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T100")
#plt.plot(fata01,fata02/128, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T1")

#plt.plot(kdata01,kdata02, color='green'  , linestyle = "solid", markersize=2.5, linewidth = 1,label="T100-1000st")
#plt.plot(kata01,kata02, color='green'  , linestyle = "solid", markersize=2.5, linewidth = 1,label="T50-1000st")
#plt.plot(jata01,jata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T40-1000st")
#plt.plot(iata01,iata02, color='Magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T30-1000st")
#plt.plot(hata01,hata02, color='Cyan' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T20-1000st")
#plt.plot(gata01,gata02, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T10-1000st")

#plt.plot(xata01,xata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T8-1000st")

#plt.plot(lata01,lata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T5-1000st")

#plt.plot(mata01,mata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T22-1000st")

#plt.plot(nata01,nata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T18-1000st")
#plt.plot(oata01,oata02, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T16-1000st")
#plt.plot(pata01,pata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T14-1000st")
#plt.plot(qata01,qata02, color='#8c564b'  , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-1000st")

#plt.plot(rata01,rata02, color='#9467bd'  , linestyle = "solid", markersize=2.5, linewidth = 1,label="T13-1000st")

#plt.plot(wata01,wata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T9-1000st")
#plt.plot(xata01,xata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T8-1000st")
#plt.plot(yata01,yata02, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T7-1000st")
#plt.plot(zata01,zata02, color='Yellow' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T6-1000st")

#plt.plot(aata01,aata02, color='#7f7f7f' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T11-1000st")

#plt.plot(sata01,sata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-rho100-1000st")
#plt.plot(tata01,tata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-s-1000st")
#plt.plot(uata01,uata02, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-b-1000st")
#plt.plot(vata01,vata02, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-n-1000st")

#plt.plot(bata01,bata02, color='Cyan' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-2000st")
#plt.plot(cata01,cata02, color='Yellow' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-64-1000st")
#plt.plot(ddata01,ddata02, color='Magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T12-129-1000st")

plt.plot(edata01,edata02, color='Cyan' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T20-64-1000st")
#plt.plot(fdata01,fdata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T30-64-1000st")
plt.plot(gdata01,gdata02, color='Magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T40-64-1000st")
plt.plot(hdata01,hdata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T10-64-1000st")
#plt.plot(vdata01,vdata02, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T1-64-1000st")
#plt.plot(wdata01,wdata02, color='yellow' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T3-64-1000st")
#plt.plot(xdata01,xdata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T2-64-1000st")

#plt.plot(ldata01,ldata02, color='Cyan' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T10-128-ncen-1000st")
#plt.plot(mdata01,mdata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T20-128-ncen-1000st")
#plt.plot(ndata01,ndata02, color='Magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T30-128-ncen-1000st")
#plt.plot(odata01,odata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T40-128-ncen-1000st")

#plt.plot(pdata01,pdata02, color='Cyan' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T10-128-cen-1000st-1D")
#plt.plot(qdata01,qdata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T20-128-cen-1000st-1D")
#plt.plot(rdata01,rdata02, color='Magenta' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T30-128-cen-1000st-1D")
#plt.plot(sdata01,sdata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T40-128-cen-1000st-1D")
#plt.plot(tdata01,tdata02, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T1-128-cen-1000st-1D")
#plt.plot(udata01,udata02, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T01-128-cen-1000st-1D")

#plt.plot(idata01,idata02, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T5-64-1000st")
#plt.plot(jdata01,jdata02, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T-1-64-1000st")

#plt.plot(ydata01,ydata02, color='black' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T-10-32-1000st")
#plt.plot(zdata01,zdata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T-100-32-1000st")
#plt.plot(deata01,deata02, color='blue' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T-50-32-1000st")
#plt.plot(eeata01,eeata02, color='green' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T-1-32-1000st")
#plt.plot(feata01,feata02, color='yellow' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T-5-32-1000st")
#plt.plot(geata01,geata02, color='Cyan' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T-5-32-1000st")

#plt.plot(heata01,heata02, color='red' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T10-128-out-1000st")
#plt.plot(ieata01,ieata02, color='Cyan' , linestyle = "solid", markersize=2.5, linewidth = 1,label="T20-128-out-1000st")

#グラフの軸
#plt.xlabel(data[data_col[0]].name)
#plt.ylabel(data[data_col[1]].name)
#plt.ylabel(data[data_col[7]].name)
#ax.set_title('Scatter plot')
ax.set_xlabel('step')
ax.set_ylabel('err')

#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=5,frameon=False)
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0, fontsize=9,frameon=False)

#plt.xticks(np.arange(0, 60 + 1, 10))
#plt.yticks(np.arange(0, 20 + 1, 5))
#p = plt.plot([0.0, 60.0],[10.0, 10.0], "black", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[7.6, 7.6], "red", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[12.7, 12.7], "blue", linestyle='dashed') # normal way
fig.tight_layout()
#グラフ表示
plt.show()
#plt.figure(figsize=(5, 6))

# 保存するPDFファイル名
pp = PdfPages('/Users/maeda/Desktop/test.pdf')
# 画像をPDFとして保存する
pp.savefig(fig)
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
