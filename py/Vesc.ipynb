# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages


im = 2
jm = 85
#km=19433
dir = '/Users/maeda/Desktop/'

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f90 = open(dir+'Dropbox/analysis/samplecnvS/Masstime084001.DAT','rb')
ary = np.fromfile(f90, np.float32,count=im*jm)
#ary91 = np.fromfile(f91, np.float32,count=im*km)
uvhpy = ary.reshape(im,jm,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')

#R=uvhpy[0,:]
time=uvhpy[0,:]
mass=uvhpy[1,:]
#vesc=uvhpy[1,:]
#T=uvhpy[2,:]
#R91=uvhpy91[0,:]
#vesc91=uvhpy91[1,:]

fig = plt.figure()
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ



plt.scatter(time, mass, s=0.1,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)
#plt.scatter(R, vesc, s=0.1,c='blue')
plt.xlim([0.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([0.0, 250000.0]) # y方向の描画範囲を指定
#plt.xticks(0.0, 50.0, 6)
#plt.yticks(0, 20, 4)
#ax.set_title('Scatter plot')
ax.set_xlabel('Radius [pc]')
ax.set_ylabel('Escape velocity [km s$^{-1}$]')
#ax.plot(t, y1, color=c1, label=l1)
#ax.plot(t, y2, color=c2, label=l2)
#ax.plot(t, y3, color=c3, label=l3)
#ax.plot(t, y4, color=c4, label=l4)
#ax.legend(loc=0)    # 凡例
#fig.tight_layout()  # レイアウトの設定
# plt.savefig('hoge.png') # 画像の保存
#plt.show()
plt.xticks(np.arange(0, 20 + 1, 10))
plt.yticks(np.arange(0, 20 + 1, 5))
p = plt.plot([0.0, 20.0],[10.0, 10.0], "black", linestyle='dashed') # normal way
p = plt.plot([0.0, 20.0],[7.6, 7.6], "red", linestyle='dashed') # normal way
p = plt.plot([0.0, 20.0],[12.7, 12.7], "blue", linestyle='dashed') # normal way

# 保存するPDFファイル名
pp = PdfPages(dir+'esc.pdf')
# 画像をPDFとして保存する
pp.savefig(fig)
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
                    
#plt.savefig("R-Vesc.png")

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages


im = 2
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
#mass99=uvhpy99[1,:]


plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')

plt.scatter(time82, mass82, s=5.9,c='red')
plt.scatter(time83, mass83, s=5.9,c='red')
plt.scatter(time84, mass84, s=5.9,c='red')
plt.scatter(time85, mass85, s=5.9,c='red')
plt.scatter(time86, mass86, s=5.9,c='red')
plt.scatter(time87, mass87, s=5.9,c='red')
plt.scatter(time88, mass88, s=5.9,c='red')
plt.scatter(time89, mass89, s=5.9,c='red')
plt.scatter(time90, mass90, s=5.9,c='red')
plt.scatter(time91, mass91, s=5.9,c='red')
plt.scatter(time92, mass92, s=5.9,c='red')
plt.scatter(time93, mass93, s=5.9,c='red')
plt.scatter(time94, mass94, s=5.9,c='red')
plt.scatter(time95, mass95, s=5.9,c='red')
plt.scatter(time96, mass96, s=5.9,c='red')
plt.scatter(time97, mass97, s=5.9,c='red')
plt.scatter(time98, mass98, s=5.9,c='red')
#plt.scatter(time99, mass99, s=5.9,c='red')


print(time)
# Out:
# [20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5
#  20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5
#  20.5 20.5 20.5 20.5]

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm



im = 3
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""

jm82 = 38
jm90= 31
#jm3 = 21
#km=19433
dir = '/Users/maeda/Desktop/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f90 = open(dir+'Dropbox/analysis/sampletstC/feedef/Masstime082001.DAT')
f91 = open(dir+'Dropbox/analysis/sampletstC/feedef/Masstime086001.DAT')
f92 = open(dir+'Dropbox/analysis/sampletstC/feedef/Masstime090001.DAT')
#f93 = open(dir+'Dropbox/analysis/samplecnvS/Masstime096001.DAT')

ary = np.fromfile(f90, np.float64,count=im*jm)
ary1 = np.fromfile(f91, np.float64,count=im*jm1)
ary2 = np.fromfile(f92, np.float64,count=im*jm2)
#ary3 = np.fromfile(f93, np.float64,count=im*jm3)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy = ary.reshape(im,jm,order='F')
uvhpy1 = ary1.reshape(im,jm1,order='F')
uvhpy2 = ary2.reshape(im,jm2,order='F')
#uvhpy3 = ary3.reshape(im,jm3,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time=uvhpy[0,:]
mass=uvhpy[1,:]
feed=uvhpy[2,:]

time1=uvhpy1[0,:]
mass1=uvhpy1[1,:]
feed1=uvhpy1[2,:]

time2=uvhpy2[0,:]
mass2=uvhpy2[1,:]
feed2=uvhpy2[2,:]

#time3=uvhpy3[0,:]
#mass3=uvhpy3[1,:]

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')

plt.scatter(time, mass, s=5.9,c=feed, cmap=cm.seismic)
plt.scatter(time1, mass1, s=5.9,c=feed1, cmap=cm.seismic)
plt.scatter(time2, mass2, s=5.9,c=feed2, cmap=cm.seismic)
#plt.scatter(time3, mass3, s=5.9,c='red')

plt.colorbar()

print(time)
# Out:
# [20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5
#  20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5
#  20.5 20.5 20.5 20.5]

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 3
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
#mass99=uvhpy99[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0


vfd82=uvhpy82[3,:]
vfd83=uvhpy83[3,:]
vfd84=uvhpy84[3,:]
vfd85=uvhpy85[3,:]
vfd86=uvhpy86[3,:]
vfd87=uvhpy87[3,:]
vfd88=uvhpy88[3,:]
vfd89=uvhpy89[3,:]
vfd90=uvhpy90[3,:]
vfd91=uvhpy91[3,:]
vfd92=uvhpy92[3,:]
vfd93=uvhpy93[3,:]
vfd94=uvhpy94[3,:]
vfd95=uvhpy95[3,:]
vfd96=uvhpy96[3,:]
vfd97=uvhpy97[3,:]
vfd98=uvhpy98[3,:]


plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time82, mass82, s=5.9,c=vfd82, cmap=cm.cool, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=vfd83, cmap=cm.cool, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=vfd84, cmap=cm.cool, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=vfd85, cmap=cm.cool, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=vfd86, cmap=cm.cool, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=vfd87, cmap=cm.cool, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=vfd88, cmap=cm.cool, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=vfd89, cmap=cm.cool, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=vfd90, cmap=cm.cool, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=vfd91, cmap=cm.cool, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=vfd92, cmap=cm.cool, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=vfd93, cmap=cm.cool, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=vfd94, cmap=cm.cool, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=vfd95, cmap=cm.cool, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=vfd96, cmap=cm.cool, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=vfd97, cmap=cm.cool, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=vfd98, cmap=cm.cool, norm=LogNorm())
plt.colorbar()


print(time)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-c422c076f2f7> in <module>
#     204
#     205
# --> 206 vfd82=uvhpy82[3,:]
#     207 vfd83=uvhpy83[3,:]
#     208 vfd84=uvhpy84[3,:]
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
c


im = 3
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]

fd82=uvhpy82[2,:]+1
fd83=uvhpy83[2,:]+1
fd84=uvhpy84[2,:]+1
fd85=uvhpy85[2,:]+1
fd86=uvhpy86[2,:]+1
fd87=uvhpy87[2,:]+1
fd88=uvhpy88[2,:]+1
fd89=uvhpy89[2,:]+1
fd90=uvhpy90[2,:]+1
fd91=uvhpy91[2,:]+1
fd92=uvhpy92[2,:]+1
fd93=uvhpy93[2,:]+1

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')

plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool, norm=LogNorm())


#plt.scatter(time99, mass99, s=5.9,c='red')
plt.colorbar()


print(time)
# Out:
# [20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5
#  20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5 20.5
#  20.5 20.5 20.5 20.5]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

mappable0 = ax1.pcolormesh(x,y,data01, cmap='jet',vmin=1, vmax=100, norm=LogNorm()) # ここがポイント！
pp = fig.colorbar(mappable0, ax=ax1, orientation="vertical")
plt.gca().set_aspect('equal')
#plt.clim(0.1, 1000.0)

plt.axes().set_aspect('equal', 'datalim')
plt.savefig("columntot.png")
plt.savefig("foo.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-a24bca030563> in <module>
#       2 ax1 = fig.add_subplot(111)
#       3
# ----> 4 mappable0 = ax1.pcolormesh(x,y,data01, cmap='jet',vmin=1, vmax=100, norm=LogNorm()) # ここがポイント！
#       5 pp = fig.colorbar(mappable0, ax=ax1, orientation="vertical")
#       6 plt.gca().set_aspect('equal')
#
# NameError: name 'x' is not defined

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24
jm110= 25
jm111= 15
jm112= 15
jm113= 16
jm114= 12
jm115= 12
jm116= 10
jm117= 6
jm118= 6
jm119= 3

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')
f110 = open(dir+'Masstime110001.DAT')
f111 = open(dir+'Masstime111001.DAT')
f112 = open(dir+'Masstime112001.DAT')
f113 = open(dir+'Masstime113001.DAT')
f114 = open(dir+'Masstime114001.DAT')
f115 = open(dir+'Masstime115001.DAT')
f116 = open(dir+'Masstime116001.DAT')
f117 = open(dir+'Masstime117001.DAT')
f118 = open(dir+'Masstime118001.DAT')
f119 = open(dir+'Masstime119001.DAT')

#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
ary110 = np.fromfile(f110, np.float64,count=im*jm110)
ary111 = np.fromfile(f111, np.float64,count=im*jm111)
ary112 = np.fromfile(f112, np.float64,count=im*jm112)
ary113 = np.fromfile(f113, np.float64,count=im*jm113)
ary114 = np.fromfile(f114, np.float64,count=im*jm114)
ary115 = np.fromfile(f115, np.float64,count=im*jm115)
ary116 = np.fromfile(f116, np.float64,count=im*jm116)
ary117 = np.fromfile(f117, np.float64,count=im*jm117)
ary118 = np.fromfile(f118, np.float64,count=im*jm118)
ary119 = np.fromfile(f119, np.float64,count=im*jm119)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
uvhpy110 = ary110.reshape(im,jm110,order='F')
uvhpy111= ary111.reshape(im,jm111,order='F')
uvhpy112 = ary112.reshape(im,jm112,order='F')
uvhpy113 = ary113.reshape(im,jm113,order='F')
uvhpy114 = ary114.reshape(im,jm114,order='F')
uvhpy115 = ary115.reshape(im,jm115,order='F')
uvhpy116 = ary116.reshape(im,jm116,order='F')
uvhpy117 = ary117.reshape(im,jm117,order='F')
uvhpy118 = ary118.reshape(im,jm118,order='F')
uvhpy119 = ary119.reshape(im,jm119,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
time110 =uvhpy110[0,:]
time111 =uvhpy111[0,:]
time112 =uvhpy112[0,:]
time113 =uvhpy113[0,:]
time114 =uvhpy114[0,:]
time115 =uvhpy115[0,:]
time116 =uvhpy116[0,:]
time117 =uvhpy117[0,:]
time118 =uvhpy118[0,:]
time119 =uvhpy119[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]
mass110=uvhpy110[1,:]
mass111=uvhpy111[1,:]
mass112=uvhpy112[1,:]
mass113=uvhpy113[1,:]
mass114=uvhpy114[1,:]
mass115=uvhpy115[1,:]
mass116=uvhpy116[1,:]
mass117=uvhpy117[1,:]
mass118=uvhpy118[1,:]
mass119=uvhpy119[1,:]
#mass99=uvhpy99[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0
fd110=uvhpy110[2,:]+1.0
fd111=uvhpy111[2,:]+1.0
fd112=uvhpy112[2,:]+1.0
fd113=uvhpy113[2,:]+1.0
fd114=uvhpy114[2,:]+1.0
fd115=uvhpy115[2,:]+1.0
fd116=uvhpy116[2,:]+1.0
fd117=uvhpy117[2,:]+1.0
fd118=uvhpy118[2,:]+1.0
fd119=uvhpy119[2,:]+1.0

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=fd99, cmap=cm.cool, norm=LogNorm())
plt.scatter(time100, mass100, s=5.9,c=fd100, cmap=cm.cool, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=fd101, cmap=cm.cool, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=fd102, cmap=cm.cool, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=fd103, cmap=cm.cool, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=fd104, cmap=cm.cool, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=fd105, cmap=cm.cool, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=fd106, cmap=cm.cool, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=fd107, cmap=cm.cool, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=fd108, cmap=cm.cool, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=fd109, cmap=cm.cool, norm=LogNorm())
plt.scatter(time110, mass110, s=5.9,c=fd110, cmap=cm.cool, norm=LogNorm())
plt.scatter(time111, mass111, s=5.9,c=fd111, cmap=cm.cool, norm=LogNorm())
plt.scatter(time112, mass112, s=5.9,c=fd112, cmap=cm.cool, norm=LogNorm())
plt.scatter(time113, mass113, s=5.9,c=fd113, cmap=cm.cool, norm=LogNorm())
plt.scatter(time114, mass114, s=5.9,c=fd114, cmap=cm.cool, norm=LogNorm())
plt.scatter(time115, mass115, s=5.9,c=fd115, cmap=cm.cool, norm=LogNorm())
plt.scatter(time116, mass116, s=5.9,c=fd116, cmap=cm.cool, norm=LogNorm())
plt.scatter(time117, mass117, s=5.9,c=fd117, cmap=cm.cool, norm=LogNorm())
plt.scatter(time118, mass118, s=5.9,c=fd118, cmap=cm.cool, norm=LogNorm())
plt.scatter(time119, mass119, s=5.9,c=fd119, cmap=cm.cool, norm=LogNorm())
plt.colorbar()

plt.xlim([10.0, 35.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
plt.clim(1, 1000) 
#plt.colorbar()

print(time)
# Out:
# [ 5.13828272e-322  2.22275957e-312 -8.14506005e-278 -4.69635522e+282
#  -1.68608809e-189 -1.23876655e-157  5.33998019e+246 -7.89081998e+022
#  -7.11309476e+139 -1.39629522e-045]

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')

#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0

vfd82=(uvhpy82[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))
vfd83=(uvhpy83[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))
vfd84=(uvhpy84[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))
vfd85=(uvhpy85[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))
vfd86=(uvhpy86[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))
vfd87=(uvhpy87[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))
vfd88=(uvhpy88[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))
vfd89=(uvhpy89[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))
vfd90=(uvhpy90[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))
vfd91=(uvhpy91[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))
vfd92=(uvhpy92[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))
vfd93=(uvhpy93[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))
vfd94=(uvhpy94[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))
vfd95=(uvhpy95[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))
vfd96=(uvhpy96[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))
vfd97=(uvhpy97[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))
vfd98=(uvhpy98[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))
vfd99=(uvhpy99[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))
vfd100=(uvhpy100[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))
vfd101=(uvhpy101[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))
vfd102=(uvhpy102[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))
vfd103=(uvhpy103[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))
vfd104=(uvhpy104[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))
vfd105=(uvhpy105[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))
vfd106=(uvhpy106[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))
vfd107=(uvhpy107[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))
vfd108=(uvhpy108[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))
vfd109=(uvhpy109[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))



plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time82, mass82, s=5.9,c=vfd82, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=vfd83, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=vfd84, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=vfd85, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=vfd86, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=vfd87, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=vfd88, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=vfd89, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=vfd90, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=vfd91, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=vfd92, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=vfd93, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=vfd94, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=vfd95, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=vfd96, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=vfd97, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=vfd98, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=vfd99, cmap=cm.cool)#, norm=LogNorm())

plt.scatter(time100, mass100, s=5.9,c=vfd100, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=vfd101, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=vfd102, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=vfd103, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=vfd104, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=vfd105, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=vfd106, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=vfd107, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=vfd108, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=vfd109, cmap=cm.cool)#, norm=LogNorm())

#pp.set_clim(0.1,10)
plt.clim(1, 20) 
plt.colorbar()

print()

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
# Out:
# (100.0, 1000000.0)

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm



imt = 13
jmt= 10



#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
ft= open(dir+'Mass-time-br2.DAT')

ary = np.fromfile(ft, np.float64,count=imt*jmt)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpyt = ary.reshape(imt,jmt,order='F')

time =uvhpyt[0,:]
mass =uvhpyt[1,:]


plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')

plt.scatter(time, mass, s=5.9, cmap=cm.cool, norm=LogNorm())
#plt.scatter(time99, mass99, s=5.9,c='red')
plt.colorbar()


print(time)
# Out:
# [ 5.13828272e-322  2.22275957e-312 -8.14506005e-278 -4.69635522e+282
#  -1.68608809e-189 -1.23876655e-157  5.33998019e+246 -7.89081998e+022
#  -7.11309476e+139 -1.39629522e-045]

# %%
r1=[0] * 10
r1[0] = 835849.84251095960 
r1[1] = 875128.28458515112   
r1[2] = 914443.10916703427    
r1[3] =  953720.47794984560
r1[4] = 993032.04970913590  
r1[5] = 1032312.8319874419 
r1[6] = 1071611.7812122125       
r1[7] = 1110897.0631209719 
r1[8] = 1149781.7386241204 
r1[9] = 1188810.4752066594  

t1=[0] * 10

t1[0] = 20.5
t1[1] = 20.75
t1[2] = 21.0
t1[3] = 21.25
t1[4] =  21.5
t1[5] =21.75
t1[6] = 22.0
t1[7] = 22.25
t1[8] = 22.5
t1[9] = 22.75


fig = plt.figure()
ax = fig.add_subplot(111)
plt.xlim([15.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 10000000.0]) # y方向の描画範囲を指定
plt.yscale('log')
plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ

ax.set_ylabel('Radius [pc]')
ax.set_xlabel('Time [Myr]')

plt.plot(t1, r1,"-or",color='blue' )
#plt.plot(r1,marker="o",color='red', linewidth = 1) 

plt.show()

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24
jm110= 25
jm111= 15
jm112= 15
jm113= 16
jm114= 12
jm115= 12
jm116= 10
jm117= 6
jm118= 6
jm119= 3

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')
f110 = open(dir+'Masstime110001.DAT')
f111 = open(dir+'Masstime111001.DAT')
f112 = open(dir+'Masstime112001.DAT')
f113 = open(dir+'Masstime113001.DAT')
f114 = open(dir+'Masstime114001.DAT')
f115 = open(dir+'Masstime115001.DAT')
f116 = open(dir+'Masstime116001.DAT')
f117 = open(dir+'Masstime117001.DAT')
f118 = open(dir+'Masstime118001.DAT')
f119 = open(dir+'Masstime119001.DAT')

#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
ary110 = np.fromfile(f110, np.float64,count=im*jm110)
ary111 = np.fromfile(f111, np.float64,count=im*jm111)
ary112 = np.fromfile(f112, np.float64,count=im*jm112)
ary113 = np.fromfile(f113, np.float64,count=im*jm113)
ary114 = np.fromfile(f114, np.float64,count=im*jm114)
ary115 = np.fromfile(f115, np.float64,count=im*jm115)
ary116 = np.fromfile(f116, np.float64,count=im*jm116)
ary117 = np.fromfile(f117, np.float64,count=im*jm117)
ary118 = np.fromfile(f118, np.float64,count=im*jm118)
ary119 = np.fromfile(f119, np.float64,count=im*jm119)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
uvhpy110 = ary110.reshape(im,jm110,order='F')
uvhpy111= ary111.reshape(im,jm111,order='F')
uvhpy112 = ary112.reshape(im,jm112,order='F')
uvhpy113 = ary113.reshape(im,jm113,order='F')
uvhpy114 = ary114.reshape(im,jm114,order='F')
uvhpy115 = ary115.reshape(im,jm115,order='F')
uvhpy116 = ary116.reshape(im,jm116,order='F')
uvhpy117 = ary117.reshape(im,jm117,order='F')
uvhpy118 = ary118.reshape(im,jm118,order='F')
uvhpy119 = ary119.reshape(im,jm119,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
time110 =uvhpy110[0,:]
time111 =uvhpy111[0,:]
time112 =uvhpy112[0,:]
time113 =uvhpy113[0,:]
time114 =uvhpy114[0,:]
time115 =uvhpy115[0,:]
time116 =uvhpy116[0,:]
time117 =uvhpy117[0,:]
time118 =uvhpy118[0,:]
time119 =uvhpy119[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]
mass110=uvhpy110[1,:]
mass111=uvhpy111[1,:]
mass112=uvhpy112[1,:]
mass113=uvhpy113[1,:]
mass114=uvhpy114[1,:]
mass115=uvhpy115[1,:]
mass116=uvhpy116[1,:]
mass117=uvhpy117[1,:]
mass118=uvhpy118[1,:]
mass119=uvhpy119[1,:]
#mass99=uvhpy99[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0
fd110=uvhpy110[2,:]+1.0
fd111=uvhpy111[2,:]+1.0
fd112=uvhpy112[2,:]+1.0
fd113=uvhpy113[2,:]+1.0
fd114=uvhpy114[2,:]+1.0
fd115=uvhpy115[2,:]+1.0
fd116=uvhpy116[2,:]+1.0
fd117=uvhpy117[2,:]+1.0
fd118=uvhpy118[2,:]+1.0
fd119=uvhpy119[2,:]+1.0

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=fd99, cmap=cm.cool, norm=LogNorm())
plt.scatter(time100, mass100, s=5.9,c=fd100, cmap=cm.cool, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=fd101, cmap=cm.cool, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=fd102, cmap=cm.cool, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=fd103, cmap=cm.cool, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=fd104, cmap=cm.cool, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=fd105, cmap=cm.cool, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=fd106, cmap=cm.cool, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=fd107, cmap=cm.cool, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=fd108, cmap=cm.cool, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=fd109, cmap=cm.cool, norm=LogNorm())

plt.colorbar()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
plt.clim(1, 1000) 
#plt.colorbar()

print(time)
# Out:
# [ 5.13828272e-322  2.22275957e-312 -8.14506005e-278 -4.69635522e+282
#  -1.68608809e-189 -1.23876655e-157  5.33998019e+246 -7.89081998e+022
#  -7.11309476e+139 -1.39629522e-045]

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')

#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0

vfd82=(uvhpy82[3,:])**(-0.5)*10.0*np.sqrt(mass82/(30000.0))
vfd83=(uvhpy83[3,:])**(-0.5)*10.0*np.sqrt(mass83/(30000.0))
vfd84=(uvhpy84[3,:])**(-0.5)*10.0*np.sqrt(mass84/(30000.0))
vfd85=(uvhpy85[3,:])**(-0.5)*10.0*np.sqrt(mass85/(30000.0))
vfd86=(uvhpy86[3,:])**(-0.5)*10.0*np.sqrt(mass86/(30000.0))
vfd87=(uvhpy87[3,:])**(-0.5)*10.0*np.sqrt(mass87/(30000.0))
vfd88=(uvhpy88[3,:])**(-0.5)*10.0*np.sqrt(mass88/(30000.0))
vfd89=(uvhpy89[3,:])**(-0.5)*10.0*np.sqrt(mass89/(30000.0))
vfd90=(uvhpy90[3,:])**(-0.5)*10.0*np.sqrt(mass90/(30000.0))
vfd91=(uvhpy91[3,:])**(-0.5)*10.0*np.sqrt(mass91/(30000.0))
vfd92=(uvhpy92[3,:])**(-0.5)*10.0*np.sqrt(mass92/(30000.0))
vfd93=(uvhpy93[3,:])**(-0.5)*10.0*np.sqrt(mass93/(30000.0))
vfd94=(uvhpy94[3,:])**(-0.5)*10.0*np.sqrt(mass94/(30000.0))
vfd95=(uvhpy95[3,:])**(-0.5)*10.0*np.sqrt(mass95/(30000.0))
vfd96=(uvhpy96[3,:])**(-0.5)*10.0*np.sqrt(mass96/(30000.0))
vfd97=(uvhpy97[3,:])**(-0.5)*10.0*np.sqrt(mass97/(30000.0))
vfd98=(uvhpy98[3,:])**(-0.5)*10.0*np.sqrt(mass98/(30000.0))
vfd99=(uvhpy99[3,:])**(-0.5)*10.0*np.sqrt(mass99/(30000.0))
vfd100=(uvhpy100[3,:])**(-0.5)*10.0*np.sqrt(mass100/(30000.0))
vfd101=(uvhpy101[3,:])**(-0.5)*10.0*np.sqrt(mass101/(30000.0))
vfd102=(uvhpy102[3,:])**(-0.5)*10.0*np.sqrt(mass102/(30000.0))
vfd103=(uvhpy103[3,:])**(-0.5)*10.0*np.sqrt(mass103/(30000.0))
vfd104=(uvhpy104[3,:])**(-0.5)*10.0*np.sqrt(mass104/(30000.0))
vfd105=(uvhpy105[3,:])**(-0.5)*10.0*np.sqrt(mass105/(30000.0))
vfd106=(uvhpy106[3,:])**(-0.5)*10.0*np.sqrt(mass106/(30000.0))
vfd107=(uvhpy107[3,:])**(-0.5)*10.0*np.sqrt(mass107/(30000.0))
vfd108=(uvhpy108[3,:])**(-0.5)*10.0*np.sqrt(mass108/(30000.0))
vfd109=(uvhpy109[3,:])**(-0.5)*10.0*np.sqrt(mass109/(30000.0))



plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time82, mass82, s=5.9,c=vfd82, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=vfd83, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=vfd84, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=vfd85, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=vfd86, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=vfd87, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=vfd88, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=vfd89, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=vfd90, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=vfd91, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=vfd92, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=vfd93, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=vfd94, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=vfd95, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=vfd96, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=vfd97, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=vfd98, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=vfd99, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())

plt.scatter(time100, mass100, s=5.9,c=vfd100, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=vfd101, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=vfd102, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=vfd103, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=vfd104, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=vfd105, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=vfd106, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=vfd107, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=vfd108, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=vfd109, cmap=cm.cool, vmin=0.0, vmax=20.0)#, norm=LogNorm())
plt.clim(1, 20) 
plt.colorbar()



print()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
# Out:
# (100.0, 1000000.0)

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')

#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0

vfd82=(uvhpy82[3,:])**(-0.5)*10.0*np.sqrt(mass82/(30000.0))/15.0
vfd83=(uvhpy83[3,:])**(-0.5)*10.0*np.sqrt(mass83/(30000.0))/15.0
vfd84=(uvhpy84[3,:])**(-0.5)*10.0*np.sqrt(mass84/(30000.0))/15.0
vfd85=(uvhpy85[3,:])**(-0.5)*10.0*np.sqrt(mass85/(30000.0))/15.0
vfd86=(uvhpy86[3,:])**(-0.5)*10.0*np.sqrt(mass86/(30000.0))/15.0
vfd87=(uvhpy87[3,:])**(-0.5)*10.0*np.sqrt(mass87/(30000.0))/15.0
vfd88=(uvhpy88[3,:])**(-0.5)*10.0*np.sqrt(mass88/(30000.0))/15.0
vfd89=(uvhpy89[3,:])**(-0.5)*10.0*np.sqrt(mass89/(30000.0))/15.0
vfd90=(uvhpy90[3,:])**(-0.5)*10.0*np.sqrt(mass90/(30000.0))/15.0
vfd91=(uvhpy91[3,:])**(-0.5)*10.0*np.sqrt(mass91/(30000.0))/15.0
vfd92=(uvhpy92[3,:])**(-0.5)*10.0*np.sqrt(mass92/(30000.0))/15.0
vfd93=(uvhpy93[3,:])**(-0.5)*10.0*np.sqrt(mass93/(30000.0))/15.0
vfd94=(uvhpy94[3,:])**(-0.5)*10.0*np.sqrt(mass94/(30000.0))/15.0
vfd95=(uvhpy95[3,:])**(-0.5)*10.0*np.sqrt(mass95/(30000.0))/15.0
vfd96=(uvhpy96[3,:])**(-0.5)*10.0*np.sqrt(mass96/(30000.0))/15.0
vfd97=(uvhpy97[3,:])**(-0.5)*10.0*np.sqrt(mass97/(30000.0))/15.0
vfd98=(uvhpy98[3,:])**(-0.5)*10.0*np.sqrt(mass98/(30000.0))/15.0
vfd99=(uvhpy99[3,:])**(-0.5)*10.0*np.sqrt(mass99/(30000.0))/15.0
vfd100=(uvhpy100[3,:])**(-0.5)*10.0*np.sqrt(mass100/(30000.0))/15.0
vfd101=(uvhpy101[3,:])**(-0.5)*10.0*np.sqrt(mass101/(30000.0))/15.0
vfd102=(uvhpy102[3,:])**(-0.5)*10.0*np.sqrt(mass102/(30000.0))/15.0
vfd103=(uvhpy103[3,:])**(-0.5)*10.0*np.sqrt(mass103/(30000.0))/15.0
vfd104=(uvhpy104[3,:])**(-0.5)*10.0*np.sqrt(mass104/(30000.0))/15.0
vfd105=(uvhpy105[3,:])**(-0.5)*10.0*np.sqrt(mass105/(30000.0))/15.0
vfd106=(uvhpy106[3,:])**(-0.5)*10.0*np.sqrt(mass106/(30000.0))/15.0
vfd107=(uvhpy107[3,:])**(-0.5)*10.0*np.sqrt(mass107/(30000.0))/15.0
vfd108=(uvhpy108[3,:])**(-0.5)*10.0*np.sqrt(mass108/(30000.0))/15.0
vfd109=(uvhpy109[3,:])**(-0.5)*10.0*np.sqrt(mass109/(30000.0))/15.0



plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''

plt.clim(1, 20) 
plt.colorbar()
plt.scatter(time82, mass82, s=5.9,c=vfd82/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=vfd83/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=vfd84/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=vfd85/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=vfd86/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=vfd87/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=vfd88/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=vfd89/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=vfd90/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=vfd91/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=vfd92/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=vfd93/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=vfd94/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=vfd95/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=vfd96/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=vfd97/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=vfd98/2.0, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=vfd99/2.0, cmap=cm.cool)#, norm=LogNorm())

plt.scatter(time100, mass100, s=5.9,c=vfd100, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=vfd101, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=vfd102, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=vfd103, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=vfd104, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=vfd105, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=vfd106, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=vfd107, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=vfd108, cmap=cm.cool)#, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=vfd109, cmap=cm.cool)#, norm=LogNorm())

#pp.set_clim(0.1,10)
#plt.clim(1, 20) 
#plt.colorbar()

print()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-47-cbdc83bfe5d7> in <module>
#     336 '''
#     337
# --> 338 plt.clim(1, 20)
#     339 plt.colorbar()
#     340 plt.scatter(time82, mass82, s=5.9,c=vfd82/2.0, cmap=cm.cool)#, norm=LogNorm())
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/matplotlib/pyplot.py in clim(vmin, vmax)
#    2106     im = gci()
#    2107     if im is None:
# -> 2108         raise RuntimeError('You must first define an image, e.g., with imshow')
#    2109
#    2110     im.set_clim(vmin, vmax)
#
# RuntimeError: You must first define an image, e.g., with imshow

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')

#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0

'''
vfd82=(uvhpy82[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))/10.0/2.5
vfd83=(uvhpy83[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))/10.0/2.5
vfd84=(uvhpy84[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))/10.0/2.5
vfd85=(uvhpy85[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))/10.0/2.5
vfd86=(uvhpy86[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))/10.0/2.5
vfd87=(uvhpy87[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))/10.0/2.5
vfd88=(uvhpy88[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))/10.0/2.5
vfd89=(uvhpy89[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))/10.0/2.5
vfd90=(uvhpy90[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))/10.0/2.5
vfd91=(uvhpy91[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))/10.0/2.5
vfd92=(uvhpy92[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))/10.0/2.5
vfd93=(uvhpy93[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))/10.0/2.5
vfd94=(uvhpy94[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))/10.0/2.5
vfd95=(uvhpy95[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))/10.0/2.5
vfd96=(uvhpy96[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))/10.0/2.5
vfd97=(uvhpy97[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))/10.0/2.5
vfd98=(uvhpy98[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))/10.0/2.5
vfd99=(uvhpy99[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))/10.0/2.5
vfd100=(uvhpy100[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))/10.0/2.5
vfd101=(uvhpy101[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))/10.0/2.5
vfd102=(uvhpy102[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))/10.0/2.5
vfd103=(uvhpy103[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))/10.0/2.5
vfd104=(uvhpy104[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))/10.0/2.5
vfd105=(uvhpy105[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))/10.0/2.5
vfd106=(uvhpy106[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))/10.0/2.5
vfd107=(uvhpy107[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))/10.0/2.5
vfd108=(uvhpy108[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))/10.0/2.5
vfd109=(uvhpy109[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))/10.0/2.5
'''
'''
vfd82=(uvhpy82[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))
vfd83=(uvhpy83[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))
vfd84=(uvhpy84[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))
vfd85=(uvhpy85[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))
vfd86=(uvhpy86[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))
vfd87=(uvhpy87[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))
vfd88=(uvhpy88[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))
vfd89=(uvhpy89[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))
vfd90=(uvhpy90[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))
vfd91=(uvhpy91[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))
vfd92=(uvhpy92[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))
vfd93=(uvhpy93[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))
vfd94=(uvhpy94[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))
vfd95=(uvhpy95[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))
vfd96=(uvhpy96[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))
vfd97=(uvhpy97[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))
vfd98=(uvhpy98[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))
vfd99=(uvhpy99[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))
vfd100=(uvhpy100[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))
vfd101=(uvhpy101[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))
vfd102=(uvhpy102[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))
vfd103=(uvhpy103[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))
vfd104=(uvhpy104[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))
vfd105=(uvhpy105[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))
vfd106=(uvhpy106[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))
vfd107=(uvhpy107[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))
vfd108=(uvhpy108[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))
vfd109=(uvhpy109[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))
'''
'''
vfd82=(uvhpy82[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))/10.0
vfd83=(uvhpy83[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))/10.0
vfd84=(uvhpy84[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))/10.0
vfd85=(uvhpy85[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))/10.0
vfd86=(uvhpy86[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))/10.0
vfd87=(uvhpy87[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))/10.0
vfd88=(uvhpy88[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))/10.0
vfd89=(uvhpy89[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))/10.0
vfd90=(uvhpy90[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))/10.0
vfd91=(uvhpy91[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))/10.0
vfd92=(uvhpy92[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))/10.0
vfd93=(uvhpy93[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))/10.0
vfd94=(uvhpy94[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))/10.0
vfd95=(uvhpy95[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))/10.0
vfd96=(uvhpy96[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))/10.0
vfd97=(uvhpy97[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))/10.0
vfd98=(uvhpy98[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))/10.0
vfd99=(uvhpy99[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))/10.0
vfd100=(uvhpy100[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))/10.0
vfd101=(uvhpy101[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))/10.0
vfd102=(uvhpy102[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))/10.0
vfd103=(uvhpy103[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))/10.0
vfd104=(uvhpy104[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))/10.0
vfd105=(uvhpy105[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))/10.0
vfd106=(uvhpy106[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))/10.0
vfd107=(uvhpy107[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))/10.0
vfd108=(uvhpy108[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))/10.0
vfd109=(uvhpy109[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))/10.0
'''
vfd82=(uvhpy82[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))/10.0
vfd83=(uvhpy83[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))/10.0
vfd84=(uvhpy84[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))/10.0
vfd85=(uvhpy85[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))/10.0
vfd86=(uvhpy86[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))/10.0
vfd87=(uvhpy87[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))/10.0
vfd88=(uvhpy88[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))/10.0
vfd89=(uvhpy89[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))/10.0
vfd90=(uvhpy90[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))/10.0
vfd91=(uvhpy91[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))/10.0
vfd92=(uvhpy92[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))/10.0
vfd93=(uvhpy93[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))/10.0
vfd94=(uvhpy94[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))/10.0
vfd95=(uvhpy95[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))/10.0
vfd96=(uvhpy96[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))/10.0
vfd97=(uvhpy97[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))/10.0
vfd98=(uvhpy98[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))/10.0
vfd99=(uvhpy99[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))/10.0
vfd100=(uvhpy100[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))/10.0
vfd101=(uvhpy101[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))/10.0
vfd102=(uvhpy102[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))/10.0
vfd103=(uvhpy103[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))/10.0
vfd104=(uvhpy104[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))/10.0
vfd105=(uvhpy105[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))/10.0
vfd106=(uvhpy106[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))/10.0
vfd107=(uvhpy107[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))/10.0
vfd108=(uvhpy108[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))/10.0
vfd109=(uvhpy109[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))/10.0

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time82, mass82, s=5.9,c=vfd82, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=vfd83, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=vfd84, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=vfd85, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=vfd86, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=vfd87, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=vfd88, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=vfd89, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=vfd90, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=vfd91, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=vfd92, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=vfd93, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=vfd94, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=vfd95, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=vfd96, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=vfd97, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=vfd98, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=vfd99, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())

plt.scatter(time100, mass100, s=5.9,c=vfd100, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=vfd101, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=vfd102, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=vfd103, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=vfd104, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=vfd105, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=vfd106, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=vfd107, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=vfd108, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=vfd109, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())

#pp.set_clim(0.1,10)
plt.clim(0, 2) 
plt.colorbar()

print()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
# Out:
# (100.0, 1000000.0)

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24
jm110= 25
jm111= 15
jm112= 15
jm113= 16
jm114= 12
jm115= 12
jm116= 10
jm117= 6
jm118= 6
jm119= 3

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')
f110 = open(dir+'Masstime110001.DAT')
f111 = open(dir+'Masstime111001.DAT')
f112 = open(dir+'Masstime112001.DAT')
f113 = open(dir+'Masstime113001.DAT')
f114 = open(dir+'Masstime114001.DAT')
f115 = open(dir+'Masstime115001.DAT')
f116 = open(dir+'Masstime116001.DAT')
f117 = open(dir+'Masstime117001.DAT')
f118 = open(dir+'Masstime118001.DAT')
f119 = open(dir+'Masstime119001.DAT')

#f99 = open(dir+'Masstime099001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
ary110 = np.fromfile(f110, np.float64,count=im*jm110)
ary111 = np.fromfile(f111, np.float64,count=im*jm111)
ary112 = np.fromfile(f112, np.float64,count=im*jm112)
ary113 = np.fromfile(f113, np.float64,count=im*jm113)
ary114 = np.fromfile(f114, np.float64,count=im*jm114)
ary115 = np.fromfile(f115, np.float64,count=im*jm115)
ary116 = np.fromfile(f116, np.float64,count=im*jm116)
ary117 = np.fromfile(f117, np.float64,count=im*jm117)
ary118 = np.fromfile(f118, np.float64,count=im*jm118)
ary119 = np.fromfile(f119, np.float64,count=im*jm119)
#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
uvhpy110 = ary110.reshape(im,jm110,order='F')
uvhpy111= ary111.reshape(im,jm111,order='F')
uvhpy112 = ary112.reshape(im,jm112,order='F')
uvhpy113 = ary113.reshape(im,jm113,order='F')
uvhpy114 = ary114.reshape(im,jm114,order='F')
uvhpy115 = ary115.reshape(im,jm115,order='F')
uvhpy116 = ary116.reshape(im,jm116,order='F')
uvhpy117 = ary117.reshape(im,jm117,order='F')
uvhpy118 = ary118.reshape(im,jm118,order='F')
uvhpy119 = ary119.reshape(im,jm119,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')
time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
time110 =uvhpy110[0,:]
time111 =uvhpy111[0,:]
time112 =uvhpy112[0,:]
time113 =uvhpy113[0,:]
time114 =uvhpy114[0,:]
time115 =uvhpy115[0,:]
time116 =uvhpy116[0,:]
time117 =uvhpy117[0,:]
time118 =uvhpy118[0,:]
time119 =uvhpy119[0,:]
#time99 =uvhpy99[0,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]
mass110=uvhpy110[1,:]
mass111=uvhpy111[1,:]
mass112=uvhpy112[1,:]
mass113=uvhpy113[1,:]
mass114=uvhpy114[1,:]
mass115=uvhpy115[1,:]
mass116=uvhpy116[1,:]
mass117=uvhpy117[1,:]
mass118=uvhpy118[1,:]
mass119=uvhpy119[1,:]
#mass99=uvhpy99[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0
fd110=uvhpy110[2,:]+1.0
fd111=uvhpy111[2,:]+1.0
fd112=uvhpy112[2,:]+1.0
fd113=uvhpy113[2,:]+1.0
fd114=uvhpy114[2,:]+1.0
fd115=uvhpy115[2,:]+1.0
fd116=uvhpy116[2,:]+1.0
fd117=uvhpy117[2,:]+1.0
fd118=uvhpy118[2,:]+1.0
fd119=uvhpy119[2,:]+1.0

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=fd99, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time100, mass100, s=5.9,c=fd100, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=fd101, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=fd102, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=fd103, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=fd104, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=fd105, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=fd106, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=fd107, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=fd108, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=fd109, cmap=cm.cool, vmin=1.0, vmax=1000.0, norm=LogNorm())

plt.colorbar()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
plt.clim(1, 1000) 
#plt.colorbar()

print(time)
# Out:
# [ 5.13828272e-322  2.22275957e-312 -8.14506005e-278 -4.69635522e+282
#  -1.68608809e-189 -1.23876655e-157  5.33998019e+246 -7.89081998e+022
#  -7.11309476e+139 -1.39629522e-045]

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm30= 0
jm31= 0
jm32= 0
jm33= 0
jm34= 0
jm35= 0
jm36= 0
jm37= 0
jm38= 0
jm39= 0
jm40= 0
jm41= 0
jm42= 0
jm43= 0
jm44= 0
jm45= 0
jm46= 1
jm47= 2
jm48= 3
jm49= 5
jm50= 4
jm51= 4
jm52= 4
jm53= 5
jm54= 5
jm55= 6
jm56= 7
jm57= 7
jm58= 9
jm59= 10
jm60= 10
jm61= 14
jm62= 16
jm63= 16
jm64= 19
jm65= 21
jm66= 19
jm67= 21
jm68= 25
jm69= 26
jm70= 28
jm71= 30
jm72= 33
jm73= 37
jm74= 39
jm75= 42
jm76= 38
jm77= 41
jm78= 38
jm79= 39
jm80= 38
jm81= 38

jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24
jm110= 25
jm111= 15
jm112= 15
jm113= 16
jm114= 12
jm115= 12
jm116= 10
jm117= 6
jm118= 6
jm119= 3

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f30 = open(dir+'Masstime030001.DAT')
f31 = open(dir+'Masstime031001.DAT')
f32 = open(dir+'Masstime032001.DAT')
f33 = open(dir+'Masstime033001.DAT')
f34 = open(dir+'Masstime034001.DAT')
f35 = open(dir+'Masstime035001.DAT')
f36 = open(dir+'Masstime036001.DAT')
f37 = open(dir+'Masstime037001.DAT')
f38 = open(dir+'Masstime038001.DAT')
f39 = open(dir+'Masstime039001.DAT')
f40 = open(dir+'Masstime040001.DAT')
f41 = open(dir+'Masstime041001.DAT')
f42 = open(dir+'Masstime042001.DAT')
f43 = open(dir+'Masstime043001.DAT')
f44 = open(dir+'Masstime044001.DAT')
f45 = open(dir+'Masstime045001.DAT')
f46 = open(dir+'Masstime046001.DAT')
f47 = open(dir+'Masstime047001.DAT')
f48 = open(dir+'Masstime048001.DAT')
f49 = open(dir+'Masstime049001.DAT')
f50 = open(dir+'Masstime050001.DAT')
f51 = open(dir+'Masstime051001.DAT')
f52 = open(dir+'Masstime052001.DAT')
f53 = open(dir+'Masstime053001.DAT')
f54 = open(dir+'Masstime054001.DAT')
f55 = open(dir+'Masstime055001.DAT')
f56 = open(dir+'Masstime056001.DAT')
f57 = open(dir+'Masstime057001.DAT')
f58 = open(dir+'Masstime058001.DAT')
f59 = open(dir+'Masstime059001.DAT')
f60 = open(dir+'Masstime060001.DAT')
f61 = open(dir+'Masstime061001.DAT')
f62 = open(dir+'Masstime062001.DAT')
f63 = open(dir+'Masstime063001.DAT')
f64 = open(dir+'Masstime064001.DAT')
f65 = open(dir+'Masstime065001.DAT')
f66 = open(dir+'Masstime066001.DAT')
f67 = open(dir+'Masstime067001.DAT')
f68 = open(dir+'Masstime068001.DAT')
f69 = open(dir+'Masstime069001.DAT')
f70 = open(dir+'Masstime070001.DAT')
f71 = open(dir+'Masstime071001.DAT')
f72 = open(dir+'Masstime072001.DAT')
f73 = open(dir+'Masstime073001.DAT')
f74 = open(dir+'Masstime074001.DAT')
f75 = open(dir+'Masstime075001.DAT')
f76 = open(dir+'Masstime076001.DAT')
f77 = open(dir+'Masstime077001.DAT')
f78 = open(dir+'Masstime078001.DAT')
f79 = open(dir+'Masstime079001.DAT')
f80 = open(dir+'Masstime080001.DAT')
f81 = open(dir+'Masstime081001.DAT')

f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')
f110 = open(dir+'Masstime110001.DAT')
f111 = open(dir+'Masstime111001.DAT')
f112 = open(dir+'Masstime112001.DAT')
f113 = open(dir+'Masstime113001.DAT')
f114 = open(dir+'Masstime114001.DAT')
f115 = open(dir+'Masstime115001.DAT')
f116 = open(dir+'Masstime116001.DAT')
f117 = open(dir+'Masstime117001.DAT')
f118 = open(dir+'Masstime118001.DAT')
f119 = open(dir+'Masstime119001.DAT')

#f99 = open(dir+'Masstime099001.DAT')
ary30 = np.fromfile(f30, np.float64,count=im*jm30)
ary31 = np.fromfile(f31, np.float64,count=im*jm31)
ary32 = np.fromfile(f32, np.float64,count=im*jm32)
ary33 = np.fromfile(f33, np.float64,count=im*jm33)
ary34 = np.fromfile(f34, np.float64,count=im*jm34)
ary35 = np.fromfile(f35, np.float64,count=im*jm35)
ary36 = np.fromfile(f36, np.float64,count=im*jm36)
ary37 = np.fromfile(f37, np.float64,count=im*jm37)
ary38 = np.fromfile(f38, np.float64,count=im*jm38)
ary39 = np.fromfile(f39, np.float64,count=im*jm39)
ary40 = np.fromfile(f40, np.float64,count=im*jm40)
ary41 = np.fromfile(f41, np.float64,count=im*jm41)
ary42 = np.fromfile(f42, np.float64,count=im*jm42)
ary43 = np.fromfile(f43, np.float64,count=im*jm43)
ary44 = np.fromfile(f44, np.float64,count=im*jm44)
ary45 = np.fromfile(f45, np.float64,count=im*jm45)
ary46 = np.fromfile(f46, np.float64,count=im*jm46)
ary47 = np.fromfile(f47, np.float64,count=im*jm47)
ary48 = np.fromfile(f48, np.float64,count=im*jm48)
ary49 = np.fromfile(f49, np.float64,count=im*jm49)
ary50 = np.fromfile(f50, np.float64,count=im*jm50)
ary51 = np.fromfile(f51, np.float64,count=im*jm51)
ary52 = np.fromfile(f52, np.float64,count=im*jm52)
ary53 = np.fromfile(f53, np.float64,count=im*jm53)
ary54 = np.fromfile(f54, np.float64,count=im*jm54)
ary55 = np.fromfile(f55, np.float64,count=im*jm55)
ary56 = np.fromfile(f56, np.float64,count=im*jm56)
ary57 = np.fromfile(f57, np.float64,count=im*jm57)
ary58 = np.fromfile(f58, np.float64,count=im*jm58)
ary59 = np.fromfile(f59, np.float64,count=im*jm59)
ary60 = np.fromfile(f60, np.float64,count=im*jm60)
ary61 = np.fromfile(f61, np.float64,count=im*jm61)
ary62 = np.fromfile(f62, np.float64,count=im*jm62)
ary63 = np.fromfile(f63, np.float64,count=im*jm63)
ary64 = np.fromfile(f64, np.float64,count=im*jm64)
ary65 = np.fromfile(f65, np.float64,count=im*jm65)
ary66 = np.fromfile(f66, np.float64,count=im*jm66)
ary67 = np.fromfile(f67, np.float64,count=im*jm67)
ary68 = np.fromfile(f68, np.float64,count=im*jm68)
ary69 = np.fromfile(f69, np.float64,count=im*jm69)
ary70 = np.fromfile(f70, np.float64,count=im*jm70)
ary71 = np.fromfile(f71, np.float64,count=im*jm71)
ary72 = np.fromfile(f72, np.float64,count=im*jm72)
ary73 = np.fromfile(f73, np.float64,count=im*jm73)
ary74 = np.fromfile(f74, np.float64,count=im*jm74)
ary75 = np.fromfile(f75, np.float64,count=im*jm75)
ary76 = np.fromfile(f76, np.float64,count=im*jm76)
ary77 = np.fromfile(f77, np.float64,count=im*jm77)
ary78 = np.fromfile(f78, np.float64,count=im*jm78)
ary79 = np.fromfile(f79, np.float64,count=im*jm79)
ary80 = np.fromfile(f80, np.float64,count=im*jm80)
ary81 = np.fromfile(f81, np.float64,count=im*jm81)

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
ary110 = np.fromfile(f110, np.float64,count=im*jm110)
ary111 = np.fromfile(f111, np.float64,count=im*jm111)
ary112 = np.fromfile(f112, np.float64,count=im*jm112)
ary113 = np.fromfile(f113, np.float64,count=im*jm113)
ary114 = np.fromfile(f114, np.float64,count=im*jm114)
ary115 = np.fromfile(f115, np.float64,count=im*jm115)
ary116 = np.fromfile(f116, np.float64,count=im*jm116)
ary117 = np.fromfile(f117, np.float64,count=im*jm117)
ary118 = np.fromfile(f118, np.float64,count=im*jm118)
ary119 = np.fromfile(f119, np.float64,count=im*jm119)

#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy30 = ary30.reshape(im,jm30,order='F')
uvhpy31 = ary31.reshape(im,jm31,order='F')
uvhpy32 = ary32.reshape(im,jm32,order='F')
uvhpy33 = ary33.reshape(im,jm33,order='F')
uvhpy34 = ary34.reshape(im,jm34,order='F')
uvhpy35 = ary35.reshape(im,jm35,order='F')
uvhpy36 = ary36.reshape(im,jm36,order='F')
uvhpy37 = ary37.reshape(im,jm37,order='F')
uvhpy38 = ary38.reshape(im,jm38,order='F')
uvhpy39 = ary39.reshape(im,jm39,order='F')
uvhpy40 = ary40.reshape(im,jm40,order='F')
uvhpy41 = ary41.reshape(im,jm41,order='F')
uvhpy42 = ary42.reshape(im,jm42,order='F')
uvhpy43 = ary43.reshape(im,jm43,order='F')
uvhpy44 = ary44.reshape(im,jm44,order='F')
uvhpy45 = ary45.reshape(im,jm45,order='F')
uvhpy46 = ary46.reshape(im,jm46,order='F')
uvhpy47 = ary47.reshape(im,jm47,order='F')
uvhpy48 = ary48.reshape(im,jm48,order='F')
uvhpy49 = ary49.reshape(im,jm49,order='F')
uvhpy50 = ary50.reshape(im,jm50,order='F')
uvhpy51 = ary51.reshape(im,jm51,order='F')
uvhpy52 = ary52.reshape(im,jm52,order='F')
uvhpy53 = ary53.reshape(im,jm53,order='F')
uvhpy54 = ary54.reshape(im,jm54,order='F')
uvhpy55 = ary55.reshape(im,jm55,order='F')
uvhpy56 = ary56.reshape(im,jm56,order='F')
uvhpy57 = ary57.reshape(im,jm57,order='F')
uvhpy58 = ary58.reshape(im,jm58,order='F')
uvhpy59 = ary59.reshape(im,jm59,order='F')
uvhpy60 = ary60.reshape(im,jm60,order='F')
uvhpy61 = ary61.reshape(im,jm61,order='F')
uvhpy62 = ary62.reshape(im,jm62,order='F')
uvhpy63 = ary63.reshape(im,jm63,order='F')
uvhpy64 = ary64.reshape(im,jm64,order='F')
uvhpy65 = ary65.reshape(im,jm65,order='F')
uvhpy66 = ary66.reshape(im,jm66,order='F')
uvhpy67 = ary67.reshape(im,jm67,order='F')
uvhpy68 = ary68.reshape(im,jm68,order='F')
uvhpy69 = ary69.reshape(im,jm69,order='F')
uvhpy70 = ary70.reshape(im,jm70,order='F')
uvhpy71 = ary71.reshape(im,jm71,order='F')
uvhpy72 = ary72.reshape(im,jm72,order='F')
uvhpy73 = ary73.reshape(im,jm73,order='F')
uvhpy74 = ary74.reshape(im,jm74,order='F')
uvhpy75 = ary75.reshape(im,jm75,order='F')
uvhpy76 = ary76.reshape(im,jm76,order='F')
uvhpy77 = ary77.reshape(im,jm77,order='F')
uvhpy78 = ary78.reshape(im,jm78,order='F')
uvhpy79 = ary79.reshape(im,jm79,order='F')
uvhpy80 = ary80.reshape(im,jm80,order='F')
uvhpy81 = ary81.reshape(im,jm81,order='F')

uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
uvhpy110 = ary110.reshape(im,jm110,order='F')
uvhpy111= ary111.reshape(im,jm111,order='F')
uvhpy112 = ary112.reshape(im,jm112,order='F')
uvhpy113 = ary113.reshape(im,jm113,order='F')
uvhpy114 = ary114.reshape(im,jm114,order='F')
uvhpy115 = ary115.reshape(im,jm115,order='F')
uvhpy116 = ary116.reshape(im,jm116,order='F')
uvhpy117 = ary117.reshape(im,jm117,order='F')
uvhpy118 = ary118.reshape(im,jm118,order='F')
uvhpy119 = ary119.reshape(im,jm119,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')

time30 =uvhpy30[0,:]
time31 =uvhpy31[0,:]
time32 =uvhpy32[0,:]
time33 =uvhpy33[0,:]
time34 =uvhpy34[0,:]
time35 =uvhpy35[0,:]
time36 =uvhpy36[0,:]
time37 =uvhpy37[0,:]
time38 =uvhpy38[0,:]
time39 =uvhpy39[0,:]
time40 =uvhpy40[0,:]
time41 =uvhpy41[0,:]
time42 =uvhpy42[0,:]
time43 =uvhpy43[0,:]
time44 =uvhpy44[0,:]
time45 =uvhpy45[0,:]
time46 =uvhpy46[0,:]
time47 =uvhpy47[0,:]
time48 =uvhpy48[0,:]
time49 =uvhpy49[0,:]
time50 =uvhpy50[0,:]
time51 =uvhpy51[0,:]
time52 =uvhpy52[0,:]
time53 =uvhpy53[0,:]
time54 =uvhpy54[0,:]
time55 =uvhpy55[0,:]
time56 =uvhpy56[0,:]
time57 =uvhpy57[0,:]
time58 =uvhpy58[0,:]
time59 =uvhpy59[0,:]
time60 =uvhpy60[0,:]
time61 =uvhpy61[0,:]
time62 =uvhpy62[0,:]
time63 =uvhpy63[0,:]
time64 =uvhpy64[0,:]
time65 =uvhpy65[0,:]
time66 =uvhpy66[0,:]
time67 =uvhpy67[0,:]
time68 =uvhpy68[0,:]
time69 =uvhpy69[0,:]
time70 =uvhpy70[0,:]
time71 =uvhpy71[0,:]
time72 =uvhpy72[0,:]
time73 =uvhpy73[0,:]
time74 =uvhpy74[0,:]
time75 =uvhpy75[0,:]
time76 =uvhpy76[0,:]
time77 =uvhpy77[0,:]
time78 =uvhpy78[0,:]
time79 =uvhpy79[0,:]
time80 =uvhpy80[0,:]
time81 =uvhpy81[0,:]

time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
time110 =uvhpy110[0,:]
time111 =uvhpy111[0,:]
time112 =uvhpy112[0,:]
time113 =uvhpy113[0,:]
time114 =uvhpy114[0,:]
time115 =uvhpy115[0,:]
time116 =uvhpy116[0,:]
time117 =uvhpy117[0,:]
time118 =uvhpy118[0,:]
time119 =uvhpy119[0,:]
#time99 =uvhpy99[0,:]

mass30=uvhpy30[1,:]
mass31=uvhpy31[1,:]
mass32=uvhpy32[1,:]
mass33=uvhpy33[1,:]
mass34=uvhpy34[1,:]
mass35=uvhpy35[1,:]
mass36=uvhpy36[1,:]
mass37=uvhpy37[1,:]
mass38=uvhpy38[1,:]
mass39=uvhpy39[1,:]
mass40=uvhpy40[1,:]
mass41=uvhpy41[1,:]
mass42=uvhpy42[1,:]
mass43=uvhpy43[1,:]
mass44=uvhpy44[1,:]
mass45=uvhpy45[1,:]
mass46=uvhpy46[1,:]
mass47=uvhpy47[1,:]
mass48=uvhpy48[1,:]
mass49=uvhpy49[1,:]
mass50=uvhpy50[1,:]
mass51=uvhpy51[1,:]
mass52=uvhpy52[1,:]
mass53=uvhpy53[1,:]
mass54=uvhpy54[1,:]
mass55=uvhpy55[1,:]
mass56=uvhpy56[1,:]
mass57=uvhpy57[1,:]
mass58=uvhpy58[1,:]
mass59=uvhpy59[1,:]
mass60=uvhpy60[1,:]
mass61=uvhpy61[1,:]
mass62=uvhpy62[1,:]
mass63=uvhpy63[1,:]
mass64=uvhpy64[1,:]
mass65=uvhpy65[1,:]
mass66=uvhpy66[1,:]
mass67=uvhpy67[1,:]
mass68=uvhpy68[1,:]
mass69=uvhpy69[1,:]
mass70=uvhpy70[1,:]
mass71=uvhpy71[1,:]
mass72=uvhpy72[1,:]
mass73=uvhpy73[1,:]
mass74=uvhpy74[1,:]
mass75=uvhpy75[1,:]
mass76=uvhpy76[1,:]
mass77=uvhpy77[1,:]
mass78=uvhpy78[1,:]
mass79=uvhpy79[1,:]
mass80=uvhpy80[1,:]
mass81=uvhpy81[1,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]
mass110=uvhpy110[1,:]
mass111=uvhpy111[1,:]
mass112=uvhpy112[1,:]
mass113=uvhpy113[1,:]
mass114=uvhpy114[1,:]
mass115=uvhpy115[1,:]
mass116=uvhpy116[1,:]
mass117=uvhpy117[1,:]
mass118=uvhpy118[1,:]
mass119=uvhpy119[1,:]
#mass99=uvhpy99[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd30=uvhpy30[2,:]*0.0+1.0
fd31=uvhpy31[2,:]*0.0+1.0
fd32=uvhpy32[2,:]*0.0+1.0
fd33=uvhpy33[2,:]*0.0+1.0
fd34=uvhpy34[2,:]*0.0+1.0
fd35=uvhpy35[2,:]*0.0+1.0
fd36=uvhpy36[2,:]*0.0+1.0
fd37=uvhpy37[2,:]*0.0+1.0
fd38=uvhpy38[2,:]*0.0+1.0
fd39=uvhpy39[2,:]*0.0+1.0
fd40=uvhpy40[2,:]*0.0+1.0
fd41=uvhpy41[2,:]*0.0+1.0
fd42=uvhpy42[2,:]*0.0+1.0
fd43=uvhpy43[2,:]*0.0+1.0
fd44=uvhpy44[2,:]*0.0+1.0
fd45=uvhpy45[2,:]*0.0+1.0
fd46=uvhpy46[2,:]*0.0+1.0
fd47=uvhpy47[2,:]*0.0+1.0
fd48=uvhpy48[2,:]*0.0+1.0
fd49=uvhpy49[2,:]*0.0+1.0
fd50=uvhpy50[2,:]*0.0+1.0
fd51=uvhpy51[2,:]*0.0+1.0
fd52=uvhpy52[2,:]*0.0+1.0
fd53=uvhpy53[2,:]*0.0+1.0
fd54=uvhpy54[2,:]*0.0+1.0
fd55=uvhpy55[2,:]*0.0+1.0
fd56=uvhpy56[2,:]*0.0+1.0
fd57=uvhpy57[2,:]*0.0+1.0
fd58=uvhpy58[2,:]*0.0+1.0
fd59=uvhpy59[2,:]*0.0+1.0
fd60=uvhpy60[2,:]*0.0+1.0
fd61=uvhpy61[2,:]*0.0+1.0
fd62=uvhpy62[2,:]*0.0+1.0
fd63=uvhpy63[2,:]*0.0+1.0
fd64=uvhpy64[2,:]*0.0+1.0
fd65=uvhpy65[2,:]*0.0+1.0
fd66=uvhpy66[2,:]*0.0+1.0
fd67=uvhpy67[2,:]*0.0+1.0
fd68=uvhpy68[2,:]*0.0+1.0
fd69=uvhpy69[2,:]*0.0+1.0
fd70=uvhpy70[2,:]*0.0+1.0
fd71=uvhpy71[2,:]+1.0
fd72=uvhpy72[2,:]+1.0
fd73=uvhpy73[2,:]+1.0
fd74=uvhpy74[2,:]+1.0
fd75=uvhpy75[2,:]+1.0
fd76=uvhpy76[2,:]+1.0
fd77=uvhpy77[2,:]+1.0
fd78=uvhpy78[2,:]+1.0
fd79=uvhpy79[2,:]+1.0
fd80=uvhpy80[2,:]+1.0
fd81=uvhpy81[2,:]+1.0

fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0
fd110=uvhpy110[2,:]+1.0
fd111=uvhpy111[2,:]+1.0
fd112=uvhpy112[2,:]+1.0
fd113=uvhpy113[2,:]+1.0
fd114=uvhpy114[2,:]+1.0
fd115=uvhpy115[2,:]+1.0
fd116=uvhpy116[2,:]+1.0
fd117=uvhpy117[2,:]+1.0
fd118=uvhpy118[2,:]+1.0
fd119=uvhpy119[2,:]+1.0

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time30, mass30, s=5.9,c=fd30, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time31, mass31, s=5.9,c=fd31, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time32, mass32, s=5.9,c=fd32, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time33, mass33, s=5.9,c=fd33, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time34, mass34, s=5.9,c=fd34, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time35, mass35, s=5.9,c=fd35, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time36, mass36, s=5.9,c=fd36, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time37, mass37, s=5.9,c=fd37, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time38, mass38, s=5.9,c=fd38, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time39, mass39, s=5.9,c=fd39, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time40, mass40, s=5.9,c=fd40, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time41, mass41, s=5.9,c=fd41, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time42, mass42, s=5.9,c=fd42, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time43, mass43, s=5.9,c=fd43, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time44, mass44, s=5.9,c=fd44, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time45, mass45, s=5.9,c=fd45, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time46, mass46, s=5.9,c=fd46, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time47, mass47, s=5.9,c=fd47, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time48, mass48, s=5.9,c=fd48, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time49, mass49, s=5.9,c=fd49, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time50, mass50, s=5.9,c=fd50, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time51, mass51, s=5.9,c=fd51, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time52, mass52, s=5.9,c=fd52, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time53, mass53, s=5.9,c=fd53, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time54, mass54, s=5.9,c=fd54, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time55, mass55, s=5.9,c=fd55, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time56, mass56, s=5.9,c=fd56, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time57, mass57, s=5.9,c=fd57, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time58, mass58, s=5.9,c=fd58, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time59, mass59, s=5.9,c=fd59, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time60, mass60, s=5.9,c=fd60, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time61, mass61, s=5.9,c=fd61, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time62, mass62, s=5.9,c=fd62, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time63, mass63, s=5.9,c=fd63, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time64, mass64, s=5.9,c=fd64, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time65, mass65, s=5.9,c=fd65, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time66, mass66, s=5.9,c=fd66, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time67, mass67, s=5.9,c=fd67, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time68, mass68, s=5.9,c=fd68, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time69, mass69, s=5.9,c=fd69, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time70, mass70, s=5.9,c=fd70, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time71, mass71, s=5.9,c=fd71, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time72, mass72, s=5.9,c=fd72, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time73, mass73, s=5.9,c=fd73, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time74, mass74, s=5.9,c=fd74, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time75, mass75, s=5.9,c=fd75, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time76, mass76, s=5.9,c=fd76, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time77, mass77, s=5.9,c=fd77, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time78, mass78, s=5.9,c=fd78, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time79, mass79, s=5.9,c=fd79, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time80, mass80, s=5.9,c=fd80, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time81, mass81, s=5.9,c=fd81, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())

plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=fd99, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time100, mass100, s=5.9,c=fd100, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=fd101, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=fd102, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=fd103, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=fd104, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=fd105, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=fd106, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=fd107, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=fd108, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=fd109, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())

plt.colorbar()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
plt.clim(1, 1000) 
#plt.colorbar()

print(time)
# Out:
# [ 5.13828272e-322  2.22275957e-312 -8.14506005e-278 -4.69635522e+282
#  -1.68608809e-189 -1.23876655e-157  5.33998019e+246 -7.89081998e+022
#  -7.11309476e+139 -1.39629522e-045]

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''

jm30= 0
jm31= 0
jm32= 0
jm33= 0
jm34= 0
jm35= 0
jm36= 0
jm37= 0
jm38= 0
jm39= 0
jm40= 0
jm41= 0
jm42= 0
jm43= 0
jm44= 0
jm45= 0
jm46= 1
jm47= 2
jm48= 3
jm49= 5
jm50= 4
jm51= 4
jm52= 4
jm53= 5
jm54= 5
jm55= 6
jm56= 7
jm57= 7
jm58= 9
jm59= 10
jm60= 10
jm61= 14
jm62= 16
jm63= 16
jm64= 19
jm65= 21
jm66= 19
jm67= 21
jm68= 25
jm69= 26
jm70= 28
jm71= 30
jm72= 33
jm73= 37
jm74= 39
jm75= 42
jm76= 38
jm77= 41
jm78= 38
jm79= 39
jm80= 38
jm81= 38

jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

f30 = open(dir+'Masstime030001.DAT')
f31 = open(dir+'Masstime031001.DAT')
f32 = open(dir+'Masstime032001.DAT')
f33 = open(dir+'Masstime033001.DAT')
f34 = open(dir+'Masstime034001.DAT')
f35 = open(dir+'Masstime035001.DAT')
f36 = open(dir+'Masstime036001.DAT')
f37 = open(dir+'Masstime037001.DAT')
f38 = open(dir+'Masstime038001.DAT')
f39 = open(dir+'Masstime039001.DAT')
f40 = open(dir+'Masstime040001.DAT')
f41 = open(dir+'Masstime041001.DAT')
f42 = open(dir+'Masstime042001.DAT')
f43 = open(dir+'Masstime043001.DAT')
f44 = open(dir+'Masstime044001.DAT')
f45 = open(dir+'Masstime045001.DAT')
f46 = open(dir+'Masstime046001.DAT')
f47 = open(dir+'Masstime047001.DAT')
f48 = open(dir+'Masstime048001.DAT')
f49 = open(dir+'Masstime049001.DAT')
f50 = open(dir+'Masstime050001.DAT')
f51 = open(dir+'Masstime051001.DAT')
f52 = open(dir+'Masstime052001.DAT')
f53 = open(dir+'Masstime053001.DAT')
f54 = open(dir+'Masstime054001.DAT')
f55 = open(dir+'Masstime055001.DAT')
f56 = open(dir+'Masstime056001.DAT')
f57 = open(dir+'Masstime057001.DAT')
f58 = open(dir+'Masstime058001.DAT')
f59 = open(dir+'Masstime059001.DAT')
f60 = open(dir+'Masstime060001.DAT')
f61 = open(dir+'Masstime061001.DAT')
f62 = open(dir+'Masstime062001.DAT')
f63 = open(dir+'Masstime063001.DAT')
f64 = open(dir+'Masstime064001.DAT')
f65 = open(dir+'Masstime065001.DAT')
f66 = open(dir+'Masstime066001.DAT')
f67 = open(dir+'Masstime067001.DAT')
f68 = open(dir+'Masstime068001.DAT')
f69 = open(dir+'Masstime069001.DAT')
f70 = open(dir+'Masstime070001.DAT')
f71 = open(dir+'Masstime071001.DAT')
f72 = open(dir+'Masstime072001.DAT')
f73 = open(dir+'Masstime073001.DAT')
f74 = open(dir+'Masstime074001.DAT')
f75 = open(dir+'Masstime075001.DAT')
f76 = open(dir+'Masstime076001.DAT')
f77 = open(dir+'Masstime077001.DAT')
f78 = open(dir+'Masstime078001.DAT')
f79 = open(dir+'Masstime079001.DAT')
f80 = open(dir+'Masstime080001.DAT')
f81 = open(dir+'Masstime081001.DAT')

f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')
f110 = open(dir+'Masstime110001.DAT')
f111 = open(dir+'Masstime111001.DAT')
f112 = open(dir+'Masstime112001.DAT')
f113 = open(dir+'Masstime113001.DAT')
f114 = open(dir+'Masstime114001.DAT')
f115 = open(dir+'Masstime115001.DAT')
f116 = open(dir+'Masstime116001.DAT')
f117 = open(dir+'Masstime117001.DAT')
f118 = open(dir+'Masstime118001.DAT')
f119 = open(dir+'Masstime119001.DAT')

#f99 = open(dir+'Masstime099001.DAT')
ary30 = np.fromfile(f30, np.float64,count=im*jm30)
ary31 = np.fromfile(f31, np.float64,count=im*jm31)
ary32 = np.fromfile(f32, np.float64,count=im*jm32)
ary33 = np.fromfile(f33, np.float64,count=im*jm33)
ary34 = np.fromfile(f34, np.float64,count=im*jm34)
ary35 = np.fromfile(f35, np.float64,count=im*jm35)
ary36 = np.fromfile(f36, np.float64,count=im*jm36)
ary37 = np.fromfile(f37, np.float64,count=im*jm37)
ary38 = np.fromfile(f38, np.float64,count=im*jm38)
ary39 = np.fromfile(f39, np.float64,count=im*jm39)
ary40 = np.fromfile(f40, np.float64,count=im*jm40)
ary41 = np.fromfile(f41, np.float64,count=im*jm41)
ary42 = np.fromfile(f42, np.float64,count=im*jm42)
ary43 = np.fromfile(f43, np.float64,count=im*jm43)
ary44 = np.fromfile(f44, np.float64,count=im*jm44)
ary45 = np.fromfile(f45, np.float64,count=im*jm45)
ary46 = np.fromfile(f46, np.float64,count=im*jm46)
ary47 = np.fromfile(f47, np.float64,count=im*jm47)
ary48 = np.fromfile(f48, np.float64,count=im*jm48)
ary49 = np.fromfile(f49, np.float64,count=im*jm49)
ary50 = np.fromfile(f50, np.float64,count=im*jm50)
ary51 = np.fromfile(f51, np.float64,count=im*jm51)
ary52 = np.fromfile(f52, np.float64,count=im*jm52)
ary53 = np.fromfile(f53, np.float64,count=im*jm53)
ary54 = np.fromfile(f54, np.float64,count=im*jm54)
ary55 = np.fromfile(f55, np.float64,count=im*jm55)
ary56 = np.fromfile(f56, np.float64,count=im*jm56)
ary57 = np.fromfile(f57, np.float64,count=im*jm57)
ary58 = np.fromfile(f58, np.float64,count=im*jm58)
ary59 = np.fromfile(f59, np.float64,count=im*jm59)
ary60 = np.fromfile(f60, np.float64,count=im*jm60)
ary61 = np.fromfile(f61, np.float64,count=im*jm61)
ary62 = np.fromfile(f62, np.float64,count=im*jm62)
ary63 = np.fromfile(f63, np.float64,count=im*jm63)
ary64 = np.fromfile(f64, np.float64,count=im*jm64)
ary65 = np.fromfile(f65, np.float64,count=im*jm65)
ary66 = np.fromfile(f66, np.float64,count=im*jm66)
ary67 = np.fromfile(f67, np.float64,count=im*jm67)
ary68 = np.fromfile(f68, np.float64,count=im*jm68)
ary69 = np.fromfile(f69, np.float64,count=im*jm69)
ary70 = np.fromfile(f70, np.float64,count=im*jm70)
ary71 = np.fromfile(f71, np.float64,count=im*jm71)
ary72 = np.fromfile(f72, np.float64,count=im*jm72)
ary73 = np.fromfile(f73, np.float64,count=im*jm73)
ary74 = np.fromfile(f74, np.float64,count=im*jm74)
ary75 = np.fromfile(f75, np.float64,count=im*jm75)
ary76 = np.fromfile(f76, np.float64,count=im*jm76)
ary77 = np.fromfile(f77, np.float64,count=im*jm77)
ary78 = np.fromfile(f78, np.float64,count=im*jm78)
ary79 = np.fromfile(f79, np.float64,count=im*jm79)
ary80 = np.fromfile(f80, np.float64,count=im*jm80)
ary81 = np.fromfile(f81, np.float64,count=im*jm81)

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
ary110 = np.fromfile(f110, np.float64,count=im*jm110)
ary111 = np.fromfile(f111, np.float64,count=im*jm111)
ary112 = np.fromfile(f112, np.float64,count=im*jm112)
ary113 = np.fromfile(f113, np.float64,count=im*jm113)
ary114 = np.fromfile(f114, np.float64,count=im*jm114)
ary115 = np.fromfile(f115, np.float64,count=im*jm115)
ary116 = np.fromfile(f116, np.float64,count=im*jm116)
ary117 = np.fromfile(f117, np.float64,count=im*jm117)
ary118 = np.fromfile(f118, np.float64,count=im*jm118)
ary119 = np.fromfile(f119, np.float64,count=im*jm119)

#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy30 = ary30.reshape(im,jm30,order='F')
uvhpy31 = ary31.reshape(im,jm31,order='F')
uvhpy32 = ary32.reshape(im,jm32,order='F')
uvhpy33 = ary33.reshape(im,jm33,order='F')
uvhpy34 = ary34.reshape(im,jm34,order='F')
uvhpy35 = ary35.reshape(im,jm35,order='F')
uvhpy36 = ary36.reshape(im,jm36,order='F')
uvhpy37 = ary37.reshape(im,jm37,order='F')
uvhpy38 = ary38.reshape(im,jm38,order='F')
uvhpy39 = ary39.reshape(im,jm39,order='F')
uvhpy40 = ary40.reshape(im,jm40,order='F')
uvhpy41 = ary41.reshape(im,jm41,order='F')
uvhpy42 = ary42.reshape(im,jm42,order='F')
uvhpy43 = ary43.reshape(im,jm43,order='F')
uvhpy44 = ary44.reshape(im,jm44,order='F')
uvhpy45 = ary45.reshape(im,jm45,order='F')
uvhpy46 = ary46.reshape(im,jm46,order='F')
uvhpy47 = ary47.reshape(im,jm47,order='F')
uvhpy48 = ary48.reshape(im,jm48,order='F')
uvhpy49 = ary49.reshape(im,jm49,order='F')
uvhpy50 = ary50.reshape(im,jm50,order='F')
uvhpy51 = ary51.reshape(im,jm51,order='F')
uvhpy52 = ary52.reshape(im,jm52,order='F')
uvhpy53 = ary53.reshape(im,jm53,order='F')
uvhpy54 = ary54.reshape(im,jm54,order='F')
uvhpy55 = ary55.reshape(im,jm55,order='F')
uvhpy56 = ary56.reshape(im,jm56,order='F')
uvhpy57 = ary57.reshape(im,jm57,order='F')
uvhpy58 = ary58.reshape(im,jm58,order='F')
uvhpy59 = ary59.reshape(im,jm59,order='F')
uvhpy60 = ary60.reshape(im,jm60,order='F')
uvhpy61 = ary61.reshape(im,jm61,order='F')
uvhpy62 = ary62.reshape(im,jm62,order='F')
uvhpy63 = ary63.reshape(im,jm63,order='F')
uvhpy64 = ary64.reshape(im,jm64,order='F')
uvhpy65 = ary65.reshape(im,jm65,order='F')
uvhpy66 = ary66.reshape(im,jm66,order='F')
uvhpy67 = ary67.reshape(im,jm67,order='F')
uvhpy68 = ary68.reshape(im,jm68,order='F')
uvhpy69 = ary69.reshape(im,jm69,order='F')
uvhpy70 = ary70.reshape(im,jm70,order='F')
uvhpy71 = ary71.reshape(im,jm71,order='F')
uvhpy72 = ary72.reshape(im,jm72,order='F')
uvhpy73 = ary73.reshape(im,jm73,order='F')
uvhpy74 = ary74.reshape(im,jm74,order='F')
uvhpy75 = ary75.reshape(im,jm75,order='F')
uvhpy76 = ary76.reshape(im,jm76,order='F')
uvhpy77 = ary77.reshape(im,jm77,order='F')
uvhpy78 = ary78.reshape(im,jm78,order='F')
uvhpy79 = ary79.reshape(im,jm79,order='F')
uvhpy80 = ary80.reshape(im,jm80,order='F')
uvhpy81 = ary81.reshape(im,jm81,order='F')

uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
uvhpy110 = ary110.reshape(im,jm110,order='F')
uvhpy111= ary111.reshape(im,jm111,order='F')
uvhpy112 = ary112.reshape(im,jm112,order='F')
uvhpy113 = ary113.reshape(im,jm113,order='F')
uvhpy114 = ary114.reshape(im,jm114,order='F')
uvhpy115 = ary115.reshape(im,jm115,order='F')
uvhpy116 = ary116.reshape(im,jm116,order='F')
uvhpy117 = ary117.reshape(im,jm117,order='F')
uvhpy118 = ary118.reshape(im,jm118,order='F')
uvhpy119 = ary119.reshape(im,jm119,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')

time30 =uvhpy30[0,:]
time31 =uvhpy31[0,:]
time32 =uvhpy32[0,:]
time33 =uvhpy33[0,:]
time34 =uvhpy34[0,:]
time35 =uvhpy35[0,:]
time36 =uvhpy36[0,:]
time37 =uvhpy37[0,:]
time38 =uvhpy38[0,:]
time39 =uvhpy39[0,:]
time40 =uvhpy40[0,:]
time41 =uvhpy41[0,:]
time42 =uvhpy42[0,:]
time43 =uvhpy43[0,:]
time44 =uvhpy44[0,:]
time45 =uvhpy45[0,:]
time46 =uvhpy46[0,:]
time47 =uvhpy47[0,:]
time48 =uvhpy48[0,:]
time49 =uvhpy49[0,:]
time50 =uvhpy50[0,:]
time51 =uvhpy51[0,:]
time52 =uvhpy52[0,:]
time53 =uvhpy53[0,:]
time54 =uvhpy54[0,:]
time55 =uvhpy55[0,:]
time56 =uvhpy56[0,:]
time57 =uvhpy57[0,:]
time58 =uvhpy58[0,:]
time59 =uvhpy59[0,:]
time60 =uvhpy60[0,:]
time61 =uvhpy61[0,:]
time62 =uvhpy62[0,:]
time63 =uvhpy63[0,:]
time64 =uvhpy64[0,:]
time65 =uvhpy65[0,:]
time66 =uvhpy66[0,:]
time67 =uvhpy67[0,:]
time68 =uvhpy68[0,:]
time69 =uvhpy69[0,:]
time70 =uvhpy70[0,:]
time71 =uvhpy71[0,:]
time72 =uvhpy72[0,:]
time73 =uvhpy73[0,:]
time74 =uvhpy74[0,:]
time75 =uvhpy75[0,:]
time76 =uvhpy76[0,:]
time77 =uvhpy77[0,:]
time78 =uvhpy78[0,:]
time79 =uvhpy79[0,:]
time80 =uvhpy80[0,:]
time81 =uvhpy81[0,:]

time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
time110 =uvhpy110[0,:]
time111 =uvhpy111[0,:]
time112 =uvhpy112[0,:]
time113 =uvhpy113[0,:]
time114 =uvhpy114[0,:]
time115 =uvhpy115[0,:]
time116 =uvhpy116[0,:]
time117 =uvhpy117[0,:]
time118 =uvhpy118[0,:]
time119 =uvhpy119[0,:]
#time99 =uvhpy99[0,:]

mass30=uvhpy30[1,:]
mass31=uvhpy31[1,:]
mass32=uvhpy32[1,:]
mass33=uvhpy33[1,:]
mass34=uvhpy34[1,:]
mass35=uvhpy35[1,:]
mass36=uvhpy36[1,:]
mass37=uvhpy37[1,:]
mass38=uvhpy38[1,:]
mass39=uvhpy39[1,:]
mass40=uvhpy40[1,:]
mass41=uvhpy41[1,:]
mass42=uvhpy42[1,:]
mass43=uvhpy43[1,:]
mass44=uvhpy44[1,:]
mass45=uvhpy45[1,:]
mass46=uvhpy46[1,:]
mass47=uvhpy47[1,:]
mass48=uvhpy48[1,:]
mass49=uvhpy49[1,:]
mass50=uvhpy50[1,:]
mass51=uvhpy51[1,:]
mass52=uvhpy52[1,:]
mass53=uvhpy53[1,:]
mass54=uvhpy54[1,:]
mass55=uvhpy55[1,:]
mass56=uvhpy56[1,:]
mass57=uvhpy57[1,:]
mass58=uvhpy58[1,:]
mass59=uvhpy59[1,:]
mass60=uvhpy60[1,:]
mass61=uvhpy61[1,:]
mass62=uvhpy62[1,:]
mass63=uvhpy63[1,:]
mass64=uvhpy64[1,:]
mass65=uvhpy65[1,:]
mass66=uvhpy66[1,:]
mass67=uvhpy67[1,:]
mass68=uvhpy68[1,:]
mass69=uvhpy69[1,:]
mass70=uvhpy70[1,:]
mass71=uvhpy71[1,:]
mass72=uvhpy72[1,:]
mass73=uvhpy73[1,:]
mass74=uvhpy74[1,:]
mass75=uvhpy75[1,:]
mass76=uvhpy76[1,:]
mass77=uvhpy77[1,:]
mass78=uvhpy78[1,:]
mass79=uvhpy79[1,:]
mass80=uvhpy80[1,:]
mass81=uvhpy81[1,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]
mass110=uvhpy110[1,:]
mass111=uvhpy111[1,:]
mass112=uvhpy112[1,:]
mass113=uvhpy113[1,:]
mass114=uvhpy114[1,:]
mass115=uvhpy115[1,:]
mass116=uvhpy116[1,:]
mass117=uvhpy117[1,:]
mass118=uvhpy118[1,:]
mass119=uvhpy119[1,:]
#mass99=uvhpy99[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd30=uvhpy30[2,:]+1.0
fd31=uvhpy31[2,:]+1.0
fd32=uvhpy32[2,:]+1.0
fd33=uvhpy33[2,:]+1.0
fd34=uvhpy34[2,:]+1.0
fd35=uvhpy35[2,:]+1.0
fd36=uvhpy36[2,:]+1.0
fd37=uvhpy37[2,:]+1.0
fd38=uvhpy38[2,:]+1.0
fd39=uvhpy39[2,:]+1.0
fd40=uvhpy40[2,:]+1.0
fd41=uvhpy41[2,:]+1.0
fd42=uvhpy42[2,:]+1.0
fd43=uvhpy43[2,:]+1.0
fd44=uvhpy44[2,:]+1.0
fd45=uvhpy45[2,:]+1.0
fd46=uvhpy46[2,:]+1.0
fd47=uvhpy47[2,:]+1.0
fd48=uvhpy48[2,:]+1.0
fd49=uvhpy49[2,:]+1.0
fd50=uvhpy50[2,:]+1.0
fd51=uvhpy51[2,:]+1.0
fd52=uvhpy52[2,:]+1.0
fd53=uvhpy53[2,:]+1.0
fd54=uvhpy54[2,:]+1.0
fd55=uvhpy55[2,:]+1.0
fd56=uvhpy56[2,:]+1.0
fd57=uvhpy57[2,:]+1.0
fd58=uvhpy58[2,:]+1.0
fd59=uvhpy59[2,:]+1.0
fd60=uvhpy60[2,:]+1.0
fd61=uvhpy61[2,:]+1.0
fd62=uvhpy62[2,:]+1.0
fd63=uvhpy63[2,:]+1.0
fd64=uvhpy64[2,:]+1.0
fd65=uvhpy65[2,:]+1.0
fd66=uvhpy66[2,:]+1.0
fd67=uvhpy67[2,:]+1.0
fd68=uvhpy68[2,:]+1.0
fd69=uvhpy69[2,:]+1.0
fd70=uvhpy70[2,:]+1.0
fd71=uvhpy71[2,:]+1.0
fd72=uvhpy72[2,:]+1.0
fd73=uvhpy73[2,:]+1.0
fd74=uvhpy74[2,:]+1.0
fd75=uvhpy75[2,:]+1.0
fd76=uvhpy76[2,:]+1.0
fd77=uvhpy77[2,:]+1.0
fd78=uvhpy78[2,:]+1.0
fd79=uvhpy79[2,:]+1.0
fd80=uvhpy80[2,:]+1.0
fd81=uvhpy81[2,:]+1.0

'''
vfd82=(uvhpy82[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))/10.0/2.5
vfd83=(uvhpy83[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))/10.0/2.5
vfd84=(uvhpy84[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))/10.0/2.5
vfd85=(uvhpy85[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))/10.0/2.5
vfd86=(uvhpy86[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))/10.0/2.5
vfd87=(uvhpy87[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))/10.0/2.5
vfd88=(uvhpy88[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))/10.0/2.5
vfd89=(uvhpy89[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))/10.0/2.5
vfd90=(uvhpy90[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))/10.0/2.5
vfd91=(uvhpy91[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))/10.0/2.5
vfd92=(uvhpy92[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))/10.0/2.5
vfd93=(uvhpy93[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))/10.0/2.5
vfd94=(uvhpy94[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))/10.0/2.5
vfd95=(uvhpy95[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))/10.0/2.5
vfd96=(uvhpy96[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))/10.0/2.5
vfd97=(uvhpy97[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))/10.0/2.5
vfd98=(uvhpy98[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))/10.0/2.5
vfd99=(uvhpy99[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))/10.0/2.5
vfd100=(uvhpy100[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))/10.0/2.5
vfd101=(uvhpy101[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))/10.0/2.5
vfd102=(uvhpy102[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))/10.0/2.5
vfd103=(uvhpy103[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))/10.0/2.5
vfd104=(uvhpy104[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))/10.0/2.5
vfd105=(uvhpy105[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))/10.0/2.5
vfd106=(uvhpy106[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))/10.0/2.5
vfd107=(uvhpy107[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))/10.0/2.5
vfd108=(uvhpy108[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))/10.0/2.5
vfd109=(uvhpy109[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))/10.0/2.5
'''
'''
vfd82=(uvhpy82[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))
vfd83=(uvhpy83[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))
vfd84=(uvhpy84[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))
vfd85=(uvhpy85[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))
vfd86=(uvhpy86[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))
vfd87=(uvhpy87[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))
vfd88=(uvhpy88[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))
vfd89=(uvhpy89[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))
vfd90=(uvhpy90[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))
vfd91=(uvhpy91[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))
vfd92=(uvhpy92[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))
vfd93=(uvhpy93[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))
vfd94=(uvhpy94[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))
vfd95=(uvhpy95[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))
vfd96=(uvhpy96[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))
vfd97=(uvhpy97[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))
vfd98=(uvhpy98[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))
vfd99=(uvhpy99[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))
vfd100=(uvhpy100[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))
vfd101=(uvhpy101[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))
vfd102=(uvhpy102[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))
vfd103=(uvhpy103[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))
vfd104=(uvhpy104[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))
vfd105=(uvhpy105[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))
vfd106=(uvhpy106[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))
vfd107=(uvhpy107[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))
vfd108=(uvhpy108[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))
vfd109=(uvhpy109[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))
'''
'''
vfd82=(uvhpy82[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))/10.0
vfd83=(uvhpy83[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))/10.0
vfd84=(uvhpy84[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))/10.0
vfd85=(uvhpy85[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))/10.0
vfd86=(uvhpy86[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))/10.0
vfd87=(uvhpy87[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))/10.0
vfd88=(uvhpy88[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))/10.0
vfd89=(uvhpy89[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))/10.0
vfd90=(uvhpy90[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))/10.0
vfd91=(uvhpy91[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))/10.0
vfd92=(uvhpy92[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))/10.0
vfd93=(uvhpy93[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))/10.0
vfd94=(uvhpy94[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))/10.0
vfd95=(uvhpy95[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))/10.0
vfd96=(uvhpy96[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))/10.0
vfd97=(uvhpy97[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))/10.0
vfd98=(uvhpy98[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))/10.0
vfd99=(uvhpy99[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))/10.0
vfd100=(uvhpy100[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))/10.0
vfd101=(uvhpy101[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))/10.0
vfd102=(uvhpy102[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))/10.0
vfd103=(uvhpy103[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))/10.0
vfd104=(uvhpy104[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))/10.0
vfd105=(uvhpy105[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))/10.0
vfd106=(uvhpy106[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))/10.0
vfd107=(uvhpy107[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))/10.0
vfd108=(uvhpy108[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))/10.0
vfd109=(uvhpy109[3,:]/2.0/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))/10.0
'''
vfd30=(uvhpy30[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass30/(30000.0))/10.0
vfd31=(uvhpy31[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass31/(30000.0))/10.0
vfd32=(uvhpy32[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass32/(30000.0))/10.0
vfd33=(uvhpy33[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass33/(30000.0))/10.0
vfd34=(uvhpy34[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass34/(30000.0))/10.0
vfd35=(uvhpy35[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass35/(30000.0))/10.0
vfd36=(uvhpy36[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass36/(30000.0))/10.0
vfd37=(uvhpy37[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass37/(30000.0))/10.0
vfd38=(uvhpy38[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass38/(30000.0))/10.0
vfd39=(uvhpy39[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass39/(30000.0))/10.0
vfd40=(uvhpy40[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass40/(30000.0))/10.0
vfd41=(uvhpy41[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass41/(30000.0))/10.0
vfd42=(uvhpy42[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass42/(30000.0))/10.0
vfd43=(uvhpy43[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass43/(30000.0))/10.0
vfd44=(uvhpy44[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass44/(30000.0))/10.0
vfd45=(uvhpy45[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass45/(30000.0))/10.0
vfd46=(uvhpy46[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass46/(30000.0))/10.0
vfd47=(uvhpy47[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass47/(30000.0))/10.0
vfd48=(uvhpy48[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass48/(30000.0))/10.0
vfd49=(uvhpy49[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass49/(30000.0))/10.0
vfd50=(uvhpy50[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass50/(30000.0))/10.0
vfd51=(uvhpy51[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass51/(30000.0))/10.0
vfd52=(uvhpy52[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass52/(30000.0))/10.0
vfd53=(uvhpy53[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass53/(30000.0))/10.0
vfd54=(uvhpy54[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass54/(30000.0))/10.0
vfd55=(uvhpy55[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass55/(30000.0))/10.0
vfd56=(uvhpy56[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass56/(30000.0))/10.0
vfd57=(uvhpy57[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass57/(30000.0))/10.0
vfd58=(uvhpy58[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass58/(30000.0))/10.0
vfd59=(uvhpy59[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass59/(30000.0))/10.0
vfd60=(uvhpy60[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass60/(30000.0))/10.0
vfd61=(uvhpy61[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass61/(30000.0))/10.0
vfd62=(uvhpy62[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass62/(30000.0))/10.0
vfd63=(uvhpy63[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass63/(30000.0))/10.0
vfd64=(uvhpy64[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass64/(30000.0))/10.0
vfd65=(uvhpy65[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass65/(30000.0))/10.0
vfd66=(uvhpy66[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass66/(30000.0))/10.0
vfd67=(uvhpy67[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass67/(30000.0))/10.0
vfd68=(uvhpy68[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass68/(30000.0))/10.0
vfd69=(uvhpy69[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass69/(30000.0))/10.0
vfd70=(uvhpy70[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass70/(30000.0))/10.0
vfd71=(uvhpy71[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass71/(30000.0))/10.0
vfd72=(uvhpy72[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass72/(30000.0))/10.0
vfd73=(uvhpy73[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass73/(30000.0))/10.0
vfd74=(uvhpy74[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass74/(30000.0))/10.0
vfd75=(uvhpy75[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass75/(30000.0))/10.0
vfd76=(uvhpy76[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass76/(30000.0))/10.0
vfd77=(uvhpy77[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass77/(30000.0))/10.0
vfd78=(uvhpy78[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass78/(30000.0))/10.0
vfd79=(uvhpy79[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass79/(30000.0))/10.0
vfd80=(uvhpy80[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass80/(30000.0))/10.0
vfd81=(uvhpy81[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass81/(30000.0))/10.0

vfd82=(uvhpy82[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass82/(30000.0))/10.0
vfd83=(uvhpy83[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass83/(30000.0))/10.0
vfd84=(uvhpy84[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass84/(30000.0))/10.0
vfd85=(uvhpy85[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass85/(30000.0))/10.0
vfd86=(uvhpy86[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass86/(30000.0))/10.0
vfd87=(uvhpy87[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass87/(30000.0))/10.0
vfd88=(uvhpy88[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass88/(30000.0))/10.0
vfd89=(uvhpy89[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass89/(30000.0))/10.0
vfd90=(uvhpy90[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass90/(30000.0))/10.0
vfd91=(uvhpy91[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass91/(30000.0))/10.0
vfd92=(uvhpy92[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass92/(30000.0))/10.0
vfd93=(uvhpy93[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass93/(30000.0))/10.0
vfd94=(uvhpy94[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass94/(30000.0))/10.0
vfd95=(uvhpy95[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass95/(30000.0))/10.0
vfd96=(uvhpy96[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass96/(30000.0))/10.0
vfd97=(uvhpy97[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass97/(30000.0))/10.0
vfd98=(uvhpy98[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass98/(30000.0))/10.0
vfd99=(uvhpy99[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass99/(30000.0))/10.0
vfd100=(uvhpy100[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass100/(30000.0))/10.0
vfd101=(uvhpy101[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass101/(30000.0))/10.0
vfd102=(uvhpy102[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass102/(30000.0))/10.0
vfd103=(uvhpy103[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass103/(30000.0))/10.0
vfd104=(uvhpy104[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass104/(30000.0))/10.0
vfd105=(uvhpy105[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass105/(30000.0))/10.0
vfd106=(uvhpy106[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass106/(30000.0))/10.0
vfd107=(uvhpy107[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass107/(30000.0))/10.0
vfd108=(uvhpy108[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass108/(30000.0))/10.0
vfd109=(uvhpy109[3,:]/2.0)**(-0.5)*10.0*np.sqrt(mass109/(30000.0))/10.0

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
plt.scatter(time30, mass30, s=5.9,c=vfd30, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time31, mass31, s=5.9,c=vfd31, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time32, mass32, s=5.9,c=vfd32, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time33, mass33, s=5.9,c=vfd33, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time34, mass34, s=5.9,c=vfd34, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time35, mass35, s=5.9,c=vfd35, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time36, mass36, s=5.9,c=vfd36, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time37, mass37, s=5.9,c=vfd37, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time38, mass38, s=5.9,c=vfd38, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time39, mass39, s=5.9,c=vfd39, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time40, mass40, s=5.9,c=vfd40, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time41, mass41, s=5.9,c=vfd41, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time42, mass42, s=5.9,c=vfd42, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time43, mass43, s=5.9,c=vfd43, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time44, mass44, s=5.9,c=vfd44, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time45, mass45, s=5.9,c=vfd45, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time46, mass46, s=5.9,c=vfd46, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time47, mass47, s=5.9,c=vfd47, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time48, mass48, s=5.9,c=vfd48, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time49, mass49, s=5.9,c=vfd49, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time50, mass50, s=5.9,c=vfd50, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time51, mass51, s=5.9,c=vfd51, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time52, mass52, s=5.9,c=vfd52, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time53, mass53, s=5.9,c=vfd53, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time54, mass54, s=5.9,c=vfd54, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time55, mass55, s=5.9,c=vfd55, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time56, mass56, s=5.9,c=vfd56, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time57, mass57, s=5.9,c=vfd57, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time58, mass58, s=5.9,c=vfd58, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time59, mass59, s=5.9,c=vfd59, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time60, mass60, s=5.9,c=vfd60, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time61, mass61, s=5.9,c=vfd61, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time62, mass62, s=5.9,c=vfd62, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time63, mass63, s=5.9,c=vfd63, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time64, mass64, s=5.9,c=vfd64, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time65, mass65, s=5.9,c=vfd65, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time66, mass66, s=5.9,c=vfd66, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time67, mass67, s=5.9,c=vfd67, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time68, mass68, s=5.9,c=vfd68, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time69, mass69, s=5.9,c=vfd69, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time70, mass70, s=5.9,c=vfd70, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time71, mass71, s=5.9,c=vfd71, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time72, mass72, s=5.9,c=vfd72, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time73, mass73, s=5.9,c=vfd73, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time74, mass74, s=5.9,c=vfd74, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time75, mass75, s=5.9,c=vfd75, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time76, mass76, s=5.9,c=vfd76, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time77, mass77, s=5.9,c=vfd77, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time78, mass78, s=5.9,c=vfd78, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time79, mass79, s=5.9,c=vfd79, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time80, mass80, s=5.9,c=vfd80, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time81, mass81, s=5.9,c=vfd81, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())

plt.scatter(time82, mass82, s=5.9,c=vfd82, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=vfd83, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=vfd84, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=vfd85, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=vfd86, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=vfd87, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=vfd88, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=vfd89, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=vfd90, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=vfd91, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=vfd92, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=vfd93, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=vfd94, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=vfd95, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=vfd96, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=vfd97, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=vfd98, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=vfd99, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())

plt.scatter(time100, mass100, s=5.9,c=vfd100, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=vfd101, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=vfd102, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=vfd103, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=vfd104, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=vfd105, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=vfd106, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=vfd107, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=vfd108, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=vfd109, cmap=cm.cool, vmin=0.0, vmax=2.0)#, norm=LogNorm())

#pp.set_clim(0.1,10)
plt.clim(0, 2) 
plt.colorbar()

print()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
# Out:
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:802: RuntimeWarning: divide by zero encountered in power
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:803: RuntimeWarning: divide by zero encountered in power
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:804: RuntimeWarning: divide by zero encountered in power
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:805: RuntimeWarning: divide by zero encountered in power
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:806: RuntimeWarning: divide by zero encountered in power
# /Users/maeda/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:807: RuntimeWarning: divide by zero encountered in power
# ...

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''
jm30= 0
jm31= 0
jm32= 0
jm33= 0
jm34= 0
jm35= 0
jm36= 0
jm37= 0
jm38= 0
jm39= 0
jm40= 0
jm41= 0
jm42= 0
jm43= 0
jm44= 0
jm45= 0
jm46= 1
jm47= 2
jm48= 3
jm49= 5
jm50= 4
jm51= 4
jm52= 4
jm53= 5
jm54= 5
jm55= 6
jm56= 7
jm57= 7
jm58= 9
jm59= 10
jm60= 10
jm61= 14
jm62= 16
jm63= 16
jm64= 19
jm65= 21
jm66= 19
jm67= 21
jm68= 25
jm69= 26
jm70= 28
jm71= 30
jm72= 33
jm73= 37
jm74= 39
jm75= 42
jm76= 38
jm77= 41
jm78= 38
jm79= 39
jm80= 38
jm81= 38

jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24
jm110= 25
jm111= 15
jm112= 15
jm113= 16
jm114= 12
jm115= 12
jm116= 10
jm117= 6
jm118= 6
jm119= 3

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定

#f90 = open(dir+'SFPhi-R098-D1B1Z1.DAT', 'rb')
#f91 = open(dir+'SFPhi-R008-D10B3Z1.DAT', 'rb')
#f90 = open(dir+'r-v75r085.DAT','rb')
f30 = open(dir+'Masstime030001.DAT')
f31 = open(dir+'Masstime031001.DAT')
f32 = open(dir+'Masstime032001.DAT')
f33 = open(dir+'Masstime033001.DAT')
f34 = open(dir+'Masstime034001.DAT')
f35 = open(dir+'Masstime035001.DAT')
f36 = open(dir+'Masstime036001.DAT')
f37 = open(dir+'Masstime037001.DAT')
f38 = open(dir+'Masstime038001.DAT')
f39 = open(dir+'Masstime039001.DAT')
f40 = open(dir+'Masstime040001.DAT')
f41 = open(dir+'Masstime041001.DAT')
f42 = open(dir+'Masstime042001.DAT')
f43 = open(dir+'Masstime043001.DAT')
f44 = open(dir+'Masstime044001.DAT')
f45 = open(dir+'Masstime045001.DAT')
f46 = open(dir+'Masstime046001.DAT')
f47 = open(dir+'Masstime047001.DAT')
f48 = open(dir+'Masstime048001.DAT')
f49 = open(dir+'Masstime049001.DAT')
f50 = open(dir+'Masstime050001.DAT')
f51 = open(dir+'Masstime051001.DAT')
f52 = open(dir+'Masstime052001.DAT')
f53 = open(dir+'Masstime053001.DAT')
f54 = open(dir+'Masstime054001.DAT')
f55 = open(dir+'Masstime055001.DAT')
f56 = open(dir+'Masstime056001.DAT')
f57 = open(dir+'Masstime057001.DAT')
f58 = open(dir+'Masstime058001.DAT')
f59 = open(dir+'Masstime059001.DAT')
f60 = open(dir+'Masstime060001.DAT')
f61 = open(dir+'Masstime061001.DAT')
f62 = open(dir+'Masstime062001.DAT')
f63 = open(dir+'Masstime063001.DAT')
f64 = open(dir+'Masstime064001.DAT')
f65 = open(dir+'Masstime065001.DAT')
f66 = open(dir+'Masstime066001.DAT')
f67 = open(dir+'Masstime067001.DAT')
f68 = open(dir+'Masstime068001.DAT')
f69 = open(dir+'Masstime069001.DAT')
f70 = open(dir+'Masstime070001.DAT')
f71 = open(dir+'Masstime071001.DAT')
f72 = open(dir+'Masstime072001.DAT')
f73 = open(dir+'Masstime073001.DAT')
f74 = open(dir+'Masstime074001.DAT')
f75 = open(dir+'Masstime075001.DAT')
f76 = open(dir+'Masstime076001.DAT')
f77 = open(dir+'Masstime077001.DAT')
f78 = open(dir+'Masstime078001.DAT')
f79 = open(dir+'Masstime079001.DAT')
f80 = open(dir+'Masstime080001.DAT')
f81 = open(dir+'Masstime081001.DAT')

f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')
f110 = open(dir+'Masstime110001.DAT')
f111 = open(dir+'Masstime111001.DAT')
f112 = open(dir+'Masstime112001.DAT')
f113 = open(dir+'Masstime113001.DAT')
f114 = open(dir+'Masstime114001.DAT')
f115 = open(dir+'Masstime115001.DAT')
f116 = open(dir+'Masstime116001.DAT')
f117 = open(dir+'Masstime117001.DAT')
f118 = open(dir+'Masstime118001.DAT')
f119 = open(dir+'Masstime119001.DAT')

#f99 = open(dir+'Masstime099001.DAT')
ary30 = np.fromfile(f30, np.float64,count=im*jm30)
ary31 = np.fromfile(f31, np.float64,count=im*jm31)
ary32 = np.fromfile(f32, np.float64,count=im*jm32)
ary33 = np.fromfile(f33, np.float64,count=im*jm33)
ary34 = np.fromfile(f34, np.float64,count=im*jm34)
ary35 = np.fromfile(f35, np.float64,count=im*jm35)
ary36 = np.fromfile(f36, np.float64,count=im*jm36)
ary37 = np.fromfile(f37, np.float64,count=im*jm37)
ary38 = np.fromfile(f38, np.float64,count=im*jm38)
ary39 = np.fromfile(f39, np.float64,count=im*jm39)
ary40 = np.fromfile(f40, np.float64,count=im*jm40)
ary41 = np.fromfile(f41, np.float64,count=im*jm41)
ary42 = np.fromfile(f42, np.float64,count=im*jm42)
ary43 = np.fromfile(f43, np.float64,count=im*jm43)
ary44 = np.fromfile(f44, np.float64,count=im*jm44)
ary45 = np.fromfile(f45, np.float64,count=im*jm45)
ary46 = np.fromfile(f46, np.float64,count=im*jm46)
ary47 = np.fromfile(f47, np.float64,count=im*jm47)
ary48 = np.fromfile(f48, np.float64,count=im*jm48)
ary49 = np.fromfile(f49, np.float64,count=im*jm49)
ary50 = np.fromfile(f50, np.float64,count=im*jm50)
ary51 = np.fromfile(f51, np.float64,count=im*jm51)
ary52 = np.fromfile(f52, np.float64,count=im*jm52)
ary53 = np.fromfile(f53, np.float64,count=im*jm53)
ary54 = np.fromfile(f54, np.float64,count=im*jm54)
ary55 = np.fromfile(f55, np.float64,count=im*jm55)
ary56 = np.fromfile(f56, np.float64,count=im*jm56)
ary57 = np.fromfile(f57, np.float64,count=im*jm57)
ary58 = np.fromfile(f58, np.float64,count=im*jm58)
ary59 = np.fromfile(f59, np.float64,count=im*jm59)
ary60 = np.fromfile(f60, np.float64,count=im*jm60)
ary61 = np.fromfile(f61, np.float64,count=im*jm61)
ary62 = np.fromfile(f62, np.float64,count=im*jm62)
ary63 = np.fromfile(f63, np.float64,count=im*jm63)
ary64 = np.fromfile(f64, np.float64,count=im*jm64)
ary65 = np.fromfile(f65, np.float64,count=im*jm65)
ary66 = np.fromfile(f66, np.float64,count=im*jm66)
ary67 = np.fromfile(f67, np.float64,count=im*jm67)
ary68 = np.fromfile(f68, np.float64,count=im*jm68)
ary69 = np.fromfile(f69, np.float64,count=im*jm69)
ary70 = np.fromfile(f70, np.float64,count=im*jm70)
ary71 = np.fromfile(f71, np.float64,count=im*jm71)
ary72 = np.fromfile(f72, np.float64,count=im*jm72)
ary73 = np.fromfile(f73, np.float64,count=im*jm73)
ary74 = np.fromfile(f74, np.float64,count=im*jm74)
ary75 = np.fromfile(f75, np.float64,count=im*jm75)
ary76 = np.fromfile(f76, np.float64,count=im*jm76)
ary77 = np.fromfile(f77, np.float64,count=im*jm77)
ary78 = np.fromfile(f78, np.float64,count=im*jm78)
ary79 = np.fromfile(f79, np.float64,count=im*jm79)
ary80 = np.fromfile(f80, np.float64,count=im*jm80)
ary81 = np.fromfile(f81, np.float64,count=im*jm81)

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)
ary110 = np.fromfile(f110, np.float64,count=im*jm110)
ary111 = np.fromfile(f111, np.float64,count=im*jm111)
ary112 = np.fromfile(f112, np.float64,count=im*jm112)
ary113 = np.fromfile(f113, np.float64,count=im*jm113)
ary114 = np.fromfile(f114, np.float64,count=im*jm114)
ary115 = np.fromfile(f115, np.float64,count=im*jm115)
ary116 = np.fromfile(f116, np.float64,count=im*jm116)
ary117 = np.fromfile(f117, np.float64,count=im*jm117)
ary118 = np.fromfile(f118, np.float64,count=im*jm118)
ary119 = np.fromfile(f119, np.float64,count=im*jm119)

#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)
uvhpy30 = ary30.reshape(im,jm30,order='F')
uvhpy31 = ary31.reshape(im,jm31,order='F')
uvhpy32 = ary32.reshape(im,jm32,order='F')
uvhpy33 = ary33.reshape(im,jm33,order='F')
uvhpy34 = ary34.reshape(im,jm34,order='F')
uvhpy35 = ary35.reshape(im,jm35,order='F')
uvhpy36 = ary36.reshape(im,jm36,order='F')
uvhpy37 = ary37.reshape(im,jm37,order='F')
uvhpy38 = ary38.reshape(im,jm38,order='F')
uvhpy39 = ary39.reshape(im,jm39,order='F')
uvhpy40 = ary40.reshape(im,jm40,order='F')
uvhpy41 = ary41.reshape(im,jm41,order='F')
uvhpy42 = ary42.reshape(im,jm42,order='F')
uvhpy43 = ary43.reshape(im,jm43,order='F')
uvhpy44 = ary44.reshape(im,jm44,order='F')
uvhpy45 = ary45.reshape(im,jm45,order='F')
uvhpy46 = ary46.reshape(im,jm46,order='F')
uvhpy47 = ary47.reshape(im,jm47,order='F')
uvhpy48 = ary48.reshape(im,jm48,order='F')
uvhpy49 = ary49.reshape(im,jm49,order='F')
uvhpy50 = ary50.reshape(im,jm50,order='F')
uvhpy51 = ary51.reshape(im,jm51,order='F')
uvhpy52 = ary52.reshape(im,jm52,order='F')
uvhpy53 = ary53.reshape(im,jm53,order='F')
uvhpy54 = ary54.reshape(im,jm54,order='F')
uvhpy55 = ary55.reshape(im,jm55,order='F')
uvhpy56 = ary56.reshape(im,jm56,order='F')
uvhpy57 = ary57.reshape(im,jm57,order='F')
uvhpy58 = ary58.reshape(im,jm58,order='F')
uvhpy59 = ary59.reshape(im,jm59,order='F')
uvhpy60 = ary60.reshape(im,jm60,order='F')
uvhpy61 = ary61.reshape(im,jm61,order='F')
uvhpy62 = ary62.reshape(im,jm62,order='F')
uvhpy63 = ary63.reshape(im,jm63,order='F')
uvhpy64 = ary64.reshape(im,jm64,order='F')
uvhpy65 = ary65.reshape(im,jm65,order='F')
uvhpy66 = ary66.reshape(im,jm66,order='F')
uvhpy67 = ary67.reshape(im,jm67,order='F')
uvhpy68 = ary68.reshape(im,jm68,order='F')
uvhpy69 = ary69.reshape(im,jm69,order='F')
uvhpy70 = ary70.reshape(im,jm70,order='F')
uvhpy71 = ary71.reshape(im,jm71,order='F')
uvhpy72 = ary72.reshape(im,jm72,order='F')
uvhpy73 = ary73.reshape(im,jm73,order='F')
uvhpy74 = ary74.reshape(im,jm74,order='F')
uvhpy75 = ary75.reshape(im,jm75,order='F')
uvhpy76 = ary76.reshape(im,jm76,order='F')
uvhpy77 = ary77.reshape(im,jm77,order='F')
uvhpy78 = ary78.reshape(im,jm78,order='F')
uvhpy79 = ary79.reshape(im,jm79,order='F')
uvhpy80 = ary80.reshape(im,jm80,order='F')
uvhpy81 = ary81.reshape(im,jm81,order='F')

uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')
uvhpy110 = ary110.reshape(im,jm110,order='F')
uvhpy111= ary111.reshape(im,jm111,order='F')
uvhpy112 = ary112.reshape(im,jm112,order='F')
uvhpy113 = ary113.reshape(im,jm113,order='F')
uvhpy114 = ary114.reshape(im,jm114,order='F')
uvhpy115 = ary115.reshape(im,jm115,order='F')
uvhpy116 = ary116.reshape(im,jm116,order='F')
uvhpy117 = ary117.reshape(im,jm117,order='F')
uvhpy118 = ary118.reshape(im,jm118,order='F')
uvhpy119 = ary119.reshape(im,jm119,order='F')
#uvhpy99 = ary99.reshape(im,jm99,order='F')
#uvhpy91 = ary91.reshape(im,km,order='F')

time30 =uvhpy30[0,:]
time31 =uvhpy31[0,:]
time32 =uvhpy32[0,:]
time33 =uvhpy33[0,:]
time34 =uvhpy34[0,:]
time35 =uvhpy35[0,:]
time36 =uvhpy36[0,:]
time37 =uvhpy37[0,:]
time38 =uvhpy38[0,:]
time39 =uvhpy39[0,:]
time40 =uvhpy40[0,:]
time41 =uvhpy41[0,:]
time42 =uvhpy42[0,:]
time43 =uvhpy43[0,:]
time44 =uvhpy44[0,:]
time45 =uvhpy45[0,:]
time46 =uvhpy46[0,:]
time47 =uvhpy47[0,:]
time48 =uvhpy48[0,:]
time49 =uvhpy49[0,:]
time50 =uvhpy50[0,:]
time51 =uvhpy51[0,:]
time52 =uvhpy52[0,:]
time53 =uvhpy53[0,:]
time54 =uvhpy54[0,:]
time55 =uvhpy55[0,:]
time56 =uvhpy56[0,:]
time57 =uvhpy57[0,:]
time58 =uvhpy58[0,:]
time59 =uvhpy59[0,:]
time60 =uvhpy60[0,:]
time61 =uvhpy61[0,:]
time62 =uvhpy62[0,:]
time63 =uvhpy63[0,:]
time64 =uvhpy64[0,:]
time65 =uvhpy65[0,:]
time66 =uvhpy66[0,:]
time67 =uvhpy67[0,:]
time68 =uvhpy68[0,:]
time69 =uvhpy69[0,:]
time70 =uvhpy70[0,:]
time71 =uvhpy71[0,:]
time72 =uvhpy72[0,:]
time73 =uvhpy73[0,:]
time74 =uvhpy74[0,:]
time75 =uvhpy75[0,:]
time76 =uvhpy76[0,:]
time77 =uvhpy77[0,:]
time78 =uvhpy78[0,:]
time79 =uvhpy79[0,:]
time80 =uvhpy80[0,:]
time81 =uvhpy81[0,:]

time82 =uvhpy82[0,:]
time83 =uvhpy83[0,:]
time84 =uvhpy84[0,:]
time85 =uvhpy85[0,:]
time86 =uvhpy86[0,:]
time87 =uvhpy87[0,:]
time88 =uvhpy88[0,:]
time89 =uvhpy89[0,:]
time90 =uvhpy90[0,:]
time91 =uvhpy91[0,:]
time92 =uvhpy92[0,:]
time93 =uvhpy93[0,:]
time94 =uvhpy94[0,:]
time95 =uvhpy95[0,:]
time96 =uvhpy96[0,:]
time97 =uvhpy97[0,:]
time98 =uvhpy98[0,:]
time99 =uvhpy99[0,:]
time100 =uvhpy100[0,:]
time101 =uvhpy101[0,:]
time102 =uvhpy102[0,:]
time103 =uvhpy103[0,:]
time104 =uvhpy104[0,:]
time105 =uvhpy105[0,:]
time106 =uvhpy106[0,:]
time107 =uvhpy107[0,:]
time108 =uvhpy108[0,:]
time109 =uvhpy109[0,:]
time110 =uvhpy110[0,:]
time111 =uvhpy111[0,:]
time112 =uvhpy112[0,:]
time113 =uvhpy113[0,:]
time114 =uvhpy114[0,:]
time115 =uvhpy115[0,:]
time116 =uvhpy116[0,:]
time117 =uvhpy117[0,:]
time118 =uvhpy118[0,:]
time119 =uvhpy119[0,:]
#time99 =uvhpy99[0,:]

mass30=uvhpy30[1,:]
mass31=uvhpy31[1,:]
mass32=uvhpy32[1,:]
mass33=uvhpy33[1,:]
mass34=uvhpy34[1,:]
mass35=uvhpy35[1,:]
mass36=uvhpy36[1,:]
mass37=uvhpy37[1,:]
mass38=uvhpy38[1,:]
mass39=uvhpy39[1,:]
mass40=uvhpy40[1,:]
mass41=uvhpy41[1,:]
mass42=uvhpy42[1,:]
mass43=uvhpy43[1,:]
mass44=uvhpy44[1,:]
mass45=uvhpy45[1,:]
mass46=uvhpy46[1,:]
mass47=uvhpy47[1,:]
mass48=uvhpy48[1,:]
mass49=uvhpy49[1,:]
mass50=uvhpy50[1,:]
mass51=uvhpy51[1,:]
mass52=uvhpy52[1,:]
mass53=uvhpy53[1,:]
mass54=uvhpy54[1,:]
mass55=uvhpy55[1,:]
mass56=uvhpy56[1,:]
mass57=uvhpy57[1,:]
mass58=uvhpy58[1,:]
mass59=uvhpy59[1,:]
mass60=uvhpy60[1,:]
mass61=uvhpy61[1,:]
mass62=uvhpy62[1,:]
mass63=uvhpy63[1,:]
mass64=uvhpy64[1,:]
mass65=uvhpy65[1,:]
mass66=uvhpy66[1,:]
mass67=uvhpy67[1,:]
mass68=uvhpy68[1,:]
mass69=uvhpy69[1,:]
mass70=uvhpy70[1,:]
mass71=uvhpy71[1,:]
mass72=uvhpy72[1,:]
mass73=uvhpy73[1,:]
mass74=uvhpy74[1,:]
mass75=uvhpy75[1,:]
mass76=uvhpy76[1,:]
mass77=uvhpy77[1,:]
mass78=uvhpy78[1,:]
mass79=uvhpy79[1,:]
mass80=uvhpy80[1,:]
mass81=uvhpy81[1,:]

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]
mass110=uvhpy110[1,:]
mass111=uvhpy111[1,:]
mass112=uvhpy112[1,:]
mass113=uvhpy113[1,:]
mass114=uvhpy114[1,:]
mass115=uvhpy115[1,:]
mass116=uvhpy116[1,:]
mass117=uvhpy117[1,:]
mass118=uvhpy118[1,:]
mass119=uvhpy119[1,:]
#mass99=uvhpy99[1,:]

'''
fd82=uvhpy82[2,:]
fd83=uvhpy83[2,:]
fd84=uvhpy84[2,:]
fd85=uvhpy85[2,:]
fd86=uvhpy86[2,:]
fd87=uvhpy87[2,:]
fd88=uvhpy88[2,:]
fd89=uvhpy89[2,:]
fd90=uvhpy90[2,:]
fd91=uvhpy91[2,:]
fd92=uvhpy92[2,:]
fd93=uvhpy93[2,:]
fd94=uvhpy94[2,:]
fd95=uvhpy95[2,:]
fd96=uvhpy96[2,:]
fd97=uvhpy97[2,:]
fd98=uvhpy98[2,:]
'''
fd30=uvhpy30[2,:]*0.0+1.0
fd31=uvhpy31[2,:]*0.0+1.0
fd32=uvhpy32[2,:]*0.0+1.0
fd33=uvhpy33[2,:]*0.0+1.0
fd34=uvhpy34[2,:]*0.0+1.0
fd35=uvhpy35[2,:]*0.0+1.0
fd36=uvhpy36[2,:]*0.0+1.0
fd37=uvhpy37[2,:]*0.0+1.0
fd38=uvhpy38[2,:]*0.0+1.0
fd39=uvhpy39[2,:]*0.0+1.0
fd40=uvhpy40[2,:]*0.0+1.0
fd41=uvhpy41[2,:]*0.0+1.0
fd42=uvhpy42[2,:]*0.0+1.0
fd43=uvhpy43[2,:]*0.0+1.0
fd44=uvhpy44[2,:]*0.0+1.0
fd45=uvhpy45[2,:]*0.0+1.0
fd46=uvhpy46[2,:]*0.0+1.0
fd47=uvhpy47[2,:]*0.0+1.0
fd48=uvhpy48[2,:]*0.0+1.0
fd49=uvhpy49[2,:]*0.0+1.0
fd50=uvhpy50[2,:]*0.0+1.0
fd51=uvhpy51[2,:]*0.0+1.0
fd52=uvhpy52[2,:]*0.0+1.0
fd53=uvhpy53[2,:]*0.0+1.0
fd54=uvhpy54[2,:]*0.0+1.0
fd55=uvhpy55[2,:]*0.0+1.0
fd56=uvhpy56[2,:]*0.0+1.0
fd57=uvhpy57[2,:]*0.0+1.0
fd58=uvhpy58[2,:]*0.0+1.0
fd59=uvhpy59[2,:]*0.0+1.0
fd60=uvhpy60[2,:]*0.0+1.0
fd61=uvhpy61[2,:]*0.0+1.0
fd62=uvhpy62[2,:]*0.0+1.0
fd63=uvhpy63[2,:]*0.0+1.0
fd64=uvhpy64[2,:]*0.0+1.0
fd65=uvhpy65[2,:]*0.0+1.0
fd66=uvhpy66[2,:]*0.0+1.0
fd67=uvhpy67[2,:]*0.0+1.0
fd68=uvhpy68[2,:]*0.0+1.0
fd69=uvhpy69[2,:]*0.0+1.0
fd70=uvhpy70[2,:]*0.0+1.0
fd71=uvhpy71[2,:]+1.0
fd72=uvhpy72[2,:]+1.0
fd73=uvhpy73[2,:]+1.0
fd74=uvhpy74[2,:]+1.0
fd75=uvhpy75[2,:]+1.0
fd76=uvhpy76[2,:]+1.0
fd77=uvhpy77[2,:]+1.0
fd78=uvhpy78[2,:]+1.0
fd79=uvhpy79[2,:]+1.0
fd80=uvhpy80[2,:]+1.0
fd81=uvhpy81[2,:]+1.0

fd82=uvhpy82[2,:]+1.0
fd83=uvhpy83[2,:]+1.0
fd84=uvhpy84[2,:]+1.0
fd85=uvhpy85[2,:]+1.0
fd86=uvhpy86[2,:]+1.0
fd87=uvhpy87[2,:]+1.0
fd88=uvhpy88[2,:]+1.0
fd89=uvhpy89[2,:]+1.0
fd90=uvhpy90[2,:]+1.0
fd91=uvhpy91[2,:]+1.0
fd92=uvhpy92[2,:]+1.0
fd93=uvhpy93[2,:]+1.0
fd94=uvhpy94[2,:]+1.0
fd95=uvhpy95[2,:]+1.0
fd96=uvhpy96[2,:]+1.0
fd97=uvhpy97[2,:]+1.0
fd98=uvhpy98[2,:]+1.0
fd99=uvhpy99[2,:]+1.0
fd100=uvhpy100[2,:]+1.0
fd101=uvhpy101[2,:]+1.0
fd102=uvhpy102[2,:]+1.0
fd103=uvhpy103[2,:]+1.0
fd104=uvhpy104[2,:]+1.0
fd105=uvhpy105[2,:]+1.0
fd106=uvhpy106[2,:]+1.0
fd107=uvhpy107[2,:]+1.0
fd108=uvhpy108[2,:]+1.0
fd109=uvhpy109[2,:]+1.0
fd110=uvhpy110[2,:]+1.0
fd111=uvhpy111[2,:]+1.0
fd112=uvhpy112[2,:]+1.0
fd113=uvhpy113[2,:]+1.0
fd114=uvhpy114[2,:]+1.0
fd115=uvhpy115[2,:]+1.0
fd116=uvhpy116[2,:]+1.0
fd117=uvhpy117[2,:]+1.0
fd118=uvhpy118[2,:]+1.0
fd119=uvhpy119[2,:]+1.0

plt.yscale('log')

ax.set_xlabel('Time [Myr]')
ax.set_ylabel('Clump Mass [M_sun]')
'''
plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.cool)
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.cool)
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.cool)
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.cool)
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.cool)
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.cool)
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.cool)
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.cool)
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.cool)
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.cool)
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.cool)
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.cool)
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.cool)
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.cool)
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.cool)
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.cool)
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.cool)
#plt.scatter(time99, mass99, s=5.9,c='red')
'''
'''
plt.scatter(time30, mass30, s=5.9,c=fd30, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time31, mass31, s=5.9,c=fd31, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time32, mass32, s=5.9,c=fd32, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time33, mass33, s=5.9,c=fd33, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time34, mass34, s=5.9,c=fd34, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time35, mass35, s=5.9,c=fd35, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time36, mass36, s=5.9,c=fd36, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time37, mass37, s=5.9,c=fd37, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time38, mass38, s=5.9,c=fd38, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time39, mass39, s=5.9,c=fd39, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time40, mass40, s=5.9,c=fd40, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time41, mass41, s=5.9,c=fd41, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time42, mass42, s=5.9,c=fd42, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time43, mass43, s=5.9,c=fd43, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time44, mass44, s=5.9,c=fd44, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time45, mass45, s=5.9,c=fd45, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time46, mass46, s=5.9,c=fd46, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time47, mass47, s=5.9,c=fd47, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time48, mass48, s=5.9,c=fd48, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time49, mass49, s=5.9,c=fd49, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time50, mass50, s=5.9,c=fd50, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time51, mass51, s=5.9,c=fd51, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time52, mass52, s=5.9,c=fd52, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time53, mass53, s=5.9,c=fd53, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time54, mass54, s=5.9,c=fd54, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time55, mass55, s=5.9,c=fd55, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time56, mass56, s=5.9,c=fd56, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time57, mass57, s=5.9,c=fd57, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time58, mass58, s=5.9,c=fd58, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time59, mass59, s=5.9,c=fd59, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time60, mass60, s=5.9,c=fd60, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time61, mass61, s=5.9,c=fd61, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time62, mass62, s=5.9,c=fd62, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time63, mass63, s=5.9,c=fd63, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time64, mass64, s=5.9,c=fd64, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time65, mass65, s=5.9,c=fd65, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time66, mass66, s=5.9,c=fd66, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time67, mass67, s=5.9,c=fd67, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time68, mass68, s=5.9,c=fd68, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time69, mass69, s=5.9,c=fd69, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time70, mass70, s=5.9,c=fd70, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time71, mass71, s=5.9,c=fd71, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time72, mass72, s=5.9,c=fd72, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time73, mass73, s=5.9,c=fd73, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time74, mass74, s=5.9,c=fd74, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time75, mass75, s=5.9,c=fd75, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time76, mass76, s=5.9,c=fd76, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time77, mass77, s=5.9,c=fd77, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time78, mass78, s=5.9,c=fd78, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time79, mass79, s=5.9,c=fd79, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time80, mass80, s=5.9,c=fd80, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time81, mass81, s=5.9,c=fd81, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())

plt.scatter(time82, mass82, s=5.9,c=fd82, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time83, mass83, s=5.9,c=fd83, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time84, mass84, s=5.9,c=fd84, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time85, mass85, s=5.9,c=fd85, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time86, mass86, s=5.9,c=fd86, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=fd87, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time88, mass88, s=5.9,c=fd88, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=fd89, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time90, mass90, s=5.9,c=fd90, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=fd91, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time92, mass92, s=5.9,c=fd92, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=fd93, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time94, mass94, s=5.9,c=fd94, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=fd95, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time96, mass96, s=5.9,c=fd96, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=fd97, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time98, mass98, s=5.9,c=fd98, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=fd99, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time100, mass100, s=5.9,c=fd100, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time101, mass101, s=5.9,c=fd101, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time102, mass102, s=5.9,c=fd102, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=fd103, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time104, mass104, s=5.9,c=fd104, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=fd105, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time106, mass106, s=5.9,c=fd106, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=fd107, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time108, mass108, s=5.9,c=fd108, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=fd109, cmap=cm.bwr, vmin=1.0, vmax=1000.0, norm=LogNorm())

plt.colorbar()

plt.xlim([10.0, 30.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
plt.clim(1, 1000) 
#plt.colorbar()

print(time)
'''

plt.hist(mass82, log=True)
# Out:
# (array([30.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  8.]),
#  array([     0.        ,  37860.61872698,  75721.23745397, 113581.85618095,
#         151442.47490794, 189303.09363492, 227163.7123619 , 265024.33108889,
#         302884.94981587, 340745.56854286, 378606.18726984]),
#  <a list of 10 Patch objects>)

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'

im = 4

jm82 = 38
jm83 = 37
jm84= 39
jm85= 42
jm86= 32
jm87= 35
jm88= 33
jm89= 31
jm90= 31
jm91= 21
jm92= 29
jm93= 27
jm94= 27
jm95= 28
jm96= 25
jm97= 25
jm98= 30
jm99= 31
jm100= 30
jm101= 29
jm102= 32
jm103= 34
jm104= 27
jm105= 27
jm106= 25
jm107= 21
jm108= 21
jm109= 24

f82 = open(dir+'Masstime082001.DAT')
f83 = open(dir+'Masstime083001.DAT')
f84 = open(dir+'Masstime084001.DAT')
f85 = open(dir+'Masstime085001.DAT')
f86 = open(dir+'Masstime086001.DAT')
f87 = open(dir+'Masstime087001.DAT')
f88 = open(dir+'Masstime088001.DAT')
f89 = open(dir+'Masstime089001.DAT')
f90 = open(dir+'Masstime090001.DAT')
f91 = open(dir+'Masstime091001.DAT')
f92 = open(dir+'Masstime092001.DAT')
f93 = open(dir+'Masstime093001.DAT')
f94 = open(dir+'Masstime094001.DAT')
f95 = open(dir+'Masstime095001.DAT')
f96 = open(dir+'Masstime096001.DAT')
f97 = open(dir+'Masstime097001.DAT')
f98 = open(dir+'Masstime098001.DAT')
f99 = open(dir+'Masstime099001.DAT')
f100 = open(dir+'Masstime100001.DAT')
f101 = open(dir+'Masstime101001.DAT')
f102 = open(dir+'Masstime102001.DAT')
f103 = open(dir+'Masstime103001.DAT')
f104 = open(dir+'Masstime104001.DAT')
f105 = open(dir+'Masstime105001.DAT')
f106 = open(dir+'Masstime106001.DAT')
f107 = open(dir+'Masstime107001.DAT')
f108 = open(dir+'Masstime108001.DAT')
f109 = open(dir+'Masstime109001.DAT')

ary82 = np.fromfile(f82, np.float64,count=im*jm82)
ary83 = np.fromfile(f83, np.float64,count=im*jm83)
ary84 = np.fromfile(f84, np.float64,count=im*jm84)
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary86 = np.fromfile(f86, np.float64,count=im*jm86)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary88 = np.fromfile(f88, np.float64,count=im*jm88)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary90 = np.fromfile(f90, np.float64,count=im*jm90)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary92 = np.fromfile(f92, np.float64,count=im*jm92)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary94 = np.fromfile(f94, np.float64,count=im*jm94)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary96 = np.fromfile(f96, np.float64,count=im*jm96)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary98 = np.fromfile(f98, np.float64,count=im*jm98)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary100 = np.fromfile(f100, np.float64,count=im*jm100)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary102 = np.fromfile(f102, np.float64,count=im*jm102)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary104 = np.fromfile(f104, np.float64,count=im*jm104)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary106 = np.fromfile(f106, np.float64,count=im*jm106)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary108 = np.fromfile(f108, np.float64,count=im*jm108)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)

uvhpy82 = ary82.reshape(im,jm82,order='F')
uvhpy83 = ary83.reshape(im,jm83,order='F')
uvhpy84 = ary84.reshape(im,jm84,order='F')
uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy86 = ary86.reshape(im,jm86,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy88 = ary88.reshape(im,jm88,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy90 = ary90.reshape(im,jm90,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy92 = ary92.reshape(im,jm92,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy94 = ary94.reshape(im,jm94,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy96 = ary96.reshape(im,jm96,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy98 = ary98.reshape(im,jm98,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy100 = ary100.reshape(im,jm100,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy102 = ary102.reshape(im,jm102,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy104 = ary104.reshape(im,jm104,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy106 = ary106.reshape(im,jm106,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy108 = ary108.reshape(im,jm108,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')

mass82=uvhpy82[1,:]
mass83=uvhpy83[1,:]
mass84=uvhpy84[1,:]
mass85=uvhpy85[1,:]
mass86=uvhpy86[1,:]
mass87=uvhpy87[1,:]
mass88=uvhpy88[1,:]
mass89=uvhpy89[1,:]
mass90=uvhpy90[1,:]
mass91=uvhpy91[1,:]
mass92=uvhpy92[1,:]
mass93=uvhpy93[1,:]
mass94=uvhpy94[1,:]
mass95=uvhpy95[1,:]
mass96=uvhpy96[1,:]
mass97=uvhpy97[1,:]
mass98=uvhpy98[1,:]
mass99=uvhpy99[1,:]
mass100=uvhpy100[1,:]
mass101=uvhpy101[1,:]
mass102=uvhpy102[1,:]
mass103=uvhpy103[1,:]
mass104=uvhpy104[1,:]
mass105=uvhpy105[1,:]
mass106=uvhpy106[1,:]
mass107=uvhpy107[1,:]
mass108=uvhpy108[1,:]
mass109=uvhpy109[1,:]


#plt.hist(mass83,  bins=np.logspace(2, 6, 4), range=(100.0, 1000000.0))
# plot
#r1=np.random.rand(100) * 1e3
#r2=np.random.rand(100) * 1e6
#df=np.r_[mass85,mass95,mass105]

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ


ax=plt.figure(figsize=(5,5)).add_subplot(111)
#ax.hist(x=df, bins=np.logspace(2, 6, 8), color='dodgerblue', alpha=0.75)
ax.hist(x=mass85, bins=np.logspace(2, 6, 8), color='red', alpha=0.5,edgecolor="black")
ax.hist(x=mass95, bins=np.logspace(2, 6, 8), color='blue', alpha=0.5,edgecolor="black")
ax.hist(x=mass105, bins=np.logspace(2, 6, 8), color='green', alpha=0.5,edgecolor="black")#, histtype="step")


ax.set_xscale('log')
ax.set_xlabel('mass')
ax.set_ylabel('num')
plt.savefig('plot_out.pdf')

plt.xlim([100.0, 1000000.0]) # y方向の描画範囲を指定
# Out:
# (100.0, 1000000.0)

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
from matplotlib.colors import LogNorm



im = 4+3
"""
jm = 33
jm1 = 40
jm2 = 38
jm3 = 44
"""
'''
jm82 = 38
jm83 = 31
jm84= 35
jm85= 28
jm86= 24
jm87= 41
jm88= 29
jm89= 20
jm90= 22
jm91= 21
jm92= 24
jm93= 24
jm94= 22
jm95= 21
jm96= 21
jm97= 26
jm98= 25
jm99= 20
'''

jm30= 0
jm31= 0
jm32= 0
jm33= 0
jm34= 0
jm35= 0
jm36= 0
jm37= 0
jm38= 0
jm39= 0
jm40= 0
jm41= 0
jm42= 0
jm43= 0
jm44= 0
jm45= 0
jm46= 1
jm47= 2
jm48= 3
jm49= 5
jm50= 4
jm51= 4
jm52= 4
jm53= 5
jm54= 5
jm55= 6
jm56= 7
jm57= 7
jm58= 9
jm59= 10
jm60= 10
jm61= 14
jm62= 16
jm63= 16
jm64= 19
jm65= 21
jm66= 19
jm67= 21
jm68= 25
jm69= 26
jm70= 28
jm71= 30
jm72= 33
jm73= 37
jm74= 39
jm75= 42
jm76= 38
jm77= 41
jm78= 38
jm79= 39
jm80= 38
jm81= 38

jm82 = 38
jm83 = 37
jm84= 39
jm85= 90
jm86= 32
jm87= 199
jm88= 33
jm89= 108
jm90= 31
jm91= 172
jm92= 29
jm93= 106
jm94= 27
jm95= 93
jm96= 25
jm97= 133
jm98= 30
jm99= 106
jm100= 30
jm101= 91
jm102= 32
jm103= 133
jm104= 27
jm105= 216
jm106= 25
jm107= 123
jm108= 21
jm109= 67

#km=19433
#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvS/th105n/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/sampletstC/feedef/'


fig = plt.figure()
ax = fig.add_subplot(111)

plt.xlim([10.0, 25.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定


f51 = open(dir+'Masstime-xg051001.DAT')
f53 = open(dir+'Masstime-xg053001.DAT')
f55 = open(dir+'Masstime-xg055001.DAT')
f57 = open(dir+'Masstime-xg057001.DAT')
f59 = open(dir+'Masstime-xg059001.DAT')
f61 = open(dir+'Masstime-xg061001.DAT')
f63 = open(dir+'Masstime-xg063001.DAT')
f65 = open(dir+'Masstime-xg065001.DAT')
f67 = open(dir+'Masstime-xg067001.DAT')
f69 = open(dir+'Masstime-xg069001.DAT')
f71 = open(dir+'Masstime-xg071001.DAT')
f73 = open(dir+'Masstime-xg073001.DAT')
f75 = open(dir+'Masstime-xg075001.DAT')
f77 = open(dir+'Masstime-xg077001.DAT')
f79 = open(dir+'Masstime-xg079001.DAT')


f85 = open(dir+'Mass-nxg085001.DAT')
f87 = open(dir+'Mass-nxg087001.DAT')
f89 = open(dir+'Mass-nxg089001.DAT')
f91 = open(dir+'Mass-nxg091001.DAT')
f93 = open(dir+'Mass-nxg093001.DAT')
f95 = open(dir+'Mass-nxg095001.DAT')
f97 = open(dir+'Mass-nxg097001.DAT')
f99 = open(dir+'Mass-nxg099001.DAT')
f101 = open(dir+'Mass-nxg101001.DAT')
f103 = open(dir+'Mass-nxg103001.DAT')
f105 = open(dir+'Mass-nxg105001.DAT')
f107 = open(dir+'Mass-nxg107001.DAT')
f109 = open(dir+'Mass-nxg109001.DAT')



ary51 = np.fromfile(f51, np.float64,count=im*jm51)
ary53 = np.fromfile(f53, np.float64,count=im*jm53)
ary55 = np.fromfile(f55, np.float64,count=im*jm55)
ary57 = np.fromfile(f57, np.float64,count=im*jm57)
ary59 = np.fromfile(f59, np.float64,count=im*jm59)
ary61 = np.fromfile(f61, np.float64,count=im*jm61)
ary63 = np.fromfile(f63, np.float64,count=im*jm63)
ary65 = np.fromfile(f65, np.float64,count=im*jm65)
ary67 = np.fromfile(f67, np.float64,count=im*jm67)
ary69 = np.fromfile(f69, np.float64,count=im*jm69)
ary71 = np.fromfile(f71, np.float64,count=im*jm71)
ary73 = np.fromfile(f73, np.float64,count=im*jm73)
ary75 = np.fromfile(f75, np.float64,count=im*jm75)
ary77 = np.fromfile(f77, np.float64,count=im*jm77)
ary79 = np.fromfile(f79, np.float64,count=im*jm79)

#f99 = open(dir+'Masstime099001.DAT')
ary85 = np.fromfile(f85, np.float64,count=im*jm85)
ary87 = np.fromfile(f87, np.float64,count=im*jm87)
ary89 = np.fromfile(f89, np.float64,count=im*jm89)
ary91 = np.fromfile(f91, np.float64,count=im*jm91)
ary93 = np.fromfile(f93, np.float64,count=im*jm93)
ary95 = np.fromfile(f95, np.float64,count=im*jm95)
ary97 = np.fromfile(f97, np.float64,count=im*jm97)
ary99 = np.fromfile(f99, np.float64,count=im*jm99)
ary101 = np.fromfile(f101, np.float64,count=im*jm101)
ary103 = np.fromfile(f103, np.float64,count=im*jm103)
ary105 = np.fromfile(f105, np.float64,count=im*jm105)
ary107 = np.fromfile(f107, np.float64,count=im*jm107)
ary109 = np.fromfile(f109, np.float64,count=im*jm109)

#ary99 = np.fromfile(f99, np.float64,count=im*jm99)
#ary91 = np.fromfile(f91, np.float64,count=im*km)

uvhpy51= ary51.reshape(im,jm51,order='F')
uvhpy53 = ary53.reshape(im,jm53,order='F')
uvhpy55 = ary55.reshape(im,jm55,order='F')
uvhpy57 = ary57.reshape(im,jm57,order='F')
uvhpy59 = ary59.reshape(im,jm59,order='F')
uvhpy61= ary61.reshape(im,jm61,order='F')
uvhpy63 = ary63.reshape(im,jm63,order='F')
uvhpy65 = ary65.reshape(im,jm65,order='F')
uvhpy67 = ary67.reshape(im,jm67,order='F')
uvhpy69 = ary69.reshape(im,jm69,order='F')
uvhpy71= ary71.reshape(im,jm71,order='F')
uvhpy73 = ary73.reshape(im,jm73,order='F')
uvhpy75 = ary75.reshape(im,jm75,order='F')
uvhpy77 = ary77.reshape(im,jm77,order='F')
uvhpy79 = ary79.reshape(im,jm79,order='F')

uvhpy85 = ary85.reshape(im,jm85,order='F')
uvhpy87 = ary87.reshape(im,jm87,order='F')
uvhpy89 = ary89.reshape(im,jm89,order='F')
uvhpy91= ary91.reshape(im,jm91,order='F')
uvhpy93 = ary93.reshape(im,jm93,order='F')
uvhpy95 = ary95.reshape(im,jm95,order='F')
uvhpy97 = ary97.reshape(im,jm97,order='F')
uvhpy99 = ary99.reshape(im,jm99,order='F')
uvhpy101= ary101.reshape(im,jm101,order='F')
uvhpy103 = ary103.reshape(im,jm103,order='F')
uvhpy105 = ary105.reshape(im,jm105,order='F')
uvhpy107 = ary107.reshape(im,jm107,order='F')
uvhpy109 = ary109.reshape(im,jm109,order='F')



time51 =uvhpy51[4,:]
time53 =uvhpy53[4,:]
time55 =uvhpy55[4,:]
time57 =uvhpy57[4,:]
time59 =uvhpy59[4,:]
time61 =uvhpy61[4,:]
time63 =uvhpy63[4,:]
time65 =uvhpy65[4,:]
time67 =uvhpy67[4,:]
time69 =uvhpy69[4,:]
time71 =uvhpy71[4,:]
time73 =uvhpy73[4,:]
time75 =uvhpy75[4,:]
time77 =uvhpy77[4,:]
time79 =uvhpy79[4,:]

time85 =uvhpy85[6,:]-1.0
time87 =uvhpy87[6,:]-1.0
time89 =uvhpy89[6,:]-1.0
time91 =uvhpy91[6,:]-1.0
time93 =uvhpy93[6,:]-1.0
time95 =uvhpy95[6,:]-1.0
time97 =uvhpy97[6,:]-1.0
time99 =uvhpy99[6,:]-1.0
time101 =uvhpy101[6,:]-1.0
time103 =uvhpy103[6,:]-1.0
time105 =uvhpy105[6,:]-1.0
time107 =uvhpy107[6,:]-1.0
time109 =uvhpy109[6,:]-1.0




mass51=uvhpy51[1,:]
mass53=uvhpy53[1,:]
mass55=uvhpy55[1,:]
mass57=uvhpy57[1,:]
mass59=uvhpy59[1,:]
mass61=uvhpy61[1,:]
mass63=uvhpy63[1,:]
mass65=uvhpy65[1,:]
mass67=uvhpy67[1,:]
mass69=uvhpy69[1,:]
mass71=uvhpy71[1,:]
mass73=uvhpy73[1,:]
mass75=uvhpy75[1,:]
mass77=uvhpy77[1,:]
mass79=uvhpy79[1,:]

mass85=uvhpy85[1,:]
mass87=uvhpy87[1,:]
mass89=uvhpy89[1,:]
mass91=uvhpy91[1,:]
mass93=uvhpy93[1,:]
mass95=uvhpy95[1,:]
mass97=uvhpy97[1,:]
mass99=uvhpy99[1,:]
mass101=uvhpy101[1,:]
mass103=uvhpy103[1,:]
mass105=uvhpy105[1,:]
mass107=uvhpy107[1,:]
mass109=uvhpy109[1,:]

vfd51=uvhpy51[0,:]
vfd53=uvhpy53[0,:]
vfd55=uvhpy55[0,:]
vfd57=uvhpy57[0,:]
vfd59=uvhpy59[0,:]
vfd61=uvhpy61[0,:]
vfd63=uvhpy63[0,:]
vfd65=uvhpy65[0,:]
vfd67=uvhpy67[0,:]
vfd69=uvhpy69[0,:]
vfd71=uvhpy71[0,:]
vfd73=uvhpy73[0,:]
vfd75=uvhpy75[0,:]
vfd77=uvhpy77[0,:]
vfd79=uvhpy79[0,:]

vfd85=uvhpy85[0,:]
vfd87=uvhpy87[0,:]
vfd89=uvhpy89[0,:]
vfd91=uvhpy91[0,:]
vfd93=uvhpy93[0,:]
vfd95=uvhpy95[0,:]
vfd97=uvhpy97[0,:]
vfd99=uvhpy99[0,:]
vfd101=uvhpy101[0,:]
vfd103=uvhpy103[0,:]
vfd105=uvhpy105[0,:]
vfd107=uvhpy107[0,:]
vfd109=uvhpy109[0,:]




plt.yscale('log')

plt.scatter(time51, mass51, s=5.9,c=vfd51, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time53, mass53, s=5.9,c=vfd53, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time55, mass55, s=5.9,c=vfd55, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time57, mass57, s=5.9,c=vfd57, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time59, mass59, s=5.9,c=vfd59, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time61, mass61, s=5.9,c=vfd61, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time63, mass63, s=5.9,c=vfd63, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time65, mass65, s=5.9,c=vfd65, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time67, mass67, s=5.9,c=vfd67, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time69, mass69, s=5.9,c=vfd69, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time71, mass71, s=5.9,c=vfd71, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time73, mass73, s=5.9,c=vfd73, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time75, mass75, s=5.9,c=vfd75, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time77, mass77, s=5.9,c=vfd77, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time79, mass79, s=5.9,c=vfd79, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())

plt.scatter(time85, mass85, s=5.9,c=vfd85, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time87, mass87, s=5.9,c=vfd87, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time89, mass89, s=5.9,c=vfd89, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time91, mass91, s=5.9,c=vfd91, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time93, mass93, s=5.9,c=vfd93, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time95, mass95, s=5.9,c=vfd95, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time97, mass97, s=5.9,c=vfd97, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time99, mass99, s=5.9,c=vfd99, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())

plt.scatter(time101, mass101, s=5.9,c=vfd101, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time103, mass103, s=5.9,c=vfd103, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time105, mass105, s=5.9,c=vfd105, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time107, mass107, s=5.9,c=vfd107, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())
plt.scatter(time109, mass109, s=5.9,c=vfd109, cmap=cm.cool, vmin=20.0, vmax=30.0)#, norm=LogNorm())

#pp.set_clim(0.1,10)
plt.clim(20, 30) 
plt.colorbar()



print(time79)

plt.xlim([0.0, 100.0]) # x方向の描画範囲を指定
plt.ylim([100.0, 1000000.0]) # y方向の描画範囲を指定
# Out:
# [3.77886998e+05 2.17185556e+00 0.00000000e+00 3.48432460e+02
#  1.97500000e+01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.77886998e+05 6.56635822e-01 0.00000000e+00 1.33271910e+02
#  1.97500000e+01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.77886998e+05 4.70730911e-01 0.00000000e+00 2.84425291e+02
#  1.97500000e+01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.77886998e+05 5.30159691e-01 0.00000000e+00 2.92724049e+02
#  1.97500000e+01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.77886998e+05 6.20078536e-01 0.00000000e+00 2.99957196e+03
#  1.97500000e+01 0.00000000e+00 0.00000000e+00]
# (100.0, 1000000.0)
