# %%
# coding: UTF-8
import numpy as np
import h5py
import csv
from scipy import special


#im = 64
#jm = 64
#km = 64
im = 128
jm = 128
km = 128
#im = 512
#jm = 512
#km = 512
#num = 1
#num = 3
#num = 7
#num = 17
num = 18
nstep = 20
#itime = 1
#ftime = 104
itime = 98
ftime =98
timejump=1
dx1=100.0/512.0
Ms=0.024

cx=50.0
cy=50.0
cz=50.0

cim = cx.astype(np.int32)
cjm = cy.astype(np.int32)
ckm = cz.astype(np.int32)


#dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvD/'
dir = '/Users/maeda/Desktop/Dropbox/analysis/samplecnvA/Phi/Maeda2021/'
f90 = open(dir+'AllHDF'+"%03.f"%(j)+'.DAT', 'rb')
ary = np.fromfile(f90, np.float32,count=im*jm*km*num) #count=im*jm*dim*nstep
uvhpy = ary.reshape(num,im,jm,km, order='F')

slice1=uvhpy[0,:,:,:]
slice2=uvhpy[1,:,:,:]
slice3=uvhpy[2,:,:,:]
slice4=uvhpy[3,:,:,:]
slice5=uvhpy[4,:,:,:]
slice6=uvhpy[5,:,:,:]
slice7=uvhpy[6,:,:,:]
slice8=uvhpy[7,:,:,:]
slice9=uvhpy[8,:,:,:]
slice10=uvhpy[9,:,:,:]
slice11=uvhpy[10,:,:,:]
slice12=uvhpy[11,:,:,:]
slice13=uvhpy[12,:,:,:]
slice14=uvhpy[13,:,:,:]
slice15=uvhpy[14,:,:,:]
slice16=uvhpy[15,:,:,:]
slice17=uvhpy[16,:,:,:]
slice18=uvhpy[17,:,:,:]

for ii in range(0+1, im-1 ):
    for jj in range(0+1, jm-1 ):
        for kk in range(0+1, km-1 ):
            rp[ii,jj,kk]=np.sqrt((ii*dx1-cim*dx1)**2.0+(jj*dx1-cjm*dx1)**2.0+(kk*dx1-ckm*dx1)**2.0)
# Out:
# fin

# %%
Phi0=uvhpy[17,256,256,1]
Phi=Phi0-slice17

#enG=Phi*slice1
vesc=np.sqrt(2.0*Phi)



fig = plt.figure()
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ



plt.scatter(R, vesc, s=0.1,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)
plt.scatter(R91, vesc91, s=0.1,c='blue')
plt.xlim([0.0, 60.0]) # x方向の描画範囲を指定
plt.ylim([0.0, 25.0]) # y方向の描画範囲を指定
#plt.xticks(0.0, 50.0, 6)
#plt.yticks(0, 20, 4)
#ax.set_title('Scatter plot')
ax.set_xlabel('Radius [pc]')
ax.set_ylabel('Escape velocity [km s$^{-1}$]')
#ax.plot(t, y1, color=c1, label=l1)
#ax.plot(t, y2, color=c2, label=l2)
#ax.plot(t, y3, color=c3, label=l3)
#ax.plot(t, y4, color=c4, label=l4)
#ax.legend(loc=0)    # 凡例
#fig.tight_layout()  # レイアウトの設定
# plt.savefig('hoge.png') # 画像の保存
#plt.show()
plt.xticks(np.arange(0, 60 + 1, 10))
plt.yticks(np.arange(0, 20 + 1, 5))
p = plt.plot([0.0, 60.0],[10.0, 10.0], "black", linestyle='dashed') # normal way
p = plt.plot([0.0, 60.0],[7.6, 7.6], "red", linestyle='dashed') # normal way
p = plt.plot([0.0, 60.0],[12.7, 12.7], "blue", linestyle='dashed') # normal way

# 保存するPDFファイル名
pp = PdfPages(dir+'esc.pdf')
# 画像をPDFとして保存する
pp.savefig(fig)
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
                    
#plt.savefig("R-Vesc.png")
