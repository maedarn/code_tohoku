# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages


im = 2
jm = 4125
km=19433
dir = '/Users/maeda/Desktop/'

k20err=[0] * 3
#k20err=[0] * 4
'''
k10err=[0] * 3
k50err=[0] * 3
k5err=[0] * 3
k100err=[0] * 3
'''
msh=[0] * 3
#msh=[0] * 4


#k20err[0]=5.938533227890729904e-03
#k20err[1]=1.898119342513382435e-03
#20err[2]=1.082548638805747032e-03

#k20err[0]=1.467350986786186695e-03
#k20err[1]=6.860630819573998451e-04

#k20err[0]=1.378911663778126240e-03 
#k20err[1]=6.592101417481899261e-04
#k20err[2]=3.174670855514705181e-04

#k20err[0]=1.312663429416716099e-03
#k20err[1]=6.274526822380721569e-04
#k20err[2]=3.260703233536332846e-04

#k20err[0]=1.405453891493380070e-03
#k20err[1]=6.713665788993239403e-04

#k20err[2]=2.804053656291216612e-04
#k20err[3]=1.238898548763245344e-04

#k20err[0]=1.702184206806123257e-03
#k20err[1]=7.749282522127032280e-04
#k20err[2]=2.593076787889003754e-04

#k20err[0]=1.571042230352759361e-03
#k20err[1]=6.481706514023244381e-04
#k20err[2]=9.087398939300328493e-05

k20err[0]=0.000984432346417993     #0.0009844323464179932
k20err[1]=0.00013883229113963324 #0.00013883229113963326 0.00013883229113963324 #0.00013883229113963326 0.00013883229113963337# 0.00013883229113963343
k20err[2]=2.0339681962451414e-05 #2.0339681962451407e-05 2.0339681962451414e-05 #2.0339681962451407e-05 2.033968196245101e-05   #2.033968196245099e-05


'''
k10err[0]=6.020462606102228165e-03
k10err[1]=1.929431571625173092e-03
k10err[2]=1.052323146723210812e-03

k50err[0]=5.925341509282588959e-03
k50err[1]=2.048999303951859474e-03
k50err[2]=1.175862271338701248e-03

k5err[0]=6.303857080638408661e-03
k5err[1]=2.103387843817472458e-03
k5err[2]=1.093271654099225998e-03

k100err[0]=5.965770222246646881e-03
k100err[1]=2.161503769457340240e-03
k100err[2]=1.237088697962462902e-03
'''

msh[0]=64.0
msh[1]=128.0
msh[2]=256.0
#msh[3]=512.0



fig = plt.figure()
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ


#plt.yscale('log')
#plt.xscale('log')

lgk20err=np.log10(k20err)
#lgk20err=np.e ** (lgk20err)
lgmsh=np.log10(msh)

'''
lgk100err=np.log10(k100err)
lgk10err=np.log10(k10err)
lgk50err=np.log10(k50err)
lgk5err=np.log10(k5err)
#lgk20err=np.e ** (lgk20err)
'''

plt.scatter(lgmsh, lgk20err, s=3.0,c='red')
#plt.scatter(lgmsh, lgk5err, s=3.0,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)
'''
plt.scatter(lgmsh, lgk10err, s=3.0,c='blue')
plt.scatter(lgmsh, lgk20err, s=3.0,c='black')
plt.scatter(lgmsh, lgk50err, s=3.0,c='green')
plt.scatter(lgmsh, lgk100err, s=3.0,c='green')
'''
#plt.scatter(msh, k5err, s=3.0,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)
#plt.scatter(msh, k10err, s=3.0,c='blue')
#plt.scatter(msh, k20err, s=3.0,c='black')
#plt.scatter(msh, k50err, s=3.0,c='green')
#plt.scatter(msh, k100err, s=3.0,c='green')

#lgk20err=np.log(k20err)
#lgk20err=np.e ** (lgk20err)
#lgmsh=np.log(msh)
#lgmsh=np.e ** (lgmsh)

lgmsh[0]

coef_20 = np.polyfit(lgmsh,lgk20err,1) #係数
y_pred_20 = coef_20[0]*lgmsh+ coef_20[1] #フィッティング関数

'''
coef_10 = np.polyfit(lgmsh,lgk10err,1) #係数
y_pred_10 = coef_10[0]*lgmsh+ coef_10[1] #フィッティング関数

coef_50 = np.polyfit(lgmsh,lgk50err,1) #係数
y_pred_50 = coef_50[0]*lgmsh+ coef_50[1] #フィッティング関数

coef_100 = np.polyfit(lgmsh,lgk100err,1) #係数
y_pred_100 = coef_100[0]*lgmsh+ coef_100[1] #フィッティング関数

coef_5 = np.polyfit(lgmsh,lgk5err,1) #係数
y_pred_5 = coef_5[0]*lgmsh+ coef_5[1] #フィッティング関数
'''


plt.plot(lgmsh,y_pred_20,label="d=1",c='red') #1次式
print(y_pred_20)
'''
plt.plot(lgmsh,y_pred_10,label="d=1") #1次式
plt.plot(lgmsh,y_pred_50,label="d=1") #1次式
plt.plot(lgmsh,y_pred_100,label="d=1") #1次式
plt.plot(lgmsh,y_pred_5,label="d=1") #1次式
'''

#plt.scatter(R91, vesc91, s=0.1,c='blue')
#plt.xlim([0.0, 60.0]) # x方向の描画範囲を指定
#plt.ylim([0.0001, 0.01]) # y方向の描画範囲を指定
#plt.xticks(0.0, 50.0, 6)
#plt.yticks(0, 20, 4)
#ax.set_title('Scatter plot')
ax.set_xlabel('Cell')
ax.set_ylabel('err')
#ax.plot(t, y1, color=c1, label=l1)
#ax.plot(t, y2, color=c2, label=l2)
#ax.plot(t, y3, color=c3, label=l3)
#ax.plot(t, y4, color=c4, label=l4)
#ax.legend(loc=0)    # 凡例
#fig.tight_layout()  # レイアウトの設定
# plt.savefig('hoge.png') # 画像の保存
#plt.show()
#plt.xticks(np.arange(0, 60 + 1, 10))
#plt.yticks(np.arange(0, 20 + 1, 5))
#p = plt.plot([0.0, 60.0],[10.0, 10.0], "black", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[7.6, 7.6], "red", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[12.7, 12.7], "blue", linestyle='dashed') # normal way

#x = np.arange(60, 1000, 0.1)
x = np.arange(60, 300, 0.1)
x=np.log10(x)
y = -(x) * 3.0 + 3.65726
plt.plot(x, y ,c='blue')


# 保存するPDFファイル名
pp = PdfPages('/Users/maedarn/Desktop/phierr.pdf')
# 画像をPDFとして保存する
pp.savefig(fig, bbox_inches='tight')
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
                    
#plt.savefig("R-Vesc.png")
lgk20err

coef_20
# Out:
# [-3.0095723  -3.85199316 -4.69441402]
# array([-2.79846152,  2.04495285])

# %%
# coding: UTF-8
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
from matplotlib.backends.backend_pdf import PdfPages


im = 2
jm = 4125
km=19433
dir = '/Users/maeda/Desktop/'

k20err=[0] * 3
#k20err=[0] * 4
'''
k10err=[0] * 3
k50err=[0] * 3
k5err=[0] * 3
k100err=[0] * 3
'''
msh=[0] * 3
#msh=[0] * 4



k20err[2]=0.000614432346417993     
k20err[1]=0.0005279482853208555
k20err[0]=0.0004933901332006569

'''
k10err[0]=6.020462606102228165e-03
k10err[1]=1.929431571625173092e-03
k10err[2]=1.052323146723210812e-03

k50err[0]=5.925341509282588959e-03
k50err[1]=2.048999303951859474e-03
k50err[2]=1.175862271338701248e-03

k5err[0]=6.303857080638408661e-03
k5err[1]=2.103387843817472458e-03
k5err[2]=1.093271654099225998e-03

k100err[0]=5.965770222246646881e-03
k100err[1]=2.161503769457340240e-03
k100err[2]=1.237088697962462902e-03
'''

msh[2]=1
msh[1]=2
msh[0]=4
#msh[3]=512.0



fig = plt.figure()
ax = fig.add_subplot(111)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
#plt.rcParams["xtick.minor.visible"] = True          #x軸補助目盛りの追加
#plt.rcParams["ytick.minor.visible"] = True          #y軸補助目盛りの追加
#plt.rcParams["xtick.major.width"] = 1.5              #x軸主目盛り線の線幅
#plt.rcParams["ytick.major.width"] = 1.5              #y軸主目盛り線の線幅
#plt.rcParams["xtick.minor.width"] = 1.0              #x軸補助目盛り線の線幅
#plt.rcParams["ytick.minor.width"] = 1.0              #y軸補助目盛り線の線幅
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
#plt.rcParams["xtick.minor.size"] = 5                #x軸補助目盛り線の長さ
#plt.rcParams["ytick.minor.size"] = 5                #y軸補助目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ
#plt.rcParams["axes.linewidth"] = 1.5                 #囲みの太さ


#plt.yscale('log')
#plt.xscale('log')

lgk20err=np.log10(k20err)
#lgk20err=np.e ** (lgk20err)
lgmsh=np.log10(msh)

'''
lgk100err=np.log10(k100err)
lgk10err=np.log10(k10err)
lgk50err=np.log10(k50err)
lgk5err=np.log10(k5err)
#lgk20err=np.e ** (lgk20err)
'''

plt.scatter(lgmsh, lgk20err, s=3.0,c='red')
#plt.scatter(lgmsh, lgk5err, s=3.0,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)
'''
plt.scatter(lgmsh, lgk10err, s=3.0,c='blue')
plt.scatter(lgmsh, lgk20err, s=3.0,c='black')
plt.scatter(lgmsh, lgk50err, s=3.0,c='green')
plt.scatter(lgmsh, lgk100err, s=3.0,c='green')
'''
#plt.scatter(msh, k5err, s=3.0,c='red')# norm=LogNorm())#, s=20)#, c=None, marker='o', cmap=None, norm=None,vmin=None, vmax=None, alpha=None, linewidths=None,verts=None, edgecolors=None, hold=None, data=None,**kwargs)
#plt.scatter(msh, k10err, s=3.0,c='blue')
#plt.scatter(msh, k20err, s=3.0,c='black')
#plt.scatter(msh, k50err, s=3.0,c='green')
#plt.scatter(msh, k100err, s=3.0,c='green')

#lgk20err=np.log(k20err)
#lgk20err=np.e ** (lgk20err)
#lgmsh=np.log(msh)
#lgmsh=np.e ** (lgmsh)

lgmsh[0]

coef_20 = np.polyfit(lgmsh,lgk20err,1) #係数
y_pred_20 = coef_20[0]*lgmsh+ coef_20[1] #フィッティング関数

'''
coef_10 = np.polyfit(lgmsh,lgk10err,1) #係数
y_pred_10 = coef_10[0]*lgmsh+ coef_10[1] #フィッティング関数

coef_50 = np.polyfit(lgmsh,lgk50err,1) #係数
y_pred_50 = coef_50[0]*lgmsh+ coef_50[1] #フィッティング関数

coef_100 = np.polyfit(lgmsh,lgk100err,1) #係数
y_pred_100 = coef_100[0]*lgmsh+ coef_100[1] #フィッティング関数

coef_5 = np.polyfit(lgmsh,lgk5err,1) #係数
y_pred_5 = coef_5[0]*lgmsh+ coef_5[1] #フィッティング関数
'''


plt.plot(lgmsh,y_pred_20,label="d=1",c='red') #1次式
print(y_pred_20)
'''
plt.plot(lgmsh,y_pred_10,label="d=1") #1次式
plt.plot(lgmsh,y_pred_50,label="d=1") #1次式
plt.plot(lgmsh,y_pred_100,label="d=1") #1次式
plt.plot(lgmsh,y_pred_5,label="d=1") #1次式
'''

#plt.scatter(R91, vesc91, s=0.1,c='blue')
#plt.xlim([0.0, 60.0]) # x方向の描画範囲を指定
#plt.ylim([0.0001, 0.01]) # y方向の描画範囲を指定
#plt.xticks(0.0, 50.0, 6)
#plt.yticks(0, 20, 4)
#ax.set_title('Scatter plot')
ax.set_xlabel('Cell')
ax.set_ylabel('err')
#ax.plot(t, y1, color=c1, label=l1)
#ax.plot(t, y2, color=c2, label=l2)
#ax.plot(t, y3, color=c3, label=l3)
#ax.plot(t, y4, color=c4, label=l4)
#ax.legend(loc=0)    # 凡例
#fig.tight_layout()  # レイアウトの設定
# plt.savefig('hoge.png') # 画像の保存
#plt.show()
#plt.xticks(np.arange(0, 60 + 1, 10))
#plt.yticks(np.arange(0, 20 + 1, 5))
#p = plt.plot([0.0, 60.0],[10.0, 10.0], "black", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[7.6, 7.6], "red", linestyle='dashed') # normal way
#p = plt.plot([0.0, 60.0],[12.7, 12.7], "blue", linestyle='dashed') # normal way

#x = np.arange(60, 1000, 0.1)
x = np.arange(60, 300, 0.1)
x=np.log10(x)
y = -(x) * 3.0 + 3.65726
plt.plot(x, y ,c='blue')


# 保存するPDFファイル名
pp = PdfPages('/Users/maedarn/Desktop/phierr.pdf')
# 画像をPDFとして保存する
pp.savefig(fig, bbox_inches='tight')
# PDFの保存終了
pp.close()
#plt.savefig("R-Vesc.png")
                    
#plt.savefig("R-Vesc.png")
lgk20err

coef_20
# Out:
# [-3.31288983 -3.26524803 -3.21760622]
# array([-0.15826265, -3.21760622])

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import h5py
import csv
import math
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.animation as animation
from matplotlib.animation import ArtistAnimation

i = 20
nmesh=128.0
n_nxt=1
#dir1  = '/Users/maedarn/Dropbox/analysis/cluster formation by HI cloud collision/multipole/test-dist/d0100/'
#dir1  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/wv-propagation/pfm064x/'
dir1  = '/Users/maedarn/Dropbox/analysis/gravity_solver/telegraph/test-tel/wv-propagation/pfmdmesh0128wv-sc/'
    
folder1="Phiwv"  #+ str(np.int(sample_frequency)) 
folder2="Phiexa"  #+ str(np.int(sample_frequency)) 

#h5file1 = h5py.File(dir1+'NNNAllHDF'+"%03.f"%(i)+'.h5',"r")
with h5py.File(dir1+'QAllHDF'+"%03.f"%(i)+'.h5',"r") as f:


#データ読み込み
#Phiwv1to1  = h5file1[folder1+"/Phiwv1"].value 
#Phiexa1 = h5file1[folder2+"/Rho"].value 

    Phiwv1to1= f[folder1+"/Phiwv1"]
    Phiexa1 = f[folder2+"/Phiexa"]

    data01_3D= Phiwv1to1[()]
    data02_3D=Phiexa1[()]

    data01=Phiwv1to1[:,:,1]
    data02=Phiexa1[:,:,1]
    
    data01_1D=Phiwv1to1[:,1,1]
    data02_1D=Phiexa1[:,1,1]/16.0
    
    
with h5py.File(dir1+'QAllHDF'+"%03.f"%(i+n_nxt)+'.h5',"r") as f1:
    
    Phiwv1to1n= f1[folder1+"/Phiwv1"]
    Phiexa1n = f1[folder2+"/Phiexa"]

    data01n_3D= Phiwv1to1n[()]
    data02n_3D=Phiexa1n[()]

    data01n=Phiwv1to1n[:,:,1]
    data02n=Phiexa1n[:,:,1]
    
    data01n_1D=Phiwv1to1n[:,1,1]
    data02n_1D=Phiexa1n[:,1,1]

m1=np.max(data01)
m2=np.max(data02)

data=data01-data02
data=data-m1+m2

datan=data01-data01n

data01_sq=(data01_3D-data01n_3D)*(data01_3D-data01n_3D)
data02_sq=(data02_3D-data02n_3D)*(data02_3D-data02n_3D)
data_sq=(data01-data02)*(data01-data02)

data01_rms=np.sqrt(np.sum(data01_sq))/nmesh/nmesh/nmesh
data02_rms=np.sqrt(np.sum(data02_sq))/nmesh/nmesh/nmesh
data_rms=np.sqrt(np.sum(data_sq))/nmesh/nmesh/nmesh

print(data01_rms,data02_rms,data_rms)

fig = plt.figure()
ax = fig.add_subplot(111)
#fig.subplots_adjust(bottom=0, left=0, top=1, right=1)

plt.rcParams["font.family"] = "Times New Roman"      #全体のフォントを設定
plt.rcParams["xtick.direction"] = "in"               #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"               #y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["xtick.major.size"] = 5                #x軸主目盛り線の長さ
plt.rcParams["ytick.major.size"] = 5                #y軸主目盛り線の長さ
plt.rcParams["font.size"] = 20                       #フォントの大きさ


x = np.arange(0.0, 100, 100.0/nmesh)
print(x)
length = len(x)
print(length)

plt.plot(x,data02_1D,marker="o",color='red', linewidth = 1) 
plt.plot(x,data02n_1D,marker="o",color='blue', linewidth = 1) 



#pp = PdfPages('/Users/maeda/Desktop/phi'+"%03.f"%(i)+'.pdf')
pp = PdfPages('/Users/maedarn/Desktop/phierr.pdf')
# 画像をPDFとして保存する
pp.savefig(fig, bbox_inches='tight')
# PDFの保存終了
pp.close()

plt.show()
# Out:
# 2.5511144981444148e-14 0.0 3.1167421421507413e-10
# [ 0.       0.78125  1.5625   2.34375  3.125    3.90625  4.6875   5.46875
#   6.25     7.03125  7.8125   8.59375  9.375   10.15625 10.9375  11.71875
#  12.5     13.28125 14.0625  14.84375 15.625   16.40625 17.1875  17.96875
#  18.75    19.53125 20.3125  21.09375 21.875   22.65625 23.4375  24.21875
#  25.      25.78125 26.5625  27.34375 28.125   28.90625 29.6875  30.46875
#  31.25    32.03125 32.8125  33.59375 34.375   35.15625 35.9375  36.71875
#  37.5     38.28125 39.0625  39.84375 40.625   41.40625 42.1875  42.96875
#  43.75    44.53125 45.3125  46.09375 46.875   47.65625 48.4375  49.21875
#  50.      50.78125 51.5625  52.34375 53.125   53.90625 54.6875  55.46875
#  56.25    57.03125 57.8125  58.59375 59.375   60.15625 60.9375  61.71875
#  62.5     63.28125 64.0625  64.84375 65.625   66.40625 67.1875  67.96875
#  68.75    69.53125 70.3125  71.09375 71.875   72.65625 73.4375  74.21875
#  75.      75.78125 76.5625  77.34375 78.125   78.90625 79.6875  80.46875
#  81.25    82.03125 82.8125  83.59375 84.375   85.15625 85.9375  86.71875
#  87.5     88.28125 89.0625  89.84375 90.625   91.40625 92.1875  92.96875
#  93.75    94.53125 95.3125  96.09375 96.875   97.65625 98.4375  99.21875]
# 128
